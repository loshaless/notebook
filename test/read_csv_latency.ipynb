# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('latency.csv')
df['seq_id'] = pd.to_numeric(df['seq_id'], errors='coerce')

test = df[df['interaction_id'] == 'qGKqAj']
sorted_test = test.sort_values(by=['action', 'seq_id'])
sorted_test
# Out:
#      interaction_id  seq_id                        action  duration  \
# 1254         qGKqAj     2.0   call_intent_detection_total  0.675311
# 1260         qGKqAj     3.0   call_intent_detection_total  0.776727
# 1264         qGKqAj     4.0   call_intent_detection_total  0.723981
# 1270         qGKqAj     5.0   call_intent_detection_total  0.633813
# 1274         qGKqAj     6.0   call_intent_detection_total  0.649266
# ...             ...     ...                           ...       ...
# 1383         qGKqAj    54.0              summarizer_total  1.381428
# 1385         qGKqAj    55.0              summarizer_total  1.275050
# 1389         qGKqAj    56.0              summarizer_total  1.393505
# 1391         qGKqAj    57.0              summarizer_total  1.324106
# 1395         qGKqAj    59.0              summarizer_total  1.333106
#
#                  timestamp
# 1254   2025-01-24 12:32:35
# 1260   2025-01-24 12:32:40
# 1264   2025-01-24 12:32:45
# 1270   2025-01-24 12:32:50
# 1274   2025-01-24 12:32:55
# ...                    ...
# 1383   2025-01-24 12:34:40
# 1385   2025-01-24 12:34:43
# 1389   2025-01-24 12:34:45
# 1391   2025-01-24 12:34:48
# 1395   2025-01-24 12:34:53
#
# [147 rows x 5 columns]
