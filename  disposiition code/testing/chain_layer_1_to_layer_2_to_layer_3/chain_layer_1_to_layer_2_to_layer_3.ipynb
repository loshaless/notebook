# %% [markdown]
# # FUNCTION

# %%
import pandas as pd
from io import StringIO
from google.cloud import storage
from vertexai.generative_models import (
    GenerativeModel,
    GenerationConfig,
    HarmCategory,
    HarmBlockThreshold
)

def load_transcription_csv(file_path):
    storage_client = storage.Client()
    bucket = storage_client.bucket('athena-nonprod-gcs')
    blob = bucket.blob(file_path)
    content = blob.download_as_text()

    return pd.read_csv(StringIO(content))[['speaker', 'transcript']]

def get_prompt(file_name, **kwargs):
    with open(f'./prompt/{file_name}', 'r') as file:
        prompt_template = file.read()

    return prompt_template.format(**kwargs)

def generate_prompt_formatted(layer: int, interaction_id: str, list_of_option):
    transcript_df = load_transcription_csv(f"athena-ws4a/athena-qapm/transcription/{interaction_id}/transcription_results.csv")
    transcript_df = transcript_df.where(pd.notnull(transcript_df), '')
    json_dict = transcript_df.to_dict(orient='records')
    prompt = get_prompt(
        file_name=f'disposition_code_cleaned_layer_{layer}.txt',
        transcript=json_dict,
        list_of_option=','.join(list_of_option),
    )
    return prompt

# %% [markdown]
# ## MODEL LLM

# %%
model = GenerativeModel('gemini-1.5-flash-002')
generation_config = GenerationConfig(
    temperature=0,  # Example temperature value
    # top_k=1,         # Example top-k value
    # top_p=0.1        # Example top-p value
)

def generate_content(prompt):
    result = model.generate_content(
        contents=prompt,
        safety_settings={
            HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        },
        generation_config=generation_config
    )
    return result

# %% [markdown]
# # BATCH PROCESS

# %%
import json

with open('../../clean_data/action_to_product.json') as f:
    map_action_to_product = json.load(f)
    list_of_action = list(map_action_to_product.keys())

with open('../../clean_data/action_product_to_detail.json') as f:
    map_action_product_to_detail = json.load(f)

def get_layer_1(interaction_id: str, list_of_option):
    prompt = generate_prompt_formatted(1, interaction_id, list_of_option)
    response = generate_content(prompt).text
    disposition_result = json.loads(response.replace("```json", "").replace("```", "").strip())
    return disposition_result[0]['value']

def get_layer_2(layer_1: str, interaction_id: str):
    list_of_product = map_action_to_product[layer_1]
    prompt = generate_prompt_formatted(2, interaction_id, list_of_product)
    response = generate_content(prompt).text
    disposition_result = json.loads(response.replace("```json", "").replace("```", "").strip())
    return layer_1 + "|" + disposition_result[0]['value']

def get_layer_3(layer_2: str, interaction_id: str):
    list_of_conversational_context = map_action_product_to_detail[layer_2]
    prompt = generate_prompt_formatted(3, interaction_id, list_of_conversational_context)
    response = generate_content(prompt).text
    disposition_result = json.loads(response.replace("```json", "").replace("```", "").strip())
    return disposition_result

list_of_unknown_csv = [9151919416110000090, 9151919416110000091, 9151919416110000092]
output_data = []

for interaction_id in range(9151919416110000051, 9151919416110000100):
    if interaction_id in list_of_unknown_csv:
        continue
    try:
        layer_1 = get_layer_1(interaction_id, list_of_action)
        layer_2 = get_layer_2(layer_1, interaction_id)
        disposition_result = get_layer_3(layer_2, interaction_id)

        output_data.append({
            'interaction_id': interaction_id,
            'option_1': layer_2 + "|" + disposition_result[0]['value'],
            'explanation_1': disposition_result[0]['field3'],
            'option_2': layer_2 + "|" + disposition_result[1]['value'] if len(disposition_result) > 1 else None,
            'explanation_2': disposition_result[1]['field3'] if len(disposition_result) > 1 else None,
            'option_3': layer_2 + "|" +  disposition_result[2]['value'] if len(disposition_result) > 2 else None,
            'explanation_3': disposition_result[2]['field3'] if len(disposition_result) > 2 else None,
        })

        print(f"Processing interaction_id: {interaction_id}")
    except Exception as e:
        print(f"Error: {e} at interaction_id: {interaction_id}")
# Out:
# Processing interaction_id: 9151919416110000051
# Processing interaction_id: 9151919416110000052
# Processing interaction_id: 9151919416110000053
# Processing interaction_id: 9151919416110000054
# Processing interaction_id: 9151919416110000055
# Processing interaction_id: 9151919416110000056
# Processing interaction_id: 9151919416110000057
# Processing interaction_id: 9151919416110000058
# Processing interaction_id: 9151919416110000059
# Processing interaction_id: 9151919416110000060
# Processing interaction_id: 9151919416110000061
# Processing interaction_id: 9151919416110000062
# Processing interaction_id: 9151919416110000063
# Processing interaction_id: 9151919416110000064
# Processing interaction_id: 9151919416110000065
# Processing interaction_id: 9151919416110000066
# Processing interaction_id: 9151919416110000067
# Processing interaction_id: 9151919416110000068
# Processing interaction_id: 9151919416110000069
# Processing interaction_id: 9151919416110000070
# Processing interaction_id: 9151919416110000071
# Processing interaction_id: 9151919416110000072
# Processing interaction_id: 9151919416110000073
# Processing interaction_id: 9151919416110000074
# Processing interaction_id: 9151919416110000075
# Processing interaction_id: 9151919416110000076
# Processing interaction_id: 9151919416110000077
# Processing interaction_id: 9151919416110000078
# Processing interaction_id: 9151919416110000079
# Processing interaction_id: 9151919416110000080
# Processing interaction_id: 9151919416110000081
# Processing interaction_id: 9151919416110000082
# Processing interaction_id: 9151919416110000083
# Processing interaction_id: 9151919416110000084
# Processing interaction_id: 9151919416110000085
# Processing interaction_id: 9151919416110000086
# Processing interaction_id: 9151919416110000087
# Processing interaction_id: 9151919416110000088
# Processing interaction_id: 9151919416110000089
# Processing interaction_id: 9151919416110000093
# Processing interaction_id: 9151919416110000094
# Processing interaction_id: 9151919416110000095
# Processing interaction_id: 9151919416110000096
# Processing interaction_id: 9151919416110000097
# Processing interaction_id: 9151919416110000098
# Processing interaction_id: 9151919416110000099

# %%
df = pd.DataFrame(output_data)
df
# Out:
#          interaction_id                                           option_1  \
# 0   9151919416110000051           Complain|Credit Card|Sanggahan Transaksi
# 1   9151919416110000052           Complain|Credit Card|Sanggahan Transaksi
# 2   9151919416110000053                       Complain|ATM|Gagal Transaksi
# 3   9151919416110000054           Complain|Credit Card|Sanggahan Transaksi
# 4   9151919416110000055                 Complain|OCTO Mobile|Kendala Login
# 5   9151919416110000056               Inquiry|Debit Card|Biaya/Bunga/Denda
# 6   9151919416110000057                                 Inquiry|KPR|Status
# 7   9151919416110000058                          Inquiry|Credit Card|Limit
# 8   9151919416110000059  Complain|Credit Card|Pembayaran Tagihan Credit...
# 9   9151919416110000060                     Inquiry|Credit Card|Annual Fee
# 10  9151919416110000061               Complain|Credit Card|Penutupan Kartu
# 11  9151919416110000062  Complain|Credit Card|Pembayaran Tagihan Credit...
# 12  9151919416110000063           Complain|Credit Card|Biaya/ Bunga/ Denda
# 13  9151919416110000064           Complain|Credit Card|Biaya/ Bunga/ Denda
# 14  9151919416110000065               Complain|KTA/ PL|Bunga/ Biaya/ Denda
# 15  9151919416110000066              Request|Credit Card|Pelunasan Cicilan
# 16  9151919416110000067                         Complain|Credit Card|Limit
# 17  9151919416110000068                 Complain|KPR|Pelunasan Keseluruhan
# 18  9151919416110000069                          Inquiry|Credit Card|Limit
# 19  9151919416110000070               Inquiry|Credit Card|Aktivasi dan PIN
# 20  9151919416110000071                        Inquiry|Credit Card|Tagihan
# 21  9151919416110000072              Inquiry|Credit Card|Perhitungan Bunga
# 22  9151919416110000073              Complain|Debit Card|Kendala Transaksi
# 23  9151919416110000074                     Request|Credit Card|Pembatalan
# 24  9151919416110000075              Complain|Credit Card|Credit Protector
# 25  9151919416110000076               Request|Credit Card|Credit Protector
# 26  9151919416110000077                     Request|Credit Card|Pembatalan
# 27  9151919416110000078               Request|Credit Card|Reversal Payment
# 28  9151919416110000079  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 29  9151919416110000080  Request|OCTO Mobile|Kendala Registrasi Perangk...
# 30  9151919416110000081                      Request|OCTO Mobile|Terblokir
# 31  9151919416110000082             Complain|OCTO Mobile|Kendala Transaksi
# 32  9151919416110000083             Complain|OCTO Mobile|Kendala Transaksi
# 33  9151919416110000084                     Complain|OCTO Clicks|Terblokir
# 34  9151919416110000085  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 35  9151919416110000086                        Inquiry|Credit Card|Tagihan
# 36  9151919416110000087  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37  9151919416110000088                Request|Credit Card|Penutupan Kartu
# 38  9151919416110000089                          Inquiry|Credit Card|Limit
# 39  9151919416110000093               Request|Credit Card|Aktivasi dan PIN
# 40  9151919416110000094  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 41  9151919416110000095  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 42  9151919416110000096                      Inquiry|Credit Card|Cash Plus
# 43  9151919416110000097                      Request|Credit Card|Transaksi
# 44  9151919416110000098                      Request|Credit Card|Pengajuan
# 45  9151919416110000099  Request|Credit Card|Pendaftaran dan Pembatalan...
#
#                                         explanation_1  \
# 0   Penjelasan klasifikasi: Nasabah melaporkan tra...
# 1   Penjelasan klasifikasi: Nasabah melaporkan tra...
# 2   Penjelasan klasifikasi: Nasabah mengalami gaga...
# 3   Penjelasan klasifikasi: Nasabah menanyakan tra...
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...
# 5   Penjelasan klasifikasi: Nasabah menanyakan bia...
# 6   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 7   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 8   Penjelasan klasifikasi: Nasabah menanyakan sta...
# 9   Penjelasan klasifikasi: Nasabah menanyakan sta...
# 10  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 11  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 12  Penjelasan klasifikasi: Nasabah memprotes tagi...
# 13  Penjelasan klasifikasi: Nasabah memprotes besa...
# 14  Penjelasan klasifikasi: Nasabah menanyakan det...
# 15  Penjelasan klasifikasi: Nasabah menanyakan ker...
# 16  Penjelasan klasifikasi: Nasabah meminta pengur...
# 17  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 18  Penjelasan klasifikasi: Nasabah menanyakan lim...
# 19  Penjelasan klasifikasi: Nasabah menanyakan car...
# 20  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 21  Penjelasan klasifikasi: Nasabah menanyakan sim...
# 22  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 23  Penjelasan klasifikasi: Nasabah meminta pembat...
# 24  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 25  Penjelasan klasifikasi: Nasabah menanyakan dan...
# 26  Penjelasan klasifikasi: Nasabah meminta pembat...
# 27  Penjelasan klasifikasi: Nasabah ingin memindah...
# 28  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 29  Penjelasan klasifikasi: Nasabah mengalami kend...
# 30  Penjelasan klasifikasi: Nasabah mengalami kend...
# 31  Penjelasan klasifikasi: Nasabah mengalami kend...
# 32  Penjelasan klasifikasi: Nasabah mengalami kend...
# 33  Penjelasan klasifikasi: Nasabah mengalami kend...
# 34  Penjelasan klasifikasi: Nasabah menanyakan min...
# 35  Penjelasan klasifikasi: Nasabah menanyakan det...
# 36  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 37  Penjelasan klasifikasi: Nasabah meminta penutu...
# 38  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 39  Penjelasan klasifikasi: Nasabah mengalami kend...
# 40  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 41  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 42  Penjelasan klasifikasi: Nasabah menanyakan kon...
# 43  Penjelasan klasifikasi: Nasabah menanyakan kon...
# 44  Penjelasan klasifikasi: Nasabah meminta pembua...
# 45  Penjelasan klasifikasi: Nasabah mengalami kend...
#
#                                              option_2  \
# 0              Complain|Credit Card|Kendala Transaksi
# 1               Complain|Credit Card|Pergantian Kartu
# 2                                  Complain|ATM|Other
# 3              Complain|Credit Card|Kendala Transaksi
# 4   Complain|OCTO Mobile|Kendala Registrasi Perang...
# 5                            Inquiry|Debit Card|Fitur
# 6                                   Inquiry|KPR|Other
# 7                         Inquiry|Credit Card|Tagihan
# 8                          Complain|Credit Card|Limit
# 9                          Inquiry|Credit Card|Status
# 10                       Complain|Credit Card|Tagihan
# 11                Complain|Credit Card|Perubahan Data
# 12                       Complain|Credit Card|Tagihan
# 13  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 14    Complain|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 15                      Request|Credit Card|Pengajuan
# 16                         Complain|Credit Card|Other
# 17                                 Complain|KPR|Other
# 18                     Inquiry|Credit Card|Annual Fee
# 19                          Inquiry|Credit Card|Fitur
# 20                         Inquiry|Credit Card|Status
# 21                      Inquiry|Credit Card|Transaksi
# 22                          Complain|Debit Card|Other
# 23               Request|Credit Card|Credit Protector
# 24                       Complain|Credit Card|Tagihan
# 25                        Request|Credit Card|Tagihan
# 26               Request|Credit Card|Credit Protector
# 27                     Request|Credit Card|Annual Fee
# 28  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...
# 29                      Request|OCTO Mobile|Terblokir
# 30                          Request|OCTO Mobile|Other
# 31                         Complain|OCTO Mobile|Fitur
# 32                         Complain|OCTO Mobile|Fitur
# 33              Complain|OCTO Clicks|Tidak Terima OTP
# 34  Complain|Credit Card|Pembayaran Tagihan Credit...
# 35                        Inquiry|Credit Card|Tagihan
# 36           Complain|Credit Card|Biaya/ Bunga/ Denda
# 37               Request|Credit Card|Aktivasi dan PIN
# 38               Inquiry|Credit Card|Redeem Cash Back
# 39                      Request|Credit Card|Transaksi
# 40                         Complain|Credit Card|Promo
# 41           Complain|Credit Card|Biaya/ Bunga/ Denda
# 42                      Inquiry|Credit Card|Transaksi
# 43              Request|Credit Card|Pelunasan Cicilan
# 44               Request|Credit Card|Aktivasi dan PIN
# 45                          Request|Credit Card|Other
#
#                                         explanation_2  \
# 0   Penjelasan klasifikasi:  Agen memproses lapora...
# 1   Penjelasan klasifikasi: Nasabah meminta pencet...
# 2   Penjelasan klasifikasi: Masalah dengan transak...
# 3   Penjelasan klasifikasi:  Nasabah mengalami tra...
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...
# 5   Penjelasan klasifikasi: Nasabah ingin mengetah...
# 6   Penjelasan klasifikasi: Informasi sisa tagihan...
# 7   Penjelasan klasifikasi: Nasabah menanyakan pen...
# 8   Penjelasan klasifikasi: Nasabah mengalami kend...
# 9   Penjelasan klasifikasi:  Nasabah menanyakan de...
# 10  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 11  Penjelasan klasifikasi: Nasabah meminta peruba...
# 12  Penjelasan klasifikasi:  Nasabah menanyakan ta...
# 13  Penjelasan klasifikasi: Nasabah meminta pengha...
# 14  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 15  Penjelasan klasifikasi: Nasabah ingin mengajuk...
# 16  Penjelasan klasifikasi: Nasabah melaporkan gan...
# 17  Penjelasan klasifikasi:  Nasabah mengalami ken...
# 18  Penjelasan klasifikasi: Nasabah menanyakan det...
# 19  Penjelasan klasifikasi:  Diskusi detail mengen...
# 20  Penjelasan klasifikasi: Nasabah menanyakan det...
# 21  Penjelasan klasifikasi: Nasabah meminta perhit...
# 22  Penjelasan klasifikasi: Nasabah mengalami perb...
# 23  Penjelasan klasifikasi:  Pembatalan Credit Pro...
# 24  Penjelasan klasifikasi: Nasabah melakukan peng...
# 25  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 26  Penjelasan klasifikasi:  Nasabah ingin membata...
# 27  Penjelasan klasifikasi:  Pembahasan mengenai p...
# 28  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 29  Penjelasan klasifikasi: Akun M-Banking nasabah...
# 30  Penjelasan klasifikasi: Nasabah mengalami masa...
# 31  Penjelasan klasifikasi:  Permasalahan transaks...
# 32  Penjelasan klasifikasi:  Nasabah mengalami mas...
# 33  Penjelasan klasifikasi: Nasabah mengalami masa...
# 34  Penjelasan klasifikasi: Nasabah mengalami kesu...
# 35  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 36  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 37  Penjelasan klasifikasi:  Proses penutupan kart...
# 38  Penjelasan klasifikasi: Nasabah menanyakan dan...
# 39  Penjelasan klasifikasi: Nasabah mengalami tran...
# 40  Penjelasan klasifikasi: Nasabah menanyakan det...
# 41  Penjelasan klasifikasi: Perselisihan mengenai ...
# 42  Penjelasan klasifikasi: Percakapan berfokus pa...
# 43  Penjelasan klasifikasi: Nasabah melakukan peru...
# 44  Penjelasan klasifikasi:  Proses verifikasi dat...
# 45  Penjelasan klasifikasi:  Nasabah menanyakan  p...
#
#                                              option_3  \
# 0                      Complain|Credit Card|Transaksi
# 1                 Complain|Credit Card|Perubahan Data
# 2                                                None
# 3                        Complain|Credit Card|Tagihan
# 4              Complain|OCTO Mobile|Kendala Transaksi
# 5                            Inquiry|Debit Card|Other
# 6                                                None
# 7                       Inquiry|Credit Card|Transaksi
# 8     Complain|Credit Card|Naik/ Turun Limit Permanen
# 9                Inquiry|Credit Card|Aktivasi dan PIN
# 10                         Complain|Credit Card|Other
# 11                      Complain|Credit Card|Penipuan
# 12                         Complain|Credit Card|Other
# 13                         Complain|Credit Card|Other
# 14                             Complain|KTA/ PL|Other
# 15                        Request|Credit Card|Tagihan
# 16                       Complain|Credit Card|Tagihan
# 17                                 Complain|KPR|Other
# 18                        Inquiry|Credit Card|Tagihan
# 19                          Inquiry|Credit Card|Promo
# 20               Inquiry|Credit Card|Credit Protector
# 21               Inquiry|Credit Card|Aktivasi dan PIN
# 22              Complain|Debit Card|Kendala Transaksi
# 23                          Request|Credit Card|Other
# 24                    Complain|Credit Card|Pembatalan
# 25  Request|Credit Card|Pembayaran Tagihan Credit ...
# 26               Request|Credit Card|Aktivasi dan PIN
# 27                      Request|Credit Card|Pengajuan
# 28                    Complain|Credit Card|Pembatalan
# 29                     Request|OCTO Mobile|Registrasi
# 30                        Request|OCTO Mobile|Release
# 31                         Complain|OCTO Mobile|Other
# 32                         Complain|OCTO Mobile|Other
# 33             Complain|OCTO Clicks|Kendala Transaksi
# 34                         Complain|Credit Card|Other
# 35                          Inquiry|Credit Card|Promo
# 36             Complain|Credit Card|Pelunasan Cicilan
# 37                          Request|Credit Card|Other
# 38     Inquiry|Credit Card|Naik/ Turun Limit Permanen
# 39                          Request|Credit Card|Other
# 40                       Complain|Credit Card|Tagihan
# 41                         Complain|Credit Card|Limit
# 42                 Inquiry|Credit Card|Perubahan Data
# 43  Request|Credit Card|Pembayaran Tagihan Credit ...
# 44                 Request|Credit Card|Perubahan Data
# 45               Request|Credit Card|Aktivasi dan PIN
#
#                                         explanation_3
# 0   Penjelasan klasifikasi: Nasabah mengajukan san...
# 1   Penjelasan klasifikasi: Nasabah mengalami peru...
# 2                                                None
# 3   Penjelasan klasifikasi:  Proses verifikasi PIN...
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...
# 5   Penjelasan klasifikasi: Nasabah menanyakan car...
# 6                                                None
# 7   Penjelasan klasifikasi: Nasabah bertanya tenta...
# 8   Penjelasan klasifikasi: Nasabah menanyakan car...
# 9   Penjelasan klasifikasi:  Verifikasi identitas ...
# 10  Penjelasan klasifikasi: Nasabah mengeluhkan pr...
# 11  Penjelasan klasifikasi: Nasabah melaporkan men...
# 12  Penjelasan klasifikasi:  Follow up terkait kom...
# 13  Penjelasan klasifikasi:  Nasabah menyampaikan ...
# 14  Penjelasan klasifikasi:  Nasabah mengajukan ko...
# 15  Penjelasan klasifikasi: Percakapan membahas ta...
# 16  Penjelasan klasifikasi: Nasabah menanyakan ken...
# 17  Penjelasan klasifikasi:  Percakapan berfokus p...
# 18  Penjelasan klasifikasi:  Nasabah menanyakan ja...
# 19  Penjelasan klasifikasi: Nasabah menanyakan men...
# 20  Penjelasan klasifikasi: Nasabah meminta pembat...
# 21  Penjelasan klasifikasi:  Nasabah melakukan ver...
# 22  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 23  Penjelasan klasifikasi:  Konfirmasi pembatalan...
# 24  Penjelasan klasifikasi:  Pembatalan Credit Pro...
# 25  Penjelasan klasifikasi: Nasabah menanyakan met...
# 26  Penjelasan klasifikasi:  Proses pembatalan Cre...
# 27  Penjelasan klasifikasi:  Diskusi mengenai pena...
# 28  Penjelasan klasifikasi: Nasabah meminta pembat...
# 29  Penjelasan klasifikasi: Nasabah meminta bantua...
# 30  Penjelasan klasifikasi:  Pembukaan blokir Octo...
# 31  Penjelasan klasifikasi: Agen memandu nasabah u...
# 32  Penjelasan klasifikasi:  Permasalahan PIN ATM ...
# 33  Penjelasan klasifikasi: Masalah utama adalah k...
# 34  Penjelasan klasifikasi:  Nasabah memprotes pro...
# 35  Penjelasan klasifikasi:  Nasabah menanyakan pe...
# 36  Penjelasan klasifikasi:  Permasalahan pelunasa...
# 37  Penjelasan klasifikasi:  Pembahasan mengenai b...
# 38  Penjelasan klasifikasi: Nasabah menanyakan per...
# 39  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 40  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 41  Penjelasan klasifikasi: Nasabah memprotes keti...
# 42  Penjelasan klasifikasi: Nasabah mengalami kesu...
# 43  Penjelasan klasifikasi:  Proses verifikasi dan...
# 44  Penjelasan klasifikasi:  Pengumpulan data prib...
# 45  Penjelasan klasifikasi: Nasabah meminta bantua...

# %% [markdown]
# # Combine data with ground truth

# %%
# read json file
import json

with open('./ground_truth/ground_truth.json') as f:
    ground_truth = json.load(f)

# map with ground truth
df['interaction_id'] = df['interaction_id'].astype(str)
df['ground_truth'] = df['interaction_id'].map(ground_truth)

# save to csv
df.to_csv('output.csv', index=False)

# %% [markdown]
# # Read the output.csv file

# %%
import pandas as pd
df = pd.read_csv('output.csv')
# check whether option_1 or option_2 or option_3 is equal to ground_truth, the result is True or False in "is_match" column
df['is_match'] = (df['ground_truth'] == df['option_1']) | (df['ground_truth'] == df['option_2']) | (df['ground_truth'] == df['option_3'])

df_view = df[['interaction_id', 'option_1', 'option_2', 'option_3', 'ground_truth', 'is_match']]
df_view
# Out:
#          interaction_id                                           option_1  \
# 0   9151919416110000051           Complain|Credit Card|Sanggahan Transaksi
# 1   9151919416110000052           Complain|Credit Card|Sanggahan Transaksi
# 2   9151919416110000053                       Complain|ATM|Gagal Transaksi
# 3   9151919416110000054           Complain|Credit Card|Sanggahan Transaksi
# 4   9151919416110000055                 Complain|OCTO Mobile|Kendala Login
# 5   9151919416110000056               Inquiry|Debit Card|Biaya/Bunga/Denda
# 6   9151919416110000057                                 Inquiry|KPR|Status
# 7   9151919416110000058                          Inquiry|Credit Card|Limit
# 8   9151919416110000059  Complain|Credit Card|Pembayaran Tagihan Credit...
# 9   9151919416110000060                     Inquiry|Credit Card|Annual Fee
# 10  9151919416110000061               Complain|Credit Card|Penutupan Kartu
# 11  9151919416110000062  Complain|Credit Card|Pembayaran Tagihan Credit...
# 12  9151919416110000063           Complain|Credit Card|Biaya/ Bunga/ Denda
# 13  9151919416110000064           Complain|Credit Card|Biaya/ Bunga/ Denda
# 14  9151919416110000065               Complain|KTA/ PL|Bunga/ Biaya/ Denda
# 15  9151919416110000066              Request|Credit Card|Pelunasan Cicilan
# 16  9151919416110000067                         Complain|Credit Card|Limit
# 17  9151919416110000068                 Complain|KPR|Pelunasan Keseluruhan
# 18  9151919416110000069                          Inquiry|Credit Card|Limit
# 19  9151919416110000070               Inquiry|Credit Card|Aktivasi dan PIN
# 20  9151919416110000071                        Inquiry|Credit Card|Tagihan
# 21  9151919416110000072              Inquiry|Credit Card|Perhitungan Bunga
# 22  9151919416110000073              Complain|Debit Card|Kendala Transaksi
# 23  9151919416110000074                     Request|Credit Card|Pembatalan
# 24  9151919416110000075              Complain|Credit Card|Credit Protector
# 25  9151919416110000076               Request|Credit Card|Credit Protector
# 26  9151919416110000077                     Request|Credit Card|Pembatalan
# 27  9151919416110000078               Request|Credit Card|Reversal Payment
# 28  9151919416110000079  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 29  9151919416110000080  Request|OCTO Mobile|Kendala Registrasi Perangk...
# 30  9151919416110000081                      Request|OCTO Mobile|Terblokir
# 31  9151919416110000082             Complain|OCTO Mobile|Kendala Transaksi
# 32  9151919416110000083             Complain|OCTO Mobile|Kendala Transaksi
# 33  9151919416110000084                     Complain|OCTO Clicks|Terblokir
# 34  9151919416110000085  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 35  9151919416110000086                        Inquiry|Credit Card|Tagihan
# 36  9151919416110000087  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37  9151919416110000088                Request|Credit Card|Penutupan Kartu
# 38  9151919416110000089                          Inquiry|Credit Card|Limit
# 39  9151919416110000093               Request|Credit Card|Aktivasi dan PIN
# 40  9151919416110000094  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 41  9151919416110000095  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 42  9151919416110000096                      Inquiry|Credit Card|Cash Plus
# 43  9151919416110000097                      Request|Credit Card|Transaksi
# 44  9151919416110000098                      Request|Credit Card|Pengajuan
# 45  9151919416110000099  Request|Credit Card|Pendaftaran dan Pembatalan...
#
#                                              option_2  \
# 0              Complain|Credit Card|Kendala Transaksi
# 1               Complain|Credit Card|Pergantian Kartu
# 2                                  Complain|ATM|Other
# 3              Complain|Credit Card|Kendala Transaksi
# 4   Complain|OCTO Mobile|Kendala Registrasi Perang...
# 5                            Inquiry|Debit Card|Fitur
# 6                                   Inquiry|KPR|Other
# 7                         Inquiry|Credit Card|Tagihan
# 8                          Complain|Credit Card|Limit
# 9                          Inquiry|Credit Card|Status
# 10                       Complain|Credit Card|Tagihan
# 11                Complain|Credit Card|Perubahan Data
# 12                       Complain|Credit Card|Tagihan
# 13  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 14    Complain|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 15                      Request|Credit Card|Pengajuan
# 16                         Complain|Credit Card|Other
# 17                                 Complain|KPR|Other
# 18                     Inquiry|Credit Card|Annual Fee
# 19                          Inquiry|Credit Card|Fitur
# 20                         Inquiry|Credit Card|Status
# 21                      Inquiry|Credit Card|Transaksi
# 22                          Complain|Debit Card|Other
# 23               Request|Credit Card|Credit Protector
# 24                       Complain|Credit Card|Tagihan
# 25                        Request|Credit Card|Tagihan
# 26               Request|Credit Card|Credit Protector
# 27                     Request|Credit Card|Annual Fee
# 28  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...
# 29                      Request|OCTO Mobile|Terblokir
# 30                          Request|OCTO Mobile|Other
# 31                         Complain|OCTO Mobile|Fitur
# 32                         Complain|OCTO Mobile|Fitur
# 33              Complain|OCTO Clicks|Tidak Terima OTP
# 34  Complain|Credit Card|Pembayaran Tagihan Credit...
# 35                        Inquiry|Credit Card|Tagihan
# 36           Complain|Credit Card|Biaya/ Bunga/ Denda
# 37               Request|Credit Card|Aktivasi dan PIN
# 38               Inquiry|Credit Card|Redeem Cash Back
# 39                      Request|Credit Card|Transaksi
# 40                         Complain|Credit Card|Promo
# 41           Complain|Credit Card|Biaya/ Bunga/ Denda
# 42                      Inquiry|Credit Card|Transaksi
# 43              Request|Credit Card|Pelunasan Cicilan
# 44               Request|Credit Card|Aktivasi dan PIN
# 45                          Request|Credit Card|Other
#
#                                              option_3  \
# 0                      Complain|Credit Card|Transaksi
# 1                 Complain|Credit Card|Perubahan Data
# 2                                                 NaN
# 3                        Complain|Credit Card|Tagihan
# 4              Complain|OCTO Mobile|Kendala Transaksi
# 5                            Inquiry|Debit Card|Other
# 6                                                 NaN
# 7                       Inquiry|Credit Card|Transaksi
# 8     Complain|Credit Card|Naik/ Turun Limit Permanen
# 9                Inquiry|Credit Card|Aktivasi dan PIN
# 10                         Complain|Credit Card|Other
# 11                      Complain|Credit Card|Penipuan
# 12                         Complain|Credit Card|Other
# 13                         Complain|Credit Card|Other
# 14                             Complain|KTA/ PL|Other
# 15                        Request|Credit Card|Tagihan
# 16                       Complain|Credit Card|Tagihan
# 17                                 Complain|KPR|Other
# 18                        Inquiry|Credit Card|Tagihan
# 19                          Inquiry|Credit Card|Promo
# 20               Inquiry|Credit Card|Credit Protector
# 21               Inquiry|Credit Card|Aktivasi dan PIN
# 22              Complain|Debit Card|Kendala Transaksi
# 23                          Request|Credit Card|Other
# 24                    Complain|Credit Card|Pembatalan
# 25  Request|Credit Card|Pembayaran Tagihan Credit ...
# 26               Request|Credit Card|Aktivasi dan PIN
# 27                      Request|Credit Card|Pengajuan
# 28                    Complain|Credit Card|Pembatalan
# 29                     Request|OCTO Mobile|Registrasi
# 30                        Request|OCTO Mobile|Release
# 31                         Complain|OCTO Mobile|Other
# 32                         Complain|OCTO Mobile|Other
# 33             Complain|OCTO Clicks|Kendala Transaksi
# 34                         Complain|Credit Card|Other
# 35                          Inquiry|Credit Card|Promo
# 36             Complain|Credit Card|Pelunasan Cicilan
# 37                          Request|Credit Card|Other
# 38     Inquiry|Credit Card|Naik/ Turun Limit Permanen
# 39                          Request|Credit Card|Other
# 40                       Complain|Credit Card|Tagihan
# 41                         Complain|Credit Card|Limit
# 42                 Inquiry|Credit Card|Perubahan Data
# 43  Request|Credit Card|Pembayaran Tagihan Credit ...
# 44                 Request|Credit Card|Perubahan Data
# 45               Request|Credit Card|Aktivasi dan PIN
#
#                                          ground_truth  is_match
# 0                            Complain|ATM|Gagal Tarik     False
# 1            Complain|Credit Card|Sanggahan Transaksi      True
# 2              Complain|OCTO Mobile|Kendala Transaksi     False
# 3            Complain|Credit Card|Sanggahan Transaksi      True
# 4                  Complain|OCTO Mobile|Kendala Login      True
# 5                              Inquiry|Tabungan|Other     False
# 6                                   Inquiry|KPR|Other      True
# 7                           Inquiry|Credit Card|Limit      True
# 8   Inquiry|Credit Card|Pembayaran Tagihan Credit ...     False
# 9                                                 NaN     False
# 10               Complain|Credit Card|Penutupan Kartu      True
# 11          Complain|Telesales|Penawaran Tidak Sesuai     False
# 12           Complain|Credit Card|Biaya/ Bunga/ Denda      True
# 13           Complain|Credit Card|Biaya/ Bunga/ Denda      True
# 14    Complain|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)      True
# 15                 Complain|Collection|Cara Penagihan     False
# 16  Complain|Credit Card|Pembayaran Tagihan Credit...     False
# 17                 Complain|KPR|Pelunasan Keseluruhan      True
# 18                          Inquiry|Credit Card|Fitur     False
# 19                                                NaN     False
# 20           Complain|Credit Card|Biaya/ Bunga/ Denda     False
# 21  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...     False
# 22  Complain|Credit Card|Pembayaran Tagihan Credit...     False
# 23              Complain|Credit Card|Credit Protector     False
# 24              Complain|Credit Card|Credit Protector      True
# 25               Request|Credit Card|Credit Protector      True
# 26                                                NaN     False
# 27               Request|Credit Card|Reversal Payment      True
# 28  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...      True
# 29                    Complain|OCTO Mobile|Registrasi     False
# 30                                                NaN     False
# 31             Complain|OCTO Mobile|Kendala Transaksi      True
# 32                 Complain|OCTO Clicks|Kendala Login     False
# 33             Complain|OCTO Clicks|Kendala Transaksi      True
# 34  Complain|Credit Card|Pembayaran Tagihan Credit...      True
# 35  Complain|Credit Card|Tagihan (Tidak Terima/ Se...     False
# 36  Complain|Credit Card|Tagihan (Tidak Terima/ Se...      True
# 37                Request|Credit Card|Penutupan Kartu      True
# 38                            Request|Poin Xtra|Other     False
# 39              Complain|Credit Card|Aktivasi dan PIN     False
# 40                                                NaN     False
# 41                                                NaN     False
# 42  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...     False
# 43                                                NaN     False
# 44                                                NaN     False
# 45  Request|Credit Card|Pendaftaran dan Pembatalan...      True

# %% [markdown]
# # CALCULATE ACCURACY

# %%
# calculate the mean of "is_match" column where ground_truth is not NaN
accuracy = df[df['ground_truth'].notnull()]['is_match'].mean()
accuracy*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # calculate the mean of "is_match" column where ground_truth is not NaN
# ----> 2 accuracy = df[df['ground_truth'].notnull()]['is_match'].mean()
#       3 accuracy*100
#
# NameError: name 'df' is not defined

# %%
# GET WHICH LAYER GET THE WRONG PREDICTION
def split_option(df, column_name):
    """Memisahkan kolom berdasarkan '|' dan membuat kolom baru."""
    df[column_name + '_layer_1'] = df[column_name].str.split('|').str[0]
    df[column_name + '_layer_2'] = df[column_name].str.split('|').str[1]
    df[column_name + '_layer_3'] = df[column_name].str.split('|').str[2]
    return df

df = split_option(df, 'option_1')
df = split_option(df, 'option_2')
df = split_option(df, 'option_3')
df = split_option(df, 'ground_truth')

# check if layer 1, layer 2, layer 3 match with ground_truth layer 1, layer 2, layer 3
df['is_match_layer_1'] = (df['ground_truth_layer_1'] == df['option_1_layer_1'])
df['is_match_layer_2'] = (df['ground_truth_layer_2'] == df['option_1_layer_2'])
df['is_match_layer_3'] = (df['ground_truth_layer_3'] == df['option_1_layer_3']) | (df['ground_truth_layer_3'] == df['option_2_layer_3']) | (df['ground_truth_layer_3'] == df['option_3_layer_3'])

# %%
df_view = df[['interaction_id', 'option_1_layer_1', 'option_2_layer_1', 'option_3_layer_1', 'ground_truth_layer_1', 'is_match_layer_1']]
df_view
# Out:
#          interaction_id option_1_layer_1 option_2_layer_1 option_3_layer_1  \
# 0   9151919416110000051         Complain         Complain         Complain
# 1   9151919416110000052         Complain         Complain         Complain
# 2   9151919416110000053         Complain         Complain              NaN
# 3   9151919416110000054         Complain         Complain         Complain
# 4   9151919416110000055         Complain         Complain         Complain
# 5   9151919416110000056          Inquiry          Inquiry          Inquiry
# 6   9151919416110000057          Inquiry          Inquiry              NaN
# 7   9151919416110000058          Inquiry          Inquiry          Inquiry
# 8   9151919416110000059         Complain         Complain         Complain
# 9   9151919416110000060          Inquiry          Inquiry          Inquiry
# 10  9151919416110000061         Complain         Complain         Complain
# 11  9151919416110000062         Complain         Complain         Complain
# 12  9151919416110000063         Complain         Complain         Complain
# 13  9151919416110000064         Complain         Complain         Complain
# 14  9151919416110000065         Complain         Complain         Complain
# 15  9151919416110000066          Request          Request          Request
# 16  9151919416110000067         Complain         Complain         Complain
# 17  9151919416110000068         Complain         Complain         Complain
# 18  9151919416110000069          Inquiry          Inquiry          Inquiry
# 19  9151919416110000070          Inquiry          Inquiry          Inquiry
# 20  9151919416110000071          Inquiry          Inquiry          Inquiry
# 21  9151919416110000072          Inquiry          Inquiry          Inquiry
# 22  9151919416110000073         Complain         Complain         Complain
# 23  9151919416110000074          Request          Request          Request
# 24  9151919416110000075         Complain         Complain         Complain
# 25  9151919416110000076          Request          Request          Request
# 26  9151919416110000077          Request          Request          Request
# 27  9151919416110000078          Request          Request          Request
# 28  9151919416110000079         Complain         Complain         Complain
# 29  9151919416110000080          Request          Request          Request
# 30  9151919416110000081          Request          Request          Request
# 31  9151919416110000082         Complain         Complain         Complain
# 32  9151919416110000083         Complain         Complain         Complain
# 33  9151919416110000084         Complain         Complain         Complain
# 34  9151919416110000085         Complain         Complain         Complain
# 35  9151919416110000086          Inquiry          Inquiry          Inquiry
# 36  9151919416110000087         Complain         Complain         Complain
# 37  9151919416110000088          Request          Request          Request
# 38  9151919416110000089          Inquiry          Inquiry          Inquiry
# 39  9151919416110000093          Request          Request          Request
# 40  9151919416110000094         Complain         Complain         Complain
# 41  9151919416110000095         Complain         Complain         Complain
# 42  9151919416110000096          Inquiry          Inquiry          Inquiry
# 43  9151919416110000097          Request          Request          Request
# 44  9151919416110000098          Request          Request          Request
# 45  9151919416110000099          Request          Request          Request
#
#    ground_truth_layer_1  is_match_layer_1
# 0              Complain              True
# 1              Complain              True
# 2              Complain              True
# 3              Complain              True
# 4              Complain              True
# 5               Inquiry              True
# 6               Inquiry              True
# 7               Inquiry              True
# 8               Inquiry             False
# 9                   NaN             False
# 10             Complain              True
# 11             Complain              True
# 12             Complain              True
# 13             Complain              True
# 14             Complain              True
# 15             Complain             False
# 16             Complain              True
# 17             Complain              True
# 18              Inquiry              True
# 19                  NaN             False
# 20             Complain             False
# 21              Inquiry              True
# 22             Complain              True
# 23             Complain             False
# 24             Complain              True
# 25              Request              True
# 26                  NaN             False
# 27              Request              True
# 28             Complain              True
# 29             Complain             False
# 30                  NaN             False
# 31             Complain              True
# 32             Complain              True
# 33             Complain              True
# 34             Complain              True
# 35             Complain             False
# 36             Complain              True
# 37              Request              True
# 38              Request             False
# 39             Complain             False
# 40                  NaN             False
# 41                  NaN             False
# 42              Inquiry              True
# 43                  NaN             False
# 44                  NaN             False
# 45              Request              True

# %%
accuracy_layer_1 = df[df['ground_truth_layer_1'].notnull()]['is_match_layer_1'].mean()
print(f"Layer 1 accuracy: {accuracy_layer_1}")
# show df for layer 1
# df[['interaction_id', 'option_1_layer_1','option_2_layer_1','option_3_layer_1', 'ground_truth_layer_1', 'is_match_layer_1']]
df[['interaction_id', 'option_1_layer_1', 'ground_truth_layer_1', 'is_match_layer_1']]
# Out:
# Layer 1 accuracy: 0.7894736842105263
#          interaction_id option_1_layer_1 ground_truth_layer_1  \
# 0   9151919416110000051         Complain             Complain
# 1   9151919416110000052         Complain             Complain
# 2   9151919416110000053         Complain             Complain
# 3   9151919416110000054         Complain             Complain
# 4   9151919416110000055         Complain             Complain
# 5   9151919416110000056          Inquiry              Inquiry
# 6   9151919416110000057          Inquiry              Inquiry
# 7   9151919416110000058          Inquiry              Inquiry
# 8   9151919416110000059         Complain              Inquiry
# 9   9151919416110000060          Inquiry                  NaN
# 10  9151919416110000061         Complain             Complain
# 11  9151919416110000062         Complain             Complain
# 12  9151919416110000063         Complain             Complain
# 13  9151919416110000064         Complain             Complain
# 14  9151919416110000065         Complain             Complain
# 15  9151919416110000066          Request             Complain
# 16  9151919416110000067         Complain             Complain
# 17  9151919416110000068         Complain             Complain
# 18  9151919416110000069          Inquiry              Inquiry
# 19  9151919416110000070          Inquiry                  NaN
# 20  9151919416110000071          Inquiry             Complain
# 21  9151919416110000072          Inquiry              Inquiry
# 22  9151919416110000073         Complain             Complain
# 23  9151919416110000074          Request             Complain
# 24  9151919416110000075         Complain             Complain
# 25  9151919416110000076          Request              Request
# 26  9151919416110000077          Request                  NaN
# 27  9151919416110000078          Request              Request
# 28  9151919416110000079         Complain             Complain
# 29  9151919416110000080          Request             Complain
# 30  9151919416110000081          Request                  NaN
# 31  9151919416110000082         Complain             Complain
# 32  9151919416110000083         Complain             Complain
# 33  9151919416110000084         Complain             Complain
# 34  9151919416110000085         Complain             Complain
# 35  9151919416110000086          Inquiry             Complain
# 36  9151919416110000087         Complain             Complain
# 37  9151919416110000088          Request              Request
# 38  9151919416110000089          Inquiry              Request
# 39  9151919416110000093          Request             Complain
# 40  9151919416110000094         Complain                  NaN
# 41  9151919416110000095         Complain                  NaN
# 42  9151919416110000096          Inquiry              Inquiry
# 43  9151919416110000097          Request                  NaN
# 44  9151919416110000098          Request                  NaN
# 45  9151919416110000099          Request              Request
#
#     is_match_layer_1
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8              False
# 9              False
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15             False
# 16              True
# 17              True
# 18              True
# 19             False
# 20             False
# 21              True
# 22              True
# 23             False
# 24              True
# 25              True
# 26             False
# 27              True
# 28              True
# 29             False
# 30             False
# 31              True
# 32              True
# 33              True
# 34              True
# 35             False
# 36              True
# 37              True
# 38             False
# 39             False
# 40             False
# 41             False
# 42              True
# 43             False
# 44             False
# 45              True

# %%
accuracy_layer_2 = df[df['ground_truth_layer_2'].notnull()]['is_match_layer_2'].mean()
print(f"Layer 2 accuracy: {accuracy_layer_2}")
df[['interaction_id','option_1_layer_2','option_2_layer_2','option_3_layer_2', 'ground_truth_layer_2', 'is_match_layer_2']]
# Out:
# Layer 2 accuracy: 0.7894736842105263
#          interaction_id option_1_layer_2 option_2_layer_2 option_3_layer_2  \
# 0   9151919416110000051      Credit Card      Credit Card      Credit Card
# 1   9151919416110000052      Credit Card      Credit Card      Credit Card
# 2   9151919416110000053              ATM              ATM              NaN
# 3   9151919416110000054      Credit Card      Credit Card      Credit Card
# 4   9151919416110000055      OCTO Mobile      OCTO Mobile      OCTO Mobile
# 5   9151919416110000056       Debit Card       Debit Card       Debit Card
# 6   9151919416110000057              KPR              KPR              NaN
# 7   9151919416110000058      Credit Card      Credit Card      Credit Card
# 8   9151919416110000059      Credit Card      Credit Card      Credit Card
# 9   9151919416110000060      Credit Card      Credit Card      Credit Card
# 10  9151919416110000061      Credit Card      Credit Card      Credit Card
# 11  9151919416110000062      Credit Card      Credit Card      Credit Card
# 12  9151919416110000063      Credit Card      Credit Card      Credit Card
# 13  9151919416110000064      Credit Card      Credit Card      Credit Card
# 14  9151919416110000065          KTA/ PL          KTA/ PL          KTA/ PL
# 15  9151919416110000066      Credit Card      Credit Card      Credit Card
# 16  9151919416110000067      Credit Card      Credit Card      Credit Card
# 17  9151919416110000068              KPR              KPR              KPR
# 18  9151919416110000069      Credit Card      Credit Card      Credit Card
# 19  9151919416110000070      Credit Card      Credit Card      Credit Card
# 20  9151919416110000071      Credit Card      Credit Card      Credit Card
# 21  9151919416110000072      Credit Card      Credit Card      Credit Card
# 22  9151919416110000073       Debit Card       Debit Card       Debit Card
# 23  9151919416110000074      Credit Card      Credit Card      Credit Card
# 24  9151919416110000075      Credit Card      Credit Card      Credit Card
# 25  9151919416110000076      Credit Card      Credit Card      Credit Card
# 26  9151919416110000077      Credit Card      Credit Card      Credit Card
# 27  9151919416110000078      Credit Card      Credit Card      Credit Card
# 28  9151919416110000079      Credit Card      Credit Card      Credit Card
# 29  9151919416110000080      OCTO Mobile      OCTO Mobile      OCTO Mobile
# 30  9151919416110000081      OCTO Mobile      OCTO Mobile      OCTO Mobile
# 31  9151919416110000082      OCTO Mobile      OCTO Mobile      OCTO Mobile
# 32  9151919416110000083      OCTO Mobile      OCTO Mobile      OCTO Mobile
# 33  9151919416110000084      OCTO Clicks      OCTO Clicks      OCTO Clicks
# 34  9151919416110000085      Credit Card      Credit Card      Credit Card
# 35  9151919416110000086      Credit Card      Credit Card      Credit Card
# 36  9151919416110000087      Credit Card      Credit Card      Credit Card
# 37  9151919416110000088      Credit Card      Credit Card      Credit Card
# 38  9151919416110000089      Credit Card      Credit Card      Credit Card
# 39  9151919416110000093      Credit Card      Credit Card      Credit Card
# 40  9151919416110000094      Credit Card      Credit Card      Credit Card
# 41  9151919416110000095      Credit Card      Credit Card      Credit Card
# 42  9151919416110000096      Credit Card      Credit Card      Credit Card
# 43  9151919416110000097      Credit Card      Credit Card      Credit Card
# 44  9151919416110000098      Credit Card      Credit Card      Credit Card
# 45  9151919416110000099      Credit Card      Credit Card      Credit Card
#
#    ground_truth_layer_2  is_match_layer_2
# 0                   ATM             False
# 1           Credit Card              True
# 2           OCTO Mobile             False
# 3           Credit Card              True
# 4           OCTO Mobile              True
# 5              Tabungan             False
# 6                   KPR              True
# 7           Credit Card              True
# 8           Credit Card              True
# 9                   NaN             False
# 10          Credit Card              True
# 11            Telesales             False
# 12          Credit Card              True
# 13          Credit Card              True
# 14              KTA/ PL              True
# 15           Collection             False
# 16          Credit Card              True
# 17                  KPR              True
# 18          Credit Card              True
# 19                  NaN             False
# 20          Credit Card              True
# 21          Credit Card              True
# 22          Credit Card             False
# 23          Credit Card              True
# 24          Credit Card              True
# 25          Credit Card              True
# 26                  NaN             False
# 27          Credit Card              True
# 28          Credit Card              True
# 29          OCTO Mobile              True
# 30                  NaN             False
# 31          OCTO Mobile              True
# 32          OCTO Clicks             False
# 33          OCTO Clicks              True
# 34          Credit Card              True
# 35          Credit Card              True
# 36          Credit Card              True
# 37          Credit Card              True
# 38            Poin Xtra             False
# 39          Credit Card              True
# 40                  NaN             False
# 41                  NaN             False
# 42          Credit Card              True
# 43                  NaN             False
# 44                  NaN             False
# 45          Credit Card              True

# %%
accuracy_layer_3 = df[df['ground_truth_layer_3'].notnull()]['is_match_layer_3'].mean()
print(f"Layer 3 accuracy: {accuracy_layer_3}")
df[['interaction_id','option_1_layer_3','option_2_layer_3','option_3_layer_3', 'ground_truth_layer_3', 'is_match_layer_3']]
# Out:
# Layer 3 accuracy: 0.6578947368421053
#          interaction_id                        option_1_layer_3  \
# 0   9151919416110000051                     Sanggahan Transaksi
# 1   9151919416110000052                     Sanggahan Transaksi
# 2   9151919416110000053                         Gagal Transaksi
# 3   9151919416110000054                     Sanggahan Transaksi
# 4   9151919416110000055                           Kendala Login
# 5   9151919416110000056                       Biaya/Bunga/Denda
# 6   9151919416110000057                                  Status
# 7   9151919416110000058                                   Limit
# 8   9151919416110000059          Pembayaran Tagihan Credit Card
# 9   9151919416110000060                              Annual Fee
# 10  9151919416110000061                         Penutupan Kartu
# 11  9151919416110000062          Pembayaran Tagihan Credit Card
# 12  9151919416110000063                     Biaya/ Bunga/ Denda
# 13  9151919416110000064                     Biaya/ Bunga/ Denda
# 14  9151919416110000065                     Bunga/ Biaya/ Denda
# 15  9151919416110000066                       Pelunasan Cicilan
# 16  9151919416110000067                                   Limit
# 17  9151919416110000068                   Pelunasan Keseluruhan
# 18  9151919416110000069                                   Limit
# 19  9151919416110000070                        Aktivasi dan PIN
# 20  9151919416110000071                                 Tagihan
# 21  9151919416110000072                       Perhitungan Bunga
# 22  9151919416110000073                       Kendala Transaksi
# 23  9151919416110000074                              Pembatalan
# 24  9151919416110000075                        Credit Protector
# 25  9151919416110000076                        Credit Protector
# 26  9151919416110000077                              Pembatalan
# 27  9151919416110000078                        Reversal Payment
# 28  9151919416110000079         Tagihan (Tidak Terima/ Selisih)
# 29  9151919416110000080       Kendala Registrasi Perangkat Baru
# 30  9151919416110000081                               Terblokir
# 31  9151919416110000082                       Kendala Transaksi
# 32  9151919416110000083                       Kendala Transaksi
# 33  9151919416110000084                               Terblokir
# 34  9151919416110000085         Tagihan (Tidak Terima/ Selisih)
# 35  9151919416110000086                                 Tagihan
# 36  9151919416110000087         Tagihan (Tidak Terima/ Selisih)
# 37  9151919416110000088                         Penutupan Kartu
# 38  9151919416110000089                                   Limit
# 39  9151919416110000093                        Aktivasi dan PIN
# 40  9151919416110000094         Tagihan (Tidak Terima/ Selisih)
# 41  9151919416110000095         Tagihan (Tidak Terima/ Selisih)
# 42  9151919416110000096                               Cash Plus
# 43  9151919416110000097                               Transaksi
# 44  9151919416110000098                               Pengajuan
# 45  9151919416110000099  Pendaftaran dan Pembatalan E-Statement
#
#                      option_2_layer_3                option_3_layer_3  \
# 0                   Kendala Transaksi                       Transaksi
# 1                    Pergantian Kartu                  Perubahan Data
# 2                               Other                             NaN
# 3                   Kendala Transaksi                         Tagihan
# 4   Kendala Registrasi Perangkat Baru               Kendala Transaksi
# 5                               Fitur                           Other
# 6                               Other                             NaN
# 7                             Tagihan                       Transaksi
# 8                               Limit      Naik/ Turun Limit Permanen
# 9                              Status                Aktivasi dan PIN
# 10                            Tagihan                           Other
# 11                     Perubahan Data                        Penipuan
# 12                            Tagihan                           Other
# 13    Tagihan (Tidak Terima/ Selisih)                           Other
# 14     Cicilan (Bunga/ Jumlah/ Tenor)                           Other
# 15                          Pengajuan                         Tagihan
# 16                              Other                         Tagihan
# 17                              Other                           Other
# 18                         Annual Fee                         Tagihan
# 19                              Fitur                           Promo
# 20                             Status                Credit Protector
# 21                          Transaksi                Aktivasi dan PIN
# 22                              Other               Kendala Transaksi
# 23                   Credit Protector                           Other
# 24                            Tagihan                      Pembatalan
# 25                            Tagihan  Pembayaran Tagihan Credit Card
# 26                   Credit Protector                Aktivasi dan PIN
# 27                         Annual Fee                       Pengajuan
# 28     Cicilan (Bunga/ Jumlah/ Tenor)                      Pembatalan
# 29                          Terblokir                      Registrasi
# 30                              Other                         Release
# 31                              Fitur                           Other
# 32                              Fitur                           Other
# 33                   Tidak Terima OTP               Kendala Transaksi
# 34     Pembayaran Tagihan Credit Card                           Other
# 35                            Tagihan                           Promo
# 36                Biaya/ Bunga/ Denda               Pelunasan Cicilan
# 37                   Aktivasi dan PIN                           Other
# 38                   Redeem Cash Back      Naik/ Turun Limit Permanen
# 39                          Transaksi                           Other
# 40                              Promo                         Tagihan
# 41                Biaya/ Bunga/ Denda                           Limit
# 42                          Transaksi                  Perubahan Data
# 43                  Pelunasan Cicilan  Pembayaran Tagihan Credit Card
# 44                   Aktivasi dan PIN                  Perubahan Data
# 45                              Other                Aktivasi dan PIN
#
#                       ground_truth_layer_3  is_match_layer_3
# 0                              Gagal Tarik             False
# 1                      Sanggahan Transaksi              True
# 2                        Kendala Transaksi             False
# 3                      Sanggahan Transaksi              True
# 4                            Kendala Login              True
# 5                                    Other              True
# 6                                    Other              True
# 7                                    Limit              True
# 8           Pembayaran Tagihan Credit Card              True
# 9                                      NaN             False
# 10                         Penutupan Kartu              True
# 11                  Penawaran Tidak Sesuai             False
# 12                     Biaya/ Bunga/ Denda              True
# 13                     Biaya/ Bunga/ Denda              True
# 14          Cicilan (Bunga/ Jumlah/ Tenor)              True
# 15                          Cara Penagihan             False
# 16          Pembayaran Tagihan Credit Card             False
# 17                   Pelunasan Keseluruhan              True
# 18                                   Fitur             False
# 19                                     NaN             False
# 20                     Biaya/ Bunga/ Denda             False
# 21          Cicilan (Bunga/ Jumlah/ Tenor)             False
# 22          Pembayaran Tagihan Credit Card             False
# 23                        Credit Protector              True
# 24                        Credit Protector              True
# 25                        Credit Protector              True
# 26                                     NaN             False
# 27                        Reversal Payment              True
# 28          Cicilan (Bunga/ Jumlah/ Tenor)              True
# 29                              Registrasi              True
# 30                                     NaN             False
# 31                       Kendala Transaksi              True
# 32                           Kendala Login             False
# 33                       Kendala Transaksi              True
# 34          Pembayaran Tagihan Credit Card              True
# 35         Tagihan (Tidak Terima/ Selisih)             False
# 36         Tagihan (Tidak Terima/ Selisih)              True
# 37                         Penutupan Kartu              True
# 38                                   Other             False
# 39                        Aktivasi dan PIN              True
# 40                                     NaN             False
# 41                                     NaN             False
# 42          Cicilan (Bunga/ Jumlah/ Tenor)             False
# 43                                     NaN             False
# 44                                     NaN             False
# 45  Pendaftaran dan Pembatalan E-Statement              True
