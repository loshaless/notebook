# %% [markdown]
# # FUNCTION

# %%
import pandas as pd
from io import StringIO
from google.cloud import storage
import requests
from vertexai.generative_models import (
    GenerativeModel,
    GenerationConfig,
    HarmCategory,
    HarmBlockThreshold
)

def load_transcription_csv(bucket_name, file_path):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(file_path)
    content = blob.download_as_text()

    return pd.read_csv(StringIO(content))

def get_prompt(**kwargs):
    with open('prompt/disposition_code_cleaned_layer_2.txt', 'r') as file:
        prompt_template = file.read()

    return prompt_template.format(**kwargs)

def generate_prompt(bucket_name, file_path, interaction_id: str, list_of_option):
    transcript_df = load_transcription_csv(bucket_name,f"{file_path}/transcription/{interaction_id}/transcription_results.csv")
    transcript_df = transcript_df.where(pd.notnull(transcript_df), '')
    json_dict = transcript_df.to_dict(orient='records')
    prompt = get_prompt(
        transcript=json_dict,
        list_of_product=','.join(list_of_option),
    )
    return prompt

# %% [markdown]
# # BATCH PROCESS

# %% [markdown]
# ## MODEL LLM

# %%
model = GenerativeModel('gemini-1.5-flash-002')
generation_config = GenerationConfig(
    temperature=0.1,  # Example temperature value
    top_k=1,         # Example top-k value
    top_p=0.1        # Example top-p value
)

def generate_content(prompt):
    result = model.generate_content(
        contents=prompt,
        safety_settings={
            HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        },
        generation_config=generation_config
    )
    return result

# %%
import json

with open('./ref_data/list_of_option.json') as f:
    list_of_option = json.load(f)['value']

list_of_unknown_csv = [9151919416110000090, 9151919416110000091, 9151919416110000092]
output_data = []

for interaction_id in range(9151919416110000051, 9151919416110000100):
    if interaction_id in list_of_unknown_csv:
        continue
    try:
        prompt = generate_prompt('athena-nonprod-gcs', 'athena-ws4a/athena-qapm', interaction_id, list_of_option)
        response = generate_content(prompt).text
        disposition_result = json.loads(response.replace("```json", "").replace("```", "").strip())
        output_data.append({
            'interaction_id': interaction_id,
            'option_1': disposition_result[0]['value'],
            'explanation_1': disposition_result[0]['field3'],
            'option_2': disposition_result[1]['value'] if len(disposition_result) > 1 else None,
            'explanation_2': disposition_result[1]['field3'] if len(disposition_result) > 1 else None,
            'option_3': disposition_result[2]['value'] if len(disposition_result) > 2 else None,
            'explanation_3': disposition_result[2]['field3'] if len(disposition_result) > 2 else None,
        })

        print(f"Processing interaction_id: {interaction_id}")
    except Exception as e:
        print(f"Error: {e} at interaction_id: {interaction_id}")
# Out:
# Processing interaction_id: 9151919416110000051
# Processing interaction_id: 9151919416110000052
# Processing interaction_id: 9151919416110000053
# Processing interaction_id: 9151919416110000054
# Processing interaction_id: 9151919416110000055
# Processing interaction_id: 9151919416110000056
# Processing interaction_id: 9151919416110000057
# Processing interaction_id: 9151919416110000058
# Processing interaction_id: 9151919416110000059
# Processing interaction_id: 9151919416110000060
# Processing interaction_id: 9151919416110000061
# Processing interaction_id: 9151919416110000062
# Processing interaction_id: 9151919416110000063
# Processing interaction_id: 9151919416110000064
# Processing interaction_id: 9151919416110000065
# Processing interaction_id: 9151919416110000066
# Processing interaction_id: 9151919416110000067
# Processing interaction_id: 9151919416110000068
# Processing interaction_id: 9151919416110000069
# Processing interaction_id: 9151919416110000070
# Processing interaction_id: 9151919416110000071
# Processing interaction_id: 9151919416110000072
# Processing interaction_id: 9151919416110000073
# Processing interaction_id: 9151919416110000074
# Processing interaction_id: 9151919416110000075
# Processing interaction_id: 9151919416110000076
# Processing interaction_id: 9151919416110000077
# Processing interaction_id: 9151919416110000078
# Processing interaction_id: 9151919416110000079
# Processing interaction_id: 9151919416110000080
# Processing interaction_id: 9151919416110000081
# Processing interaction_id: 9151919416110000082
# Processing interaction_id: 9151919416110000083
# Processing interaction_id: 9151919416110000084
# Processing interaction_id: 9151919416110000085
# Processing interaction_id: 9151919416110000086
# Processing interaction_id: 9151919416110000087
# Processing interaction_id: 9151919416110000088
# Processing interaction_id: 9151919416110000089
# Processing interaction_id: 9151919416110000093
# Processing interaction_id: 9151919416110000094
# Processing interaction_id: 9151919416110000095
# Processing interaction_id: 9151919416110000096
# Processing interaction_id: 9151919416110000097
# Processing interaction_id: 9151919416110000098
# Processing interaction_id: 9151919416110000099

# %%
df = pd.DataFrame(output_data)
df
# Out:
#          interaction_id          option_1  \
# 0   9151919416110000051       Credit Card
# 1   9151919416110000052       Credit Card
# 2   9151919416110000053             GoPay
# 3   9151919416110000054       Credit Card
# 4   9151919416110000055       OCTO Mobile
# 5   9151919416110000056        Debit Card
# 6   9151919416110000057               KPR
# 7   9151919416110000058       Credit Card
# 8   9151919416110000059       Credit Card
# 9   9151919416110000060       Credit Card
# 10  9151919416110000061       Credit Card
# 11  9151919416110000062       Credit Card
# 12  9151919416110000063       Credit Card
# 13  9151919416110000064       Credit Card
# 14  9151919416110000065     Personal Loan
# 15  9151919416110000066       Credit Card
# 16  9151919416110000067       Credit Card
# 17  9151919416110000068               KPR
# 18  9151919416110000069       Credit Card
# 19  9151919416110000070       Credit Card
# 20  9151919416110000071       Credit Card
# 21  9151919416110000072       Credit Card
# 22  9151919416110000073       Credit Card
# 23  9151919416110000074  Credit Protector
# 24  9151919416110000075  Credit Protector
# 25  9151919416110000076  Credit Protector
# 26  9151919416110000077  Credit Protector
# 27  9151919416110000078       Credit Card
# 28  9151919416110000079       Credit Card
# 29  9151919416110000080       OCTO Mobile
# 30  9151919416110000081       OCTO Mobile
# 31  9151919416110000082       OCTO Mobile
# 32  9151919416110000083       OCTO Mobile
# 33  9151919416110000084       OCTO Clicks
# 34  9151919416110000085       Credit Card
# 35  9151919416110000086       Credit Card
# 36  9151919416110000087       Credit Card
# 37  9151919416110000088       Credit Card
# 38  9151919416110000089       Credit Card
# 39  9151919416110000093       Credit Card
# 40  9151919416110000094    Contact Center
# 41  9151919416110000095    Contact Center
# 42  9151919416110000096         Cash Plus
# 43  9151919416110000097       Credit Card
# 44  9151919416110000098       Credit Card
# 45  9151919416110000099       Credit Card
#
#                                         explanation_1         option_2  \
# 0   Penjelasan klasifikasi: Nasabah mengalami gaga...             None
# 1   Penjelasan klasifikasi: Nasabah menanyakan tra...             None
# 2   Penjelasan klasifikasi: Nasabah mengalami kend...             None
# 3   Penjelasan klasifikasi: Nasabah menanyakan tra...             None
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...             None
# 5   Penjelasan klasifikasi: Nasabah menanyakan bia...             None
# 6   Penjelasan klasifikasi: Nasabah menanyakan sis...             None
# 7   Penjelasan klasifikasi: Nasabah menanyakan sis...             None
# 8   Nasabah menanyakan status pembayaran kartu kre...             None
# 9   Penjelasan klasifikasi: Nasabah menanyakan pen...             None
# 10  Penjelasan klasifikasi: Nasabah menanyakan sta...             None
# 11  Penjelasan klasifikasi: Nasabah komplain pemba...  Fraud Awareness
# 12  Penjelasan klasifikasi: Nasabah memprotes tagi...      Credit Card
# 13  Penjelasan klasifikasi: Nasabah komplain denda...             None
# 14  Penjelasan klasifikasi: Nasabah menanyakan tun...             None
# 15  Penjelasan klasifikasi: Nasabah menanyakan ker...             None
# 16  Nasabah mengeluhkan limit minimum pembayaran k...   Contact Center
# 17  Nasabah menanyakan follow up pengajuan KPR yan...             None
# 18  Penjelasan klasifikasi: Nasabah menanyakan lim...             None
# 19  Penjelasan klasifikasi: Nasabah menanyakan car...             None
# 20  Penjelasan klasifikasi: Nasabah menanyakan tag...             None
# 21  Penjelasan klasifikasi: Nasabah menanyakan sim...             None
# 22  Penjelasan klasifikasi: Nasabah menanyakan men...             None
# 23  Penjelasan klasifikasi: Nasabah meminta pengha...             None
# 24  Penjelasan klasifikasi: Nasabah mempertanyakan...             None
# 25  Nasabah menanyakan dan meminta pembatalan Cred...             None
# 26  Nasabah meminta penghapusan Kredit Protekor Ka...             None
# 27  Penjelasan klasifikasi: Nasabah menanyakan pen...             None
# 28  Penjelasan klasifikasi: Nasabah menanyakan tag...             None
# 29  Penjelasan klasifikasi: Nasabah ingin menggant...             None
# 30  Penjelasan klasifikasi: Nasabah mengalami kend...             None
# 31  Nasabah mengalami kendala transfer via mobile ...             None
# 32  Nasabah mengalami kendala transfer via Octo Mo...             None
# 33  Penjelasan klasifikasi: Nasabah mengalami kend...             None
# 34  Penjelasan klasifikasi: Nasabah menanyakan min...             None
# 35  Penjelasan klasifikasi: Nasabah menanyakan tag...             None
# 36  Penjelasan klasifikasi: Nasabah menanyakan lap...             None
# 37  Penjelasan klasifikasi: Nasabah meminta penutu...             None
# 38  Nasabah menanyakan sisa limit kartu kredit dan...        Poin Xtra
# 39  Nasabah mengalami kendala aktivasi kartu kredi...             None
# 40  Penjelasan klasifikasi: Nasabah menanyakan det...             None
# 41  Penjelasan klasifikasi: Nasabah menanyakan det...             None
# 42  Nasabah menanyakan kemungkinan mengubah transa...             None
# 43  Penjelasan klasifikasi: Nasabah menanyakan kon...             None
# 44  Nasabah meminta aktivasi kartu kredit tambahan...             None
# 45  Penjelasan klasifikasi: Nasabah menanyakan dan...             None
#
#                                         explanation_2     option_3  \
# 0                                                None         None
# 1                                                None         None
# 2                                                None         None
# 3                                                None         None
# 4                                                None         None
# 5                                                None         None
# 6                                                None         None
# 7                                                None         None
# 8                                                None         None
# 9                                                None         None
# 10                                               None         None
# 11  Penjelasan klasifikasi: Nasabah komplain soal ...         None
# 12  Penjelasan klasifikasi: Nasabah menanyakan tag...         None
# 13                                               None         None
# 14                                               None         None
# 15                                               None         None
# 16  Nasabah melaporkan gangguan jaringan internet ...  Credit Card
# 17                                               None         None
# 18                                               None         None
# 19                                               None         None
# 20                                               None         None
# 21                                               None         None
# 22                                               None         None
# 23                                               None         None
# 24                                               None         None
# 25                                               None         None
# 26                                               None         None
# 27                                               None         None
# 28                                               None         None
# 29                                               None         None
# 30                                               None         None
# 31                                               None         None
# 32                                               None         None
# 33                                               None         None
# 34                                               None         None
# 35                                               None         None
# 36                                               None         None
# 37                                               None         None
# 38  Nasabah menanyakan informasi penukaran poin ek...         None
# 39                                               None         None
# 40                                               None         None
# 41                                               None         None
# 42                                               None         None
# 43                                               None         None
# 44                                               None         None
# 45                                               None         None
#
#                                         explanation_3
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16  Nasabah menanyakan status pengajuan penurunan ...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None

# %% [markdown]
# # Combine data with ground truth

# %%
# read json file
import json

with open('./ground_truth/ground_truth.json') as f:
    ground_truth = json.load(f)

# map with ground truth
df['interaction_id'] = df['interaction_id'].astype(str)
df['ground_truth'] = df['interaction_id'].map(ground_truth)

# check whether option_1 or option_2 or option_3 is equal to ground_truth, the result is True or False in "is_match" column
df['is_match'] = (df['ground_truth'].isin(df['option_1'])) | \
                 (df['ground_truth'].isin(df['option_2'])) | \
                 (df['ground_truth'].isin(df['option_3']))

# save to csv
df.to_csv('output.csv', index=False)

# %% [markdown]
# # Read the output.csv file

# %%
df = pd.read_csv('output.csv')
df
# Out:
#          interaction_id          option_1  \
# 0   9151919416110000051       Credit Card
# 1   9151919416110000052       Credit Card
# 2   9151919416110000053             GoPay
# 3   9151919416110000054       Credit Card
# 4   9151919416110000055       OCTO Mobile
# 5   9151919416110000056        Debit Card
# 6   9151919416110000057               KPR
# 7   9151919416110000058       Credit Card
# 8   9151919416110000059       Credit Card
# 9   9151919416110000060       Credit Card
# 10  9151919416110000061       Credit Card
# 11  9151919416110000062       Credit Card
# 12  9151919416110000063       Credit Card
# 13  9151919416110000064       Credit Card
# 14  9151919416110000065     Personal Loan
# 15  9151919416110000066       Credit Card
# 16  9151919416110000067       Credit Card
# 17  9151919416110000068               KPR
# 18  9151919416110000069       Credit Card
# 19  9151919416110000070       Credit Card
# 20  9151919416110000071       Credit Card
# 21  9151919416110000072       Credit Card
# 22  9151919416110000073       Credit Card
# 23  9151919416110000074  Credit Protector
# 24  9151919416110000075  Credit Protector
# 25  9151919416110000076  Credit Protector
# 26  9151919416110000077  Credit Protector
# 27  9151919416110000078       Credit Card
# 28  9151919416110000079       Credit Card
# 29  9151919416110000080       OCTO Mobile
# 30  9151919416110000081       OCTO Mobile
# 31  9151919416110000082       OCTO Mobile
# 32  9151919416110000083       OCTO Mobile
# 33  9151919416110000084       OCTO Clicks
# 34  9151919416110000085       Credit Card
# 35  9151919416110000086       Credit Card
# 36  9151919416110000087       Credit Card
# 37  9151919416110000088       Credit Card
# 38  9151919416110000089       Credit Card
# 39  9151919416110000093       Credit Card
# 40  9151919416110000094    Contact Center
# 41  9151919416110000095    Contact Center
# 42  9151919416110000096         Cash Plus
# 43  9151919416110000097       Credit Card
# 44  9151919416110000098       Credit Card
# 45  9151919416110000099       Credit Card
#
#                                         explanation_1         option_2  \
# 0   Penjelasan klasifikasi: Nasabah mengalami gaga...              NaN
# 1   Penjelasan klasifikasi: Nasabah menanyakan tra...              NaN
# 2   Penjelasan klasifikasi: Nasabah mengalami kend...              NaN
# 3   Penjelasan klasifikasi: Nasabah menanyakan tra...              NaN
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...              NaN
# 5   Penjelasan klasifikasi: Nasabah menanyakan bia...              NaN
# 6   Penjelasan klasifikasi: Nasabah menanyakan sis...              NaN
# 7   Penjelasan klasifikasi: Nasabah menanyakan sis...              NaN
# 8   Nasabah menanyakan status pembayaran kartu kre...              NaN
# 9   Penjelasan klasifikasi: Nasabah menanyakan pen...              NaN
# 10  Penjelasan klasifikasi: Nasabah menanyakan sta...              NaN
# 11  Penjelasan klasifikasi: Nasabah komplain pemba...  Fraud Awareness
# 12  Penjelasan klasifikasi: Nasabah memprotes tagi...      Credit Card
# 13  Penjelasan klasifikasi: Nasabah komplain denda...              NaN
# 14  Penjelasan klasifikasi: Nasabah menanyakan tun...              NaN
# 15  Penjelasan klasifikasi: Nasabah menanyakan ker...              NaN
# 16  Nasabah mengeluhkan limit minimum pembayaran k...   Contact Center
# 17  Nasabah menanyakan follow up pengajuan KPR yan...              NaN
# 18  Penjelasan klasifikasi: Nasabah menanyakan lim...              NaN
# 19  Penjelasan klasifikasi: Nasabah menanyakan car...              NaN
# 20  Penjelasan klasifikasi: Nasabah menanyakan tag...              NaN
# 21  Penjelasan klasifikasi: Nasabah menanyakan sim...              NaN
# 22  Penjelasan klasifikasi: Nasabah menanyakan men...              NaN
# 23  Penjelasan klasifikasi: Nasabah meminta pengha...              NaN
# 24  Penjelasan klasifikasi: Nasabah mempertanyakan...              NaN
# 25  Nasabah menanyakan dan meminta pembatalan Cred...              NaN
# 26  Nasabah meminta penghapusan Kredit Protekor Ka...              NaN
# 27  Penjelasan klasifikasi: Nasabah menanyakan pen...              NaN
# 28  Penjelasan klasifikasi: Nasabah menanyakan tag...              NaN
# 29  Penjelasan klasifikasi: Nasabah ingin menggant...              NaN
# 30  Penjelasan klasifikasi: Nasabah mengalami kend...              NaN
# 31  Nasabah mengalami kendala transfer via mobile ...              NaN
# 32  Nasabah mengalami kendala transfer via Octo Mo...              NaN
# 33  Penjelasan klasifikasi: Nasabah mengalami kend...              NaN
# 34  Penjelasan klasifikasi: Nasabah menanyakan min...              NaN
# 35  Penjelasan klasifikasi: Nasabah menanyakan tag...              NaN
# 36  Penjelasan klasifikasi: Nasabah menanyakan lap...              NaN
# 37  Penjelasan klasifikasi: Nasabah meminta penutu...              NaN
# 38  Nasabah menanyakan sisa limit kartu kredit dan...        Poin Xtra
# 39  Nasabah mengalami kendala aktivasi kartu kredi...              NaN
# 40  Penjelasan klasifikasi: Nasabah menanyakan det...              NaN
# 41  Penjelasan klasifikasi: Nasabah menanyakan det...              NaN
# 42  Nasabah menanyakan kemungkinan mengubah transa...              NaN
# 43  Penjelasan klasifikasi: Nasabah menanyakan kon...              NaN
# 44  Nasabah meminta aktivasi kartu kredit tambahan...              NaN
# 45  Penjelasan klasifikasi: Nasabah menanyakan dan...              NaN
#
#                                         explanation_2     option_3  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11  Penjelasan klasifikasi: Nasabah komplain soal ...          NaN
# 12  Penjelasan klasifikasi: Nasabah menanyakan tag...          NaN
# 13                                                NaN          NaN
# 14                                                NaN          NaN
# 15                                                NaN          NaN
# 16  Nasabah melaporkan gangguan jaringan internet ...  Credit Card
# 17                                                NaN          NaN
# 18                                                NaN          NaN
# 19                                                NaN          NaN
# 20                                                NaN          NaN
# 21                                                NaN          NaN
# 22                                                NaN          NaN
# 23                                                NaN          NaN
# 24                                                NaN          NaN
# 25                                                NaN          NaN
# 26                                                NaN          NaN
# 27                                                NaN          NaN
# 28                                                NaN          NaN
# 29                                                NaN          NaN
# 30                                                NaN          NaN
# 31                                                NaN          NaN
# 32                                                NaN          NaN
# 33                                                NaN          NaN
# 34                                                NaN          NaN
# 35                                                NaN          NaN
# 36                                                NaN          NaN
# 37                                                NaN          NaN
# 38  Nasabah menanyakan informasi penukaran poin ek...          NaN
# 39                                                NaN          NaN
# 40                                                NaN          NaN
# 41                                                NaN          NaN
# 42                                                NaN          NaN
# 43                                                NaN          NaN
# 44                                                NaN          NaN
# 45                                                NaN          NaN
#
#                                         explanation_3 ground_truth  is_match
# 0                                                 NaN          ATM     False
# 1                                                 NaN  Credit Card      True
# 2                                                 NaN  OCTO Mobile      True
# 3                                                 NaN  Credit Card      True
# 4                                                 NaN  OCTO Mobile      True
# 5                                                 NaN     Tabungan     False
# 6                                                 NaN          KPR      True
# 7                                                 NaN  Credit Card      True
# 8                                                 NaN  Credit Card      True
# 9                                                 NaN          NaN     False
# 10                                                NaN  Credit Card      True
# 11                                                NaN    Telesales     False
# 12                                                NaN  Credit Card      True
# 13                                                NaN  Credit Card      True
# 14                                                NaN      KTA/ PL     False
# 15                                                NaN   Collection     False
# 16  Nasabah menanyakan status pengajuan penurunan ...  Credit Card      True
# 17                                                NaN          KPR      True
# 18                                                NaN  Credit Card      True
# 19                                                NaN          NaN     False
# 20                                                NaN  Credit Card      True
# 21                                                NaN  Credit Card      True
# 22                                                NaN  Credit Card      True
# 23                                                NaN  Credit Card      True
# 24                                                NaN  Credit Card      True
# 25                                                NaN  Credit Card      True
# 26                                                NaN          NaN     False
# 27                                                NaN  Credit Card      True
# 28                                                NaN  Credit Card      True
# 29                                                NaN  OCTO Mobile      True
# 30                                                NaN          NaN     False
# 31                                                NaN  OCTO Mobile      True
# 32                                                NaN  OCTO Clicks      True
# 33                                                NaN  OCTO Clicks      True
# 34                                                NaN  Credit Card      True
# 35                                                NaN  Credit Card      True
# 36                                                NaN  Credit Card      True
# 37                                                NaN  Credit Card      True
# 38                                                NaN    Poin Xtra      True
# 39                                                NaN  Credit Card      True
# 40                                                NaN          NaN     False
# 41                                                NaN          NaN     False
# 42                                                NaN  Credit Card      True
# 43                                                NaN          NaN     False
# 44                                                NaN          NaN     False
# 45                                                NaN  Credit Card      True

# %% [markdown]
# # CALCULATE ACCURACY

# %%
# calculate the mean of "is_match" column where ground_truth is not NaN
accuracy = df[df['ground_truth'].notnull()]['is_match'].mean()
accuracy
# Out:
# np.float64(0.868421052631579)

# %%
df
# Out:
#          interaction_id          option_1  \
# 0   9151919416110000051       Credit Card
# 1   9151919416110000052       Credit Card
# 2   9151919416110000053             GoPay
# 3   9151919416110000054       Credit Card
# 4   9151919416110000055       OCTO Mobile
# 5   9151919416110000056        Debit Card
# 6   9151919416110000057               KPR
# 7   9151919416110000058       Credit Card
# 8   9151919416110000059       Credit Card
# 9   9151919416110000060       Credit Card
# 10  9151919416110000061       Credit Card
# 11  9151919416110000062       Credit Card
# 12  9151919416110000063       Credit Card
# 13  9151919416110000064       Credit Card
# 14  9151919416110000065     Personal Loan
# 15  9151919416110000066       Credit Card
# 16  9151919416110000067       Credit Card
# 17  9151919416110000068               KPR
# 18  9151919416110000069       Credit Card
# 19  9151919416110000070       Credit Card
# 20  9151919416110000071       Credit Card
# 21  9151919416110000072       Credit Card
# 22  9151919416110000073       Credit Card
# 23  9151919416110000074  Credit Protector
# 24  9151919416110000075  Credit Protector
# 25  9151919416110000076  Credit Protector
# 26  9151919416110000077  Credit Protector
# 27  9151919416110000078       Credit Card
# 28  9151919416110000079       Credit Card
# 29  9151919416110000080       OCTO Mobile
# 30  9151919416110000081       OCTO Mobile
# 31  9151919416110000082       OCTO Mobile
# 32  9151919416110000083       OCTO Mobile
# 33  9151919416110000084       OCTO Clicks
# 34  9151919416110000085       Credit Card
# 35  9151919416110000086       Credit Card
# 36  9151919416110000087       Credit Card
# 37  9151919416110000088       Credit Card
# 38  9151919416110000089       Credit Card
# 39  9151919416110000093       Credit Card
# 40  9151919416110000094    Contact Center
# 41  9151919416110000095    Contact Center
# 42  9151919416110000096         Cash Plus
# 43  9151919416110000097       Credit Card
# 44  9151919416110000098       Credit Card
# 45  9151919416110000099       Credit Card
#
#                                         explanation_1         option_2  \
# 0   Penjelasan klasifikasi: Nasabah mengalami gaga...              NaN
# 1   Penjelasan klasifikasi: Nasabah menanyakan tra...              NaN
# 2   Penjelasan klasifikasi: Nasabah mengalami kend...              NaN
# 3   Penjelasan klasifikasi: Nasabah menanyakan tra...              NaN
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...              NaN
# 5   Penjelasan klasifikasi: Nasabah menanyakan bia...              NaN
# 6   Penjelasan klasifikasi: Nasabah menanyakan sis...              NaN
# 7   Penjelasan klasifikasi: Nasabah menanyakan sis...              NaN
# 8   Nasabah menanyakan status pembayaran kartu kre...              NaN
# 9   Penjelasan klasifikasi: Nasabah menanyakan pen...              NaN
# 10  Penjelasan klasifikasi: Nasabah menanyakan sta...              NaN
# 11  Penjelasan klasifikasi: Nasabah komplain pemba...  Fraud Awareness
# 12  Penjelasan klasifikasi: Nasabah memprotes tagi...      Credit Card
# 13  Penjelasan klasifikasi: Nasabah komplain denda...              NaN
# 14  Penjelasan klasifikasi: Nasabah menanyakan tun...              NaN
# 15  Penjelasan klasifikasi: Nasabah menanyakan ker...              NaN
# 16  Nasabah mengeluhkan limit minimum pembayaran k...   Contact Center
# 17  Nasabah menanyakan follow up pengajuan KPR yan...              NaN
# 18  Penjelasan klasifikasi: Nasabah menanyakan lim...              NaN
# 19  Penjelasan klasifikasi: Nasabah menanyakan car...              NaN
# 20  Penjelasan klasifikasi: Nasabah menanyakan tag...              NaN
# 21  Penjelasan klasifikasi: Nasabah menanyakan sim...              NaN
# 22  Penjelasan klasifikasi: Nasabah menanyakan men...              NaN
# 23  Penjelasan klasifikasi: Nasabah meminta pengha...              NaN
# 24  Penjelasan klasifikasi: Nasabah mempertanyakan...              NaN
# 25  Nasabah menanyakan dan meminta pembatalan Cred...              NaN
# 26  Nasabah meminta penghapusan Kredit Protekor Ka...              NaN
# 27  Penjelasan klasifikasi: Nasabah menanyakan pen...              NaN
# 28  Penjelasan klasifikasi: Nasabah menanyakan tag...              NaN
# 29  Penjelasan klasifikasi: Nasabah ingin menggant...              NaN
# 30  Penjelasan klasifikasi: Nasabah mengalami kend...              NaN
# 31  Nasabah mengalami kendala transfer via mobile ...              NaN
# 32  Nasabah mengalami kendala transfer via Octo Mo...              NaN
# 33  Penjelasan klasifikasi: Nasabah mengalami kend...              NaN
# 34  Penjelasan klasifikasi: Nasabah menanyakan min...              NaN
# 35  Penjelasan klasifikasi: Nasabah menanyakan tag...              NaN
# 36  Penjelasan klasifikasi: Nasabah menanyakan lap...              NaN
# 37  Penjelasan klasifikasi: Nasabah meminta penutu...              NaN
# 38  Nasabah menanyakan sisa limit kartu kredit dan...        Poin Xtra
# 39  Nasabah mengalami kendala aktivasi kartu kredi...              NaN
# 40  Penjelasan klasifikasi: Nasabah menanyakan det...              NaN
# 41  Penjelasan klasifikasi: Nasabah menanyakan det...              NaN
# 42  Nasabah menanyakan kemungkinan mengubah transa...              NaN
# 43  Penjelasan klasifikasi: Nasabah menanyakan kon...              NaN
# 44  Nasabah meminta aktivasi kartu kredit tambahan...              NaN
# 45  Penjelasan klasifikasi: Nasabah menanyakan dan...              NaN
#
#                                         explanation_2     option_3  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11  Penjelasan klasifikasi: Nasabah komplain soal ...          NaN
# 12  Penjelasan klasifikasi: Nasabah menanyakan tag...          NaN
# 13                                                NaN          NaN
# 14                                                NaN          NaN
# 15                                                NaN          NaN
# 16  Nasabah melaporkan gangguan jaringan internet ...  Credit Card
# 17                                                NaN          NaN
# 18                                                NaN          NaN
# 19                                                NaN          NaN
# 20                                                NaN          NaN
# 21                                                NaN          NaN
# 22                                                NaN          NaN
# 23                                                NaN          NaN
# 24                                                NaN          NaN
# 25                                                NaN          NaN
# 26                                                NaN          NaN
# 27                                                NaN          NaN
# 28                                                NaN          NaN
# 29                                                NaN          NaN
# 30                                                NaN          NaN
# 31                                                NaN          NaN
# 32                                                NaN          NaN
# 33                                                NaN          NaN
# 34                                                NaN          NaN
# 35                                                NaN          NaN
# 36                                                NaN          NaN
# 37                                                NaN          NaN
# 38  Nasabah menanyakan informasi penukaran poin ek...          NaN
# 39                                                NaN          NaN
# 40                                                NaN          NaN
# 41                                                NaN          NaN
# 42                                                NaN          NaN
# 43                                                NaN          NaN
# 44                                                NaN          NaN
# 45                                                NaN          NaN
#
#                                         explanation_3 ground_truth  is_match
# 0                                                 NaN          ATM     False
# 1                                                 NaN  Credit Card      True
# 2                                                 NaN  OCTO Mobile      True
# 3                                                 NaN  Credit Card      True
# 4                                                 NaN  OCTO Mobile      True
# 5                                                 NaN     Tabungan     False
# 6                                                 NaN          KPR      True
# 7                                                 NaN  Credit Card      True
# 8                                                 NaN  Credit Card      True
# 9                                                 NaN          NaN     False
# 10                                                NaN  Credit Card      True
# 11                                                NaN    Telesales     False
# 12                                                NaN  Credit Card      True
# 13                                                NaN  Credit Card      True
# 14                                                NaN      KTA/ PL     False
# 15                                                NaN   Collection     False
# 16  Nasabah menanyakan status pengajuan penurunan ...  Credit Card      True
# 17                                                NaN          KPR      True
# 18                                                NaN  Credit Card      True
# 19                                                NaN          NaN     False
# 20                                                NaN  Credit Card      True
# 21                                                NaN  Credit Card      True
# 22                                                NaN  Credit Card      True
# 23                                                NaN  Credit Card      True
# 24                                                NaN  Credit Card      True
# 25                                                NaN  Credit Card      True
# 26                                                NaN          NaN     False
# 27                                                NaN  Credit Card      True
# 28                                                NaN  Credit Card      True
# 29                                                NaN  OCTO Mobile      True
# 30                                                NaN          NaN     False
# 31                                                NaN  OCTO Mobile      True
# 32                                                NaN  OCTO Clicks      True
# 33                                                NaN  OCTO Clicks      True
# 34                                                NaN  Credit Card      True
# 35                                                NaN  Credit Card      True
# 36                                                NaN  Credit Card      True
# 37                                                NaN  Credit Card      True
# 38                                                NaN    Poin Xtra      True
# 39                                                NaN  Credit Card      True
# 40                                                NaN          NaN     False
# 41                                                NaN          NaN     False
# 42                                                NaN  Credit Card      True
# 43                                                NaN          NaN     False
# 44                                                NaN          NaN     False
# 45                                                NaN  Credit Card      True
