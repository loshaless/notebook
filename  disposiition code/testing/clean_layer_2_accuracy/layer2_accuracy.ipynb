# %% [markdown]
# # FUNCTION

# %%
import pandas as pd
from io import StringIO
from google.cloud import storage
import requests
from vertexai.generative_models import (
    GenerativeModel,
    GenerationConfig,
    HarmCategory,
    HarmBlockThreshold
)

def load_transcription_csv(bucket_name, file_path):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(file_path)
    content = blob.download_as_text()

    return pd.read_csv(StringIO(content))[['speaker', 'transcript']]

def get_prompt(**kwargs):
    with open('prompt/disposition_code_cleaned_layer_2.txt', 'r') as file:
        prompt_template = file.read()

    return prompt_template.format(**kwargs)

def generate_prompt(bucket_name, file_path, interaction_id: str, list_of_option):
    transcript_df = load_transcription_csv(bucket_name,f"{file_path}/transcription/{interaction_id}/transcription_results.csv")
    transcript_df = transcript_df.where(pd.notnull(transcript_df), '')
    json_dict = transcript_df.to_dict(orient='records')
    prompt = get_prompt(
        transcript=json_dict,
        list_of_option=','.join(list_of_option),
    )
    return prompt

# %% [markdown]
# # BATCH PROCESS

# %% [markdown]
# ## MODEL LLM

# %%
model = GenerativeModel('gemini-1.5-flash-002')
generation_config = GenerationConfig(
    temperature=0.1,  # Example temperature value
    top_k=1,         # Example top-k value
    top_p=0.1        # Example top-p value
)

def generate_content(prompt):
    result = model.generate_content(
        contents=prompt,
        safety_settings={
            HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        },
        generation_config=generation_config
    )
    return result

# %%
import json

with open('./ref_data/list_of_option.json') as f:
    list_of_option = json.load(f)['value']

list_of_unknown_csv = [9151919416110000090, 9151919416110000091, 9151919416110000092]
output_data = []

for interaction_id in range(9151919416110000051, 9151919416110000099 + 1):
    if interaction_id in list_of_unknown_csv:
        continue
    try:
        prompt = generate_prompt('athena-nonprod-gcs', 'athena-ws4a/athena-qapm', interaction_id, list_of_option)
        response = generate_content(prompt).text
        disposition_result = json.loads(response.replace("```json", "").replace("```", "").strip())
        output_data.append({
            'interaction_id': interaction_id,
            'option_1': disposition_result[0]['value'],
            'explanation_1': disposition_result[0]['penjelasan'],
            'option_2': disposition_result[1]['value'] if len(disposition_result) > 1 else None,
            'explanation_2': disposition_result[1]['penjelasan'] if len(disposition_result) > 1 else None,
            'option_3': disposition_result[2]['value'] if len(disposition_result) > 2 else None,
            'explanation_3': disposition_result[2]['penjelasan'] if len(disposition_result) > 2 else None,
        })

        print(f"Processing interaction_id: {interaction_id}")
    except Exception as e:
        print(f"Error: {e} at interaction_id: {interaction_id}")
# Out:
# Processing interaction_id: 9151919416110000051
# Processing interaction_id: 9151919416110000052
# Processing interaction_id: 9151919416110000053
# Processing interaction_id: 9151919416110000054
# Processing interaction_id: 9151919416110000055
# Processing interaction_id: 9151919416110000056
# Processing interaction_id: 9151919416110000057
# Processing interaction_id: 9151919416110000058
# Processing interaction_id: 9151919416110000059
# Processing interaction_id: 9151919416110000060
# Processing interaction_id: 9151919416110000061
# Processing interaction_id: 9151919416110000062
# Processing interaction_id: 9151919416110000063
# Processing interaction_id: 9151919416110000064
# Processing interaction_id: 9151919416110000065
# Processing interaction_id: 9151919416110000066
# Processing interaction_id: 9151919416110000067
# Processing interaction_id: 9151919416110000068
# Processing interaction_id: 9151919416110000069
# Processing interaction_id: 9151919416110000070
# Processing interaction_id: 9151919416110000071
# Processing interaction_id: 9151919416110000072
# Processing interaction_id: 9151919416110000073
# Processing interaction_id: 9151919416110000074
# Processing interaction_id: 9151919416110000075
# Processing interaction_id: 9151919416110000076
# Processing interaction_id: 9151919416110000077
# Processing interaction_id: 9151919416110000078
# Processing interaction_id: 9151919416110000079
# Processing interaction_id: 9151919416110000080
# Processing interaction_id: 9151919416110000081
# Processing interaction_id: 9151919416110000082
# Processing interaction_id: 9151919416110000083
# Processing interaction_id: 9151919416110000084
# Processing interaction_id: 9151919416110000085
# Processing interaction_id: 9151919416110000086
# Processing interaction_id: 9151919416110000087
# Processing interaction_id: 9151919416110000088
# Processing interaction_id: 9151919416110000089
# Processing interaction_id: 9151919416110000093
# Processing interaction_id: 9151919416110000094
# Processing interaction_id: 9151919416110000095
# Processing interaction_id: 9151919416110000096
# Processing interaction_id: 9151919416110000097
# Processing interaction_id: 9151919416110000098
# Processing interaction_id: 9151919416110000099

# %%
df = pd.DataFrame(output_data)
df
# Out:
#          interaction_id                                 option_1  \
# 0   9151919416110000051                              Credit Card
# 1   9151919416110000052                              Credit Card
# 2   9151919416110000053                            ATM/ CDM/ CRM
# 3   9151919416110000054                              Credit Card
# 4   9151919416110000055                              OCTO Mobile
# 5   9151919416110000056                               Debit Card
# 6   9151919416110000057                                      KPR
# 7   9151919416110000058                              Credit Card
# 8   9151919416110000059                              Credit Card
# 9   9151919416110000060                              Credit Card
# 10  9151919416110000061                              Credit Card
# 11  9151919416110000062                              Credit Card
# 12  9151919416110000063                              Credit Card
# 13  9151919416110000064                              Credit Card
# 14  9151919416110000065                                  KTA/ PL
# 15  9151919416110000066                              Credit Card
# 16  9151919416110000067                              Credit Card
# 17  9151919416110000068                                      KPR
# 18  9151919416110000069                              Credit Card
# 19  9151919416110000070                              Credit Card
# 20  9151919416110000071            Credit Card, Credit Protector
# 21  9151919416110000072                              Credit Card
# 22  9151919416110000073                              OCTO Mobile
# 23  9151919416110000074                         Credit Protector
# 24  9151919416110000075  Credit Card, Credit Protector, Asuransi
# 25  9151919416110000076            Credit Card, Credit Protector
# 26  9151919416110000077                         Credit Protector
# 27  9151919416110000078                              Credit Card
# 28  9151919416110000079                              Credit Card
# 29  9151919416110000080                              OCTO Mobile
# 30  9151919416110000081                              OCTO Mobile
# 31  9151919416110000082                              OCTO Mobile
# 32  9151919416110000083                              OCTO Mobile
# 33  9151919416110000084                              OCTO Clicks
# 34  9151919416110000085                              Credit Card
# 35  9151919416110000086                              Credit Card
# 36  9151919416110000087                              Credit Card
# 37  9151919416110000088                              Credit Card
# 38  9151919416110000089                              Credit Card
# 39  9151919416110000093                              Credit Card
# 40  9151919416110000094                              Credit Card
# 41  9151919416110000095                              Credit Card
# 42  9151919416110000096                              Credit Card
# 43  9151919416110000097                              Credit Card
# 44  9151919416110000098                              Credit Card
# 45  9151919416110000099                              Credit Card
#
#                                         explanation_1  \
# 0   Nasabah melaporkan transaksi tarik tunai kartu...
# 1   Nasabah melaporkan transaksi mencurigakan di k...
# 2   Nasabah mengalami kendala dalam melakukan top ...
# 3   Nasabah menanyakan transaksi ganda (double) di...
# 4   Nasabah mengalami kendala login OCTO Mobile se...
# 5   Nasabah menanyakan biaya debit card charges da...
# 6   Nasabah menanyakan sisa tagihan KPR dan inform...
# 7   Nasabah menanyakan sisa limit kartu kredit dan...
# 8   Nasabah menanyakan status pembayaran kartu kre...
# 9   Nasabah menanyakan penghapusan biaya annual fe...
# 10  Nasabah menanyakan status penutupan kartu kred...
# 11  Nasabah komplain pembayaran kartu kredit yang ...
# 12  Nasabah menanyakan dan memprotes tagihan kartu...
# 13  Nasabah menanyakan dan memprotes besarnya dend...
# 14  Nasabah menanyakan detail tunggakan Personal L...
# 15  Nasabah menanyakan keringanan cicilan kartu kr...
# 16  Nasabah menanyakan terkait limit kartu kredit ...
# 17  Nasabah menanyakan progress pengajuan pelunasa...
# 18  Nasabah menanyakan limit dan biaya tahunan kar...
# 19  Nasabah menanyakan cara aktivasi kartu kredit ...
# 20  Nasabah menanyakan tagihan dan biaya administr...
# 21  Nasabah menanyakan simulasi cicilan kartu kred...
# 22  Nasabah menanyakan detail tagihan dan pembayar...
# 23  Nasabah meminta penghapusan Kredit Protekor Ka...
# 24  Nasabah menanyakan dan meminta pembatalan Cred...
# 25  Nasabah menanyakan dan meminta pembatalan Cred...
# 26  Nasabah meminta penghapusan Kredit Proteksi Ka...
# 27  Nasabah menanyakan pengalihan dana kelebihan p...
# 28  Nasabah menanyakan tagihan kartu kredit yang t...
# 29  Nasabah ingin mengaktifkan OCTO Mobile di hand...
# 30  Nasabah mengalami kendala blokir OCTO Mobile k...
# 31  Nasabah mengalami kendala transfer dana melalu...
# 32  Nasabah mengalami kendala transfer dana melalu...
# 33  Nasabah mengalami kendala dengan Octo Clicks, ...
# 34  Nasabah menanyakan minimum payment kartu kredi...
# 35  Nasabah menanyakan detail tagihan kartu kredit...
# 36  Nasabah menanyakan tagihan kartu kredit yang d...
# 37  Nasabah meminta penutupan kartu kredit karena ...
# 38  Nasabah menanyakan sisa limit kartu kredit dan...
# 39  Nasabah mengalami kendala aktivasi kartu kredi...
# 40  Nasabah menanyakan mengenai minimum payment ta...
# 41  Nasabah menanyakan minimum payment dan memprot...
# 42  Nasabah menanyakan kemungkinan mengubah transa...
# 43  Nasabah menanyakan konversi transaksi kartu kr...
# 44  Nasabah meminta pembuatan kartu kredit tambaha...
# 45  Nasabah mengalami kendala dalam verifikasi kod...
#
#                              option_2  \
# 0                                 ATM
# 1                      Contact Center
# 2                         OCTO Mobile
# 3                                QRIS
# 4                         Credit Card
# 5                         OCTO Mobile
# 6                                 KPR
# 7                         Credit Card
# 8                         Credit Card
# 9                                None
# 10                         Collection
# 11                    Fraud Awareness
# 12                        Credit Card
# 13                        Credit Card
# 14                      Personal Loan
# 15                         Collection
# 16                     Contact Center
# 17                                KPR
# 18                        Credit Card
# 19                        Credit Card
# 20                               None
# 21                               None
# 22                         Debit Card
# 23                        Credit Card
# 24                               None
# 25                        Credit Card
# 26                   Credit Protector
# 27                     Contact Center
# 28                      Personal Loan
# 29                Aktivasi CC by Bank
# 30                           OCTO Pay
# 31                     Contact Center
# 32                   Internet Banking
# 33                        OCTO Clicks
# 34                        Credit Card
# 35                        Credit Card
# 36                        Credit Card
# 37                               None
# 38                          Poin Xtra
# 39                        Credit Card
# 40                     Contact Center
# 41                        Credit Card
# 42                          Cash Plus
# 43                        Credit Card
# 44  Contact Center Dok KTP Supplement
# 45                        Credit Card
#
#                                         explanation_2  \
# 0   Permasalahan transaksi terjadi di ATM BNI, seh...
# 1   Nasabah mengalami masalah dengan transaksi kar...
# 2   Masalah utama adalah kegagalan transaksi top u...
# 3   Permasalahan transaksi ganda (double) dilakuka...
# 4   Nasabah mengalami dispute/sanggahan transaksi ...
# 5   Nasabah menanyakan biaya transaksi ATM Bersama...
# 6   Percakapan berfokus pada informasi sisa tagiha...
# 7   Nasabah menggunakan kartu kredit CIMB Niaga da...
# 8   Percakapan berfokus pada verifikasi pembayaran...
# 9                                                None
# 10  Nasabah mengalami masalah dengan penagihan kar...
# 11  Nasabah melaporkan menerima telepon dari nomor...
# 12  Percakapan berfokus pada permasalahan tagihan ...
# 13  Percakapan berfokus pada permasalahan denda da...
# 14  Percakapan berfokus pada penyelesaian masalah ...
# 15  Percakapan berfokus pada permasalahan tagihan ...
# 16  Nasabah melaporkan gangguan jaringan internet ...
# 17  Percakapan berfokus pada keluhan nasabah terka...
# 18  Nasabah menanyakan detail limit kartu kredit u...
# 19  Nasabah menanyakan informasi mengenai limit ka...
# 20                                               None
# 21                                               None
# 22  Nasabah menggunakan autodebet CIMB Niaga untuk...
# 23  Percakapan berfokus pada pembatalan Kredit Pro...
# 24                                               None
# 25  Nasabah melakukan verifikasi PIN dan OTP untuk...
# 26  Percakapan berfokus pada pembatalan Kredit Pro...
# 27  Nasabah menanyakan dan memproses pengalihan da...
# 28  Percakapan berfokus pada permasalahan tagihan ...
# 29  Percakapan berfokus pada aktivasi OCTO Mobile ...
# 30  Nasabah menanyakan cara mengganti sumber dana ...
# 31  Permasalahan transaksi mobile banking yang gag...
# 32  Permasalahan transaksi gagal melalui OCTO Mobi...
# 33  Permasalahan nasabah terkait dengan akses Octo...
# 34  Percakapan berfokus pada masalah pembayaran ka...
# 35  Nasabah mempertanyakan perbedaan antara subtot...
# 36  Percakapan berfokus pada klarifikasi tagihan k...
# 37                                               None
# 38  Nasabah menanyakan dan melakukan penukaran poi...
# 39  Nasabah mengalami transaksi kartu kredit gagal...
# 40  Percakapan berfokus pada permasalahan tagihan ...
# 41  Percakapan berfokus pada permasalahan tagihan ...
# 42  Percakapan berfokus pada transaksi kartu kredi...
# 43  Percakapan berfokus pada perubahan transaksi k...
# 44  Percakapan berfokus pada verifikasi data nasab...
# 45  Nasabah menanyakan dan melakukan aktivasi kart...
#
#                              option_3  \
# 0                      Contact Center
# 1                      Contact Center
# 2                      Contact Center
# 3                      Contact Center
# 4                         Credit Card
# 5                                 ATM
# 6                      Contact Center
# 7                         Credit Card
# 8                      Contact Center
# 9                                None
# 10                         Collection
# 11                     Contact Center
# 12                        Credit Card
# 13                     Contact Center
# 14                                KTA
# 15             Restrukturisasi Kredit
# 16                        Credit Card
# 17                     Contact Center
# 18                        Credit Card
# 19                        Credit Card
# 20                               None
# 21                               None
# 22                                ATM
# 23                           Asuransi
# 24                               None
# 25           Credit Card, OCTO Mobile
# 26                   Credit Protector
# 27                        Credit Card
# 28                   Credit Protector
# 29                     Contact Center
# 30                        OCTO Mobile
# 31                     Contact Center
# 32                        OCTO Mobile
# 33                        OCTO Clicks
# 34                         Collection
# 35                          Poin Xtra
# 36                        Credit Card
# 37                               None
# 38                        Credit Card
# 39                        OCTO Mobile
# 40                            KTA/ PL
# 41                     Contact Center
# 42                     Contact Center
# 43                        Credit Card
# 44  Contact Center Dok KTP Supplement
# 45                Aktivasi CC by Bank
#
#                                         explanation_3
# 0   Nasabah mengajukan pengaduan dan membutuhkan p...
# 1   Nasabah membutuhkan informasi terkait proses p...
# 2   Permasalahan berpusat pada kegagalan transaksi...
# 3   Proses investigasi transaksi ganda pada kartu ...
# 4   Nasabah mempertanyakan mekanisme pembayaran ta...
# 5   Percakapan berfokus pada biaya administrasi ka...
# 6   Nasabah menanyakan informasi detail KPR melalu...
# 7   Percakapan berfokus pada penggunaan dan pengel...
# 8   Nasabah mengalami kendala terkait update saldo...
# 9                                                None
# 10  Nasabah menanyakan detail tagihan kartu kredit...
# 11  Nasabah meminta investigasi terhadap nomor tel...
# 12  Nasabah menanyakan detail tagihan kartu kredit...
# 13  Nasabah melakukan complain terkait besarnya bi...
# 14  Nasabah mengalami kendala pembayaran KTA dan m...
# 15  Agen membantu nasabah dalam proses pengajuan k...
# 16  Nasabah menanyakan dan melaporkan masalah terk...
# 17  Nasabah menghubungi contact center CIMB Niaga ...
# 18  Nasabah menanyakan jatuh tempo tagihan kartu k...
# 19  Nasabah melakukan konfirmasi data dan menanyak...
# 20                                               None
# 21                                               None
# 22  Percakapan berfokus pada klarifikasi tagihan d...
# 23  Nasabah menghubungi contact center untuk pemba...
# 24                                               None
# 25  Nasabah menanyakan sisa limit kartu kredit dan...
# 26  Nasabah menanyakan informasi terkait Kredit Pr...
# 27  Nasabah menanyakan dan meminta penghapusan bia...
# 28  Nasabah menanyakan detail angsuran pinjaman di...
# 29  Nasabah mengalami kendala aktivasi OCTO Mobile...
# 30  Nasabah menanyakan cara mengganti PIN OCTO Mob...
# 31  Agen melakukan panduan dan troubleshooting mas...
# 32  Nasabah meminta panduan penggunaan OCTO Mobile...
# 33  Agen melakukan verifikasi data nasabah untuk m...
# 34  Nasabah mengalami kesulitan pembayaran kartu k...
# 35  Nasabah menanyakan informasi mengenai poin rew...
# 36  Agen dan supervisor membahas masalah tagihan k...
# 37                                               None
# 38  Nasabah menanyakan persyaratan kenaikan limit ...
# 39  Nasabah mengalami masalah dengan aktivasi kart...
# 40  Nasabah mempertanyakan ketidakkonsistenan info...
# 41  Nasabah mempertanyakan mekanisme pembayaran mi...
# 42  Nasabah membutuhkan informasi terkait biaya ta...
# 43  Proses verifikasi dan konfirmasi perubahan tra...
# 44  Proses pengajuan kartu kredit tambahan membutu...
# 45  Percakapan membahas tentang  masalah teknis te...

# %% [markdown]
# # Combine data with ground truth

# %%
# read json file
import json

with open('./ground_truth/ground_truth.json') as f:
    ground_truth = json.load(f)

# map with ground truth
df['interaction_id'] = df['interaction_id'].astype(str)
df['ground_truth'] = df['interaction_id'].map(ground_truth)

# save to csv
df.to_csv('output.csv', index=False)

# %% [markdown]
# # Read the output.csv file

# %%
df = pd.read_csv('output.csv')

# check whether option_1 is equal to ground_truth, the result is True or False in "is_match" column
df['is_match'] = df['ground_truth'] == df['option_1']

df_view = df[['interaction_id', 'option_1', 'ground_truth', 'is_match']]
df_view
# Out:
#          interaction_id                                 option_1 ground_truth  \
# 0   9151919416110000051                              Credit Card          ATM
# 1   9151919416110000052                              Credit Card  Credit Card
# 2   9151919416110000053                            ATM/ CDM/ CRM  OCTO Mobile
# 3   9151919416110000054                              Credit Card  Credit Card
# 4   9151919416110000055                              OCTO Mobile  OCTO Mobile
# 5   9151919416110000056                               Debit Card     Tabungan
# 6   9151919416110000057                                      KPR          KPR
# 7   9151919416110000058                              Credit Card  Credit Card
# 8   9151919416110000059                              Credit Card  Credit Card
# 9   9151919416110000060                              Credit Card          NaN
# 10  9151919416110000061                              Credit Card  Credit Card
# 11  9151919416110000062                              Credit Card    Telesales
# 12  9151919416110000063                              Credit Card  Credit Card
# 13  9151919416110000064                              Credit Card  Credit Card
# 14  9151919416110000065                                  KTA/ PL      KTA/ PL
# 15  9151919416110000066                              Credit Card   Collection
# 16  9151919416110000067                              Credit Card  Credit Card
# 17  9151919416110000068                                      KPR          KPR
# 18  9151919416110000069                              Credit Card  Credit Card
# 19  9151919416110000070                              Credit Card          NaN
# 20  9151919416110000071            Credit Card, Credit Protector  Credit Card
# 21  9151919416110000072                              Credit Card  Credit Card
# 22  9151919416110000073                              OCTO Mobile  Credit Card
# 23  9151919416110000074                         Credit Protector  Credit Card
# 24  9151919416110000075  Credit Card, Credit Protector, Asuransi  Credit Card
# 25  9151919416110000076            Credit Card, Credit Protector  Credit Card
# 26  9151919416110000077                         Credit Protector          NaN
# 27  9151919416110000078                              Credit Card  Credit Card
# 28  9151919416110000079                              Credit Card  Credit Card
# 29  9151919416110000080                              OCTO Mobile  OCTO Mobile
# 30  9151919416110000081                              OCTO Mobile          NaN
# 31  9151919416110000082                              OCTO Mobile  OCTO Mobile
# 32  9151919416110000083                              OCTO Mobile  OCTO Clicks
# 33  9151919416110000084                              OCTO Clicks  OCTO Clicks
# 34  9151919416110000085                              Credit Card  Credit Card
# 35  9151919416110000086                              Credit Card  Credit Card
# 36  9151919416110000087                              Credit Card  Credit Card
# 37  9151919416110000088                              Credit Card  Credit Card
# 38  9151919416110000089                              Credit Card    Poin Xtra
# 39  9151919416110000093                              Credit Card  Credit Card
# 40  9151919416110000094                              Credit Card          NaN
# 41  9151919416110000095                              Credit Card          NaN
# 42  9151919416110000096                              Credit Card  Credit Card
# 43  9151919416110000097                              Credit Card          NaN
# 44  9151919416110000098                              Credit Card          NaN
# 45  9151919416110000099                              Credit Card  Credit Card
#
#     is_match
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
# 5      False
# 6       True
# 7       True
# 8       True
# 9      False
# 10      True
# 11     False
# 12      True
# 13      True
# 14      True
# 15     False
# 16      True
# 17      True
# 18      True
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27      True
# 28      True
# 29      True
# 30     False
# 31      True
# 32     False
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38     False
# 39      True
# 40     False
# 41     False
# 42      True
# 43     False
# 44     False
# 45      True

# %% [markdown]
# # CALCULATE ACCURACY

# %%
# calculate the mean of "is_match" column where ground_truth is not NaN
accuracy = df[df['ground_truth'].notnull()]['is_match'].mean()
accuracy
# Out:
# np.float64(0.6842105263157895)

# %%
df
# Out:
#          interaction_id                                 option_1  \
# 0   9151919416110000051                              Credit Card
# 1   9151919416110000052                              Credit Card
# 2   9151919416110000053                            ATM/ CDM/ CRM
# 3   9151919416110000054                              Credit Card
# 4   9151919416110000055                              OCTO Mobile
# 5   9151919416110000056                               Debit Card
# 6   9151919416110000057                                      KPR
# 7   9151919416110000058                              Credit Card
# 8   9151919416110000059                              Credit Card
# 9   9151919416110000060                              Credit Card
# 10  9151919416110000061                              Credit Card
# 11  9151919416110000062                              Credit Card
# 12  9151919416110000063                              Credit Card
# 13  9151919416110000064                              Credit Card
# 14  9151919416110000065                                  KTA/ PL
# 15  9151919416110000066                              Credit Card
# 16  9151919416110000067                              Credit Card
# 17  9151919416110000068                                      KPR
# 18  9151919416110000069                              Credit Card
# 19  9151919416110000070                              Credit Card
# 20  9151919416110000071            Credit Card, Credit Protector
# 21  9151919416110000072                              Credit Card
# 22  9151919416110000073                              OCTO Mobile
# 23  9151919416110000074                         Credit Protector
# 24  9151919416110000075  Credit Card, Credit Protector, Asuransi
# 25  9151919416110000076            Credit Card, Credit Protector
# 26  9151919416110000077                         Credit Protector
# 27  9151919416110000078                              Credit Card
# 28  9151919416110000079                              Credit Card
# 29  9151919416110000080                              OCTO Mobile
# 30  9151919416110000081                              OCTO Mobile
# 31  9151919416110000082                              OCTO Mobile
# 32  9151919416110000083                              OCTO Mobile
# 33  9151919416110000084                              OCTO Clicks
# 34  9151919416110000085                              Credit Card
# 35  9151919416110000086                              Credit Card
# 36  9151919416110000087                              Credit Card
# 37  9151919416110000088                              Credit Card
# 38  9151919416110000089                              Credit Card
# 39  9151919416110000093                              Credit Card
# 40  9151919416110000094                              Credit Card
# 41  9151919416110000095                              Credit Card
# 42  9151919416110000096                              Credit Card
# 43  9151919416110000097                              Credit Card
# 44  9151919416110000098                              Credit Card
# 45  9151919416110000099                              Credit Card
#
#                                         explanation_1  \
# 0   Nasabah melaporkan transaksi tarik tunai kartu...
# 1   Nasabah melaporkan transaksi mencurigakan di k...
# 2   Nasabah mengalami kendala dalam melakukan top ...
# 3   Nasabah menanyakan transaksi ganda (double) di...
# 4   Nasabah mengalami kendala login OCTO Mobile se...
# 5   Nasabah menanyakan biaya debit card charges da...
# 6   Nasabah menanyakan sisa tagihan KPR dan inform...
# 7   Nasabah menanyakan sisa limit kartu kredit dan...
# 8   Nasabah menanyakan status pembayaran kartu kre...
# 9   Nasabah menanyakan penghapusan biaya annual fe...
# 10  Nasabah menanyakan status penutupan kartu kred...
# 11  Nasabah komplain pembayaran kartu kredit yang ...
# 12  Nasabah menanyakan dan memprotes tagihan kartu...
# 13  Nasabah menanyakan dan memprotes besarnya dend...
# 14  Nasabah menanyakan detail tunggakan Personal L...
# 15  Nasabah menanyakan keringanan cicilan kartu kr...
# 16  Nasabah menanyakan terkait limit kartu kredit ...
# 17  Nasabah menanyakan progress pengajuan pelunasa...
# 18  Nasabah menanyakan limit dan biaya tahunan kar...
# 19  Nasabah menanyakan cara aktivasi kartu kredit ...
# 20  Nasabah menanyakan tagihan dan biaya administr...
# 21  Nasabah menanyakan simulasi cicilan kartu kred...
# 22  Nasabah menanyakan detail tagihan dan pembayar...
# 23  Nasabah meminta penghapusan Kredit Protekor Ka...
# 24  Nasabah menanyakan dan meminta pembatalan Cred...
# 25  Nasabah menanyakan dan meminta pembatalan Cred...
# 26  Nasabah meminta penghapusan Kredit Proteksi Ka...
# 27  Nasabah menanyakan pengalihan dana kelebihan p...
# 28  Nasabah menanyakan tagihan kartu kredit yang t...
# 29  Nasabah ingin mengaktifkan OCTO Mobile di hand...
# 30  Nasabah mengalami kendala blokir OCTO Mobile k...
# 31  Nasabah mengalami kendala transfer dana melalu...
# 32  Nasabah mengalami kendala transfer dana melalu...
# 33  Nasabah mengalami kendala dengan Octo Clicks, ...
# 34  Nasabah menanyakan minimum payment kartu kredi...
# 35  Nasabah menanyakan detail tagihan kartu kredit...
# 36  Nasabah menanyakan tagihan kartu kredit yang d...
# 37  Nasabah meminta penutupan kartu kredit karena ...
# 38  Nasabah menanyakan sisa limit kartu kredit dan...
# 39  Nasabah mengalami kendala aktivasi kartu kredi...
# 40  Nasabah menanyakan mengenai minimum payment ta...
# 41  Nasabah menanyakan minimum payment dan memprot...
# 42  Nasabah menanyakan kemungkinan mengubah transa...
# 43  Nasabah menanyakan konversi transaksi kartu kr...
# 44  Nasabah meminta pembuatan kartu kredit tambaha...
# 45  Nasabah mengalami kendala dalam verifikasi kod...
#
#                              option_2  \
# 0                                 ATM
# 1                      Contact Center
# 2                         OCTO Mobile
# 3                                QRIS
# 4                         Credit Card
# 5                         OCTO Mobile
# 6                                 KPR
# 7                         Credit Card
# 8                         Credit Card
# 9                                 NaN
# 10                         Collection
# 11                    Fraud Awareness
# 12                        Credit Card
# 13                        Credit Card
# 14                      Personal Loan
# 15                         Collection
# 16                     Contact Center
# 17                                KPR
# 18                        Credit Card
# 19                        Credit Card
# 20                                NaN
# 21                                NaN
# 22                         Debit Card
# 23                        Credit Card
# 24                                NaN
# 25                        Credit Card
# 26                   Credit Protector
# 27                     Contact Center
# 28                      Personal Loan
# 29                Aktivasi CC by Bank
# 30                           OCTO Pay
# 31                     Contact Center
# 32                   Internet Banking
# 33                        OCTO Clicks
# 34                        Credit Card
# 35                        Credit Card
# 36                        Credit Card
# 37                                NaN
# 38                          Poin Xtra
# 39                        Credit Card
# 40                     Contact Center
# 41                        Credit Card
# 42                          Cash Plus
# 43                        Credit Card
# 44  Contact Center Dok KTP Supplement
# 45                        Credit Card
#
#                                         explanation_2  \
# 0   Permasalahan transaksi terjadi di ATM BNI, seh...
# 1   Nasabah mengalami masalah dengan transaksi kar...
# 2   Masalah utama adalah kegagalan transaksi top u...
# 3   Permasalahan transaksi ganda (double) dilakuka...
# 4   Nasabah mengalami dispute/sanggahan transaksi ...
# 5   Nasabah menanyakan biaya transaksi ATM Bersama...
# 6   Percakapan berfokus pada informasi sisa tagiha...
# 7   Nasabah menggunakan kartu kredit CIMB Niaga da...
# 8   Percakapan berfokus pada verifikasi pembayaran...
# 9                                                 NaN
# 10  Nasabah mengalami masalah dengan penagihan kar...
# 11  Nasabah melaporkan menerima telepon dari nomor...
# 12  Percakapan berfokus pada permasalahan tagihan ...
# 13  Percakapan berfokus pada permasalahan denda da...
# 14  Percakapan berfokus pada penyelesaian masalah ...
# 15  Percakapan berfokus pada permasalahan tagihan ...
# 16  Nasabah melaporkan gangguan jaringan internet ...
# 17  Percakapan berfokus pada keluhan nasabah terka...
# 18  Nasabah menanyakan detail limit kartu kredit u...
# 19  Nasabah menanyakan informasi mengenai limit ka...
# 20                                                NaN
# 21                                                NaN
# 22  Nasabah menggunakan autodebet CIMB Niaga untuk...
# 23  Percakapan berfokus pada pembatalan Kredit Pro...
# 24                                                NaN
# 25  Nasabah melakukan verifikasi PIN dan OTP untuk...
# 26  Percakapan berfokus pada pembatalan Kredit Pro...
# 27  Nasabah menanyakan dan memproses pengalihan da...
# 28  Percakapan berfokus pada permasalahan tagihan ...
# 29  Percakapan berfokus pada aktivasi OCTO Mobile ...
# 30  Nasabah menanyakan cara mengganti sumber dana ...
# 31  Permasalahan transaksi mobile banking yang gag...
# 32  Permasalahan transaksi gagal melalui OCTO Mobi...
# 33  Permasalahan nasabah terkait dengan akses Octo...
# 34  Percakapan berfokus pada masalah pembayaran ka...
# 35  Nasabah mempertanyakan perbedaan antara subtot...
# 36  Percakapan berfokus pada klarifikasi tagihan k...
# 37                                                NaN
# 38  Nasabah menanyakan dan melakukan penukaran poi...
# 39  Nasabah mengalami transaksi kartu kredit gagal...
# 40  Percakapan berfokus pada permasalahan tagihan ...
# 41  Percakapan berfokus pada permasalahan tagihan ...
# 42  Percakapan berfokus pada transaksi kartu kredi...
# 43  Percakapan berfokus pada perubahan transaksi k...
# 44  Percakapan berfokus pada verifikasi data nasab...
# 45  Nasabah menanyakan dan melakukan aktivasi kart...
#
#                              option_3  \
# 0                      Contact Center
# 1                      Contact Center
# 2                      Contact Center
# 3                      Contact Center
# 4                         Credit Card
# 5                                 ATM
# 6                      Contact Center
# 7                         Credit Card
# 8                      Contact Center
# 9                                 NaN
# 10                         Collection
# 11                     Contact Center
# 12                        Credit Card
# 13                     Contact Center
# 14                                KTA
# 15             Restrukturisasi Kredit
# 16                        Credit Card
# 17                     Contact Center
# 18                        Credit Card
# 19                        Credit Card
# 20                                NaN
# 21                                NaN
# 22                                ATM
# 23                           Asuransi
# 24                                NaN
# 25           Credit Card, OCTO Mobile
# 26                   Credit Protector
# 27                        Credit Card
# 28                   Credit Protector
# 29                     Contact Center
# 30                        OCTO Mobile
# 31                     Contact Center
# 32                        OCTO Mobile
# 33                        OCTO Clicks
# 34                         Collection
# 35                          Poin Xtra
# 36                        Credit Card
# 37                                NaN
# 38                        Credit Card
# 39                        OCTO Mobile
# 40                            KTA/ PL
# 41                     Contact Center
# 42                     Contact Center
# 43                        Credit Card
# 44  Contact Center Dok KTP Supplement
# 45                Aktivasi CC by Bank
#
#                                         explanation_3 ground_truth  is_match
# 0   Nasabah mengajukan pengaduan dan membutuhkan p...          ATM      True
# 1   Nasabah membutuhkan informasi terkait proses p...  Credit Card      True
# 2   Permasalahan berpusat pada kegagalan transaksi...  OCTO Mobile      True
# 3   Proses investigasi transaksi ganda pada kartu ...  Credit Card      True
# 4   Nasabah mempertanyakan mekanisme pembayaran ta...  OCTO Mobile      True
# 5   Percakapan berfokus pada biaya administrasi ka...     Tabungan     False
# 6   Nasabah menanyakan informasi detail KPR melalu...          KPR      True
# 7   Percakapan berfokus pada penggunaan dan pengel...  Credit Card      True
# 8   Nasabah mengalami kendala terkait update saldo...  Credit Card      True
# 9                                                 NaN          NaN     False
# 10  Nasabah menanyakan detail tagihan kartu kredit...  Credit Card      True
# 11  Nasabah meminta investigasi terhadap nomor tel...    Telesales     False
# 12  Nasabah menanyakan detail tagihan kartu kredit...  Credit Card      True
# 13  Nasabah melakukan complain terkait besarnya bi...  Credit Card      True
# 14  Nasabah mengalami kendala pembayaran KTA dan m...      KTA/ PL      True
# 15  Agen membantu nasabah dalam proses pengajuan k...   Collection      True
# 16  Nasabah menanyakan dan melaporkan masalah terk...  Credit Card      True
# 17  Nasabah menghubungi contact center CIMB Niaga ...          KPR      True
# 18  Nasabah menanyakan jatuh tempo tagihan kartu k...  Credit Card      True
# 19  Nasabah melakukan konfirmasi data dan menanyak...          NaN     False
# 20                                                NaN  Credit Card      True
# 21                                                NaN  Credit Card      True
# 22  Percakapan berfokus pada klarifikasi tagihan d...  Credit Card      True
# 23  Nasabah menghubungi contact center untuk pemba...  Credit Card      True
# 24                                                NaN  Credit Card      True
# 25  Nasabah menanyakan sisa limit kartu kredit dan...  Credit Card      True
# 26  Nasabah menanyakan informasi terkait Kredit Pr...          NaN     False
# 27  Nasabah menanyakan dan meminta penghapusan bia...  Credit Card      True
# 28  Nasabah menanyakan detail angsuran pinjaman di...  Credit Card      True
# 29  Nasabah mengalami kendala aktivasi OCTO Mobile...  OCTO Mobile      True
# 30  Nasabah menanyakan cara mengganti PIN OCTO Mob...          NaN     False
# 31  Agen melakukan panduan dan troubleshooting mas...  OCTO Mobile      True
# 32  Nasabah meminta panduan penggunaan OCTO Mobile...  OCTO Clicks      True
# 33  Agen melakukan verifikasi data nasabah untuk m...  OCTO Clicks      True
# 34  Nasabah mengalami kesulitan pembayaran kartu k...  Credit Card      True
# 35  Nasabah menanyakan informasi mengenai poin rew...  Credit Card      True
# 36  Agen dan supervisor membahas masalah tagihan k...  Credit Card      True
# 37                                                NaN  Credit Card      True
# 38  Nasabah menanyakan persyaratan kenaikan limit ...    Poin Xtra      True
# 39  Nasabah mengalami masalah dengan aktivasi kart...  Credit Card      True
# 40  Nasabah mempertanyakan ketidakkonsistenan info...          NaN     False
# 41  Nasabah mempertanyakan mekanisme pembayaran mi...          NaN     False
# 42  Nasabah membutuhkan informasi terkait biaya ta...  Credit Card      True
# 43  Proses verifikasi dan konfirmasi perubahan tra...          NaN     False
# 44  Proses pengajuan kartu kredit tambahan membutu...          NaN     False
# 45  Percakapan membahas tentang  masalah teknis te...  Credit Card      True
