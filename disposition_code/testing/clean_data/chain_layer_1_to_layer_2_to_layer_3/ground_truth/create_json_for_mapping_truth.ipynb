# %%
import pandas as pd

# import the data from excell with sheet name 'ground_truth'
ground_truth = pd.read_excel('Disposition Code Testing.xlsx', sheet_name='ground_truth')
view_ground_truth = ground_truth[['interaction_id_edit', 'CleanGroundTruth']]
view_ground_truth
# Out:
#      interaction_id_edit                                   CleanGroundTruth
# 0   9151919416110000051'                           Complain|ATM|Gagal Tarik
# 1   9151919416110000052'           Complain|Credit Card|Sanggahan Transaksi
# 2   9151919416110000053'             Complain|OCTO Mobile|Kendala Transaksi
# 3   9151919416110000054'           Complain|Credit Card|Sanggahan Transaksi
# 4   9151919416110000055'                 Complain|OCTO Mobile|Kendala Login
# 5   9151919416110000056'                             Inquiry|Tabungan|Other
# 6   9151919416110000057'                                  Inquiry|KPR|Other
# 7   9151919416110000058'                          Inquiry|Credit Card|Limit
# 8   9151919416110000059'  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 9   9151919416110000060'                                                NaN
# 10  9151919416110000061'               Complain|Credit Card|Penutupan Kartu
# 11  9151919416110000062'          Complain|Telesales|Penawaran Tidak Sesuai
# 12  9151919416110000063'           Complain|Credit Card|Biaya/ Bunga/ Denda
# 13  9151919416110000064'           Complain|Credit Card|Biaya/ Bunga/ Denda
# 14  9151919416110000065'    Complain|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 15  9151919416110000066'                 Complain|Collection|Cara Penagihan
# 16  9151919416110000067'  Complain|Credit Card|Pembayaran Tagihan Credit...
# 17  9151919416110000068'                 Complain|KPR|Pelunasan Keseluruhan
# 18  9151919416110000069'                          Inquiry|Credit Card|Fitur
# 19  9151919416110000070'                                                NaN
# 20  9151919416110000071'           Complain|Credit Card|Biaya/ Bunga/ Denda
# 21  9151919416110000072'  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 22  9151919416110000073'  Complain|Credit Card|Pembayaran Tagihan Credit...
# 23  9151919416110000074'              Complain|Credit Card|Credit Protector
# 24  9151919416110000075'              Complain|Credit Card|Credit Protector
# 25  9151919416110000076'               Request|Credit Card|Credit Protector
# 26  9151919416110000078'               Request|Credit Card|Reversal Payment
# 27  9151919416110000079'  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...
# 28  9151919416110000080'                    Complain|OCTO Mobile|Registrasi
# 29  9151919416110000081'                                                NaN
# 30  9151919416110000082'             Complain|OCTO Mobile|Kendala Transaksi
# 31  9151919416110000083'                 Complain|OCTO Clicks|Kendala Login
# 32  9151919416110000084'             Complain|OCTO Clicks|Kendala Transaksi
# 33  9151919416110000085'  Complain|Credit Card|Pembayaran Tagihan Credit...
# 34  9151919416110000086'  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 35  9151919416110000087'  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 36  9151919416110000088'                Request|Credit Card|Penutupan Kartu
# 37  9151919416110000089'                            Request|Poin Xtra|Other
# 38  9151919416110000090'            Request|Credit Card|Blokir/ Buka Blokir
# 39  9151919416110000091'                       Complain|Credit Card|Tagihan
# 40  9151919416110000092'             Complain|Credit Card|Kirim Ulang Kartu
# 41  9151919416110000093'              Complain|Credit Card|Aktivasi dan PIN
# 42  9151919416110000094'                                                NaN
# 43  9151919416110000095'                                                NaN
# 44  9151919416110000096'  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 45  9151919416110000097'                                                NaN
# 46  9151919416110000098'                                                NaN
# 47  9151919416110000099'  Request|Credit Card|Pendaftaran dan Pembatalan...
# 48  9151919416110000100'                                                NaN

# %% [markdown]
# # CREATE GROUND TRUTH JSON FILE

# %%
import json

# filter df, to only show interaction_id_edit and GroundTruth columns
ground_truth = ground_truth[['interaction_id_edit', 'CleanGroundTruth']]
# create a json with the interaction_id_edit as key and GroundTruth as value
ground_truth = ground_truth.set_index('interaction_id_edit').to_dict()['CleanGroundTruth']
# remove all last char from they key
ground_truth = {k[:-1]: v for k, v in ground_truth.items()}

# export this to json file, please add new line for better view
with open('ground_truth.json', 'w') as f:
    json.dump(ground_truth, f, indent=4)

# %% [markdown]
# # TEST JSON FILE

# %%
# load json file
with open('ground_truth.json', 'r') as f:
    data = json.load(f)

data
# Out:
# {'9151919416110000051': 'Complain|ATM|Gagal Tarik',
#  '9151919416110000052': 'Complain|Credit Card|Sanggahan Transaksi',
#  '9151919416110000053': 'Complain|OCTO Mobile|Kendala Transaksi',
#  '9151919416110000054': 'Complain|Credit Card|Sanggahan Transaksi',
#  '9151919416110000055': 'Complain|OCTO Mobile|Kendala Login',
#  '9151919416110000056': 'Inquiry|Tabungan|Other',
#  '9151919416110000057': 'Inquiry|KPR|Other',
#  '9151919416110000058': 'Inquiry|Credit Card|Limit',
#  '9151919416110000059': 'Inquiry|Credit Card|Pembayaran Tagihan Credit Card',
#  '9151919416110000060': nan,
#  '9151919416110000061': 'Complain|Credit Card|Penutupan Kartu',
#  '9151919416110000062': 'Complain|Telesales|Penawaran Tidak Sesuai',
#  '9151919416110000063': 'Complain|Credit Card|Biaya/ Bunga/ Denda',
#  '9151919416110000064': 'Complain|Credit Card|Biaya/ Bunga/ Denda',
#  '9151919416110000065': 'Complain|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)',
#  '9151919416110000066': 'Complain|Collection|Cara Penagihan',
#  '9151919416110000067': 'Complain|Credit Card|Pembayaran Tagihan Credit Card',
#  '9151919416110000068': 'Complain|KPR|Pelunasan Keseluruhan',
#  '9151919416110000069': 'Inquiry|Credit Card|Fitur',
#  '9151919416110000070': nan,
#  '9151919416110000071': 'Complain|Credit Card|Biaya/ Bunga/ Denda',
#  '9151919416110000072': 'Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Tenor)',
#  '9151919416110000073': 'Complain|Credit Card|Pembayaran Tagihan Credit Card',
#  '9151919416110000074': 'Complain|Credit Card|Credit Protector',
#  '9151919416110000075': 'Complain|Credit Card|Credit Protector',
#  '9151919416110000076': 'Request|Credit Card|Credit Protector',
#  '9151919416110000078': 'Request|Credit Card|Reversal Payment',
#  '9151919416110000079': 'Complain|Credit Card|Cicilan (Bunga/ Jumlah/ Tenor)',
#  '9151919416110000080': 'Complain|OCTO Mobile|Registrasi',
#  '9151919416110000081': nan,
#  '9151919416110000082': 'Complain|OCTO Mobile|Kendala Transaksi',
#  '9151919416110000083': 'Complain|OCTO Clicks|Kendala Login',
#  '9151919416110000084': 'Complain|OCTO Clicks|Kendala Transaksi',
#  '9151919416110000085': 'Complain|Credit Card|Pembayaran Tagihan Credit Card',
#  '9151919416110000086': 'Complain|Credit Card|Tagihan (Tidak Terima/ Selisih)',
#  '9151919416110000087': 'Complain|Credit Card|Tagihan (Tidak Terima/ Selisih)',
#  '9151919416110000088': 'Request|Credit Card|Penutupan Kartu',
#  '9151919416110000089': 'Request|Poin Xtra|Other',
#  '9151919416110000090': 'Request|Credit Card|Blokir/ Buka Blokir',
#  '9151919416110000091': 'Complain|Credit Card|Tagihan',
#  '9151919416110000092': 'Complain|Credit Card|Kirim Ulang Kartu',
#  '9151919416110000093': 'Complain|Credit Card|Aktivasi dan PIN',
#  '9151919416110000094': nan,
#  '9151919416110000095': nan,
#  '9151919416110000096': 'Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Tenor)',
#  '9151919416110000097': nan,
#  '9151919416110000098': nan,
#  '9151919416110000099': 'Request|Credit Card|Pendaftaran dan Pembatalan E-Statement',
#  '9151919416110000100': nan}
