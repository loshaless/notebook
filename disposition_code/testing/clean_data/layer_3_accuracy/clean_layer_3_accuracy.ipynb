# %% [markdown]
# # FUNCTION

# %%
import pandas as pd
from io import StringIO
from google.cloud import storage
import requests
from vertexai.generative_models import (
    GenerativeModel,
    GenerationConfig,
    HarmCategory,
    HarmBlockThreshold
)

def load_transcription_csv(bucket_name, file_path):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(file_path)
    content = blob.download_as_text()

    return pd.read_csv(StringIO(content))[['speaker', 'transcript']]

def get_prompt(**kwargs):
    with open('./prompt/disposition_code_cleaned_layer_3.txt', 'r') as file:
        prompt_template = file.read()

    return prompt_template.format(**kwargs)

def generate_prompt(bucket_name, file_path, interaction_id: str, list_of_option):
    transcript_df = load_transcription_csv(bucket_name,f"{file_path}/transcription/{interaction_id}/transcription_results.csv")
    transcript_df = transcript_df.where(pd.notnull(transcript_df), '')
    json_dict = transcript_df.to_dict(orient='records')

    prompt = get_prompt(
        transcript=json_dict,
        conversational_context=','.join(list_of_option),
    )
    return prompt

# %%
text = load_transcription_csv('athena-nonprod-gcs', 'athena-ws4a/athena-qapm/transcription/9151919416110000100/transcription_results.csv')

json_dict = text.to_dict(orient='records')
json_dict
# Out:
# [{'speaker': 'Agent',
#   'transcript': 'Selamat sore dengan Echo, bagaimana saya bisa membantu?'},
#  {'speaker': 'Customer',
#   'transcript': 'Iya, Mas, mau tanya. Kalau untuk eh kartu kredit Platinum Mastercard, itu limitnya berapa ya?'},
#  {'speaker': 'Agent',
#   'transcript': 'Baik. Untuk minimal limitnya atau bagaimana, Bu?'},
#  {'speaker': 'Customer',
#   'transcript': 'Eh, kalau saya mau tahu kartu saya limitnya berapa, gimana?'},
#  {'speaker': 'Agent',
#   'transcript': 'Baik. Dikarenakan untuk limit total, itu tidak dapat saya informasikan. Eh, itu dikarenakan bagian dari verifikasi. Ibu dapat melakukan pengecekannya melalui lembar tagihan, Ibu.'},
#  {'speaker': 'Customer', 'transcript': 'Lembar tagihan.'},
#  {'speaker': 'Agent',
#   'transcript': 'Benar. Di lembar tagihan, e-statement itu di bagian paling atas ada available credit-nya, Bu.'},
#  {'speaker': 'Customer',
#   'transcript': 'Enggak, enggak. Kan itu di email, enggak? Iya. Soalnya udah udah lama enggak di email tuh. Udah lama enggak dapat email ya.'},
#  {'speaker': 'Agent', 'transcript': 'Baik. Kemudian Ibu juga dapat'},
#  {'speaker': 'Customer',
#   'transcript': 'eh bisa eh melakukan pengecekannya melalui oto mobile juga Bu'},
#  {'speaker': 'Agent', 'transcript': 'Oto mobile'},
#  {'speaker': 'Customer', 'transcript': 'Benar'},
#  {'speaker': 'Agent', 'transcript': 'Mobile mobile banking ya'},
#  {'speaker': 'Customer', 'transcript': 'Benar mobile banking dari CIMB ya'},
#  {'speaker': 'Agent',
#   'transcript': 'Oh saya enggak saya enggak daftar mobile banking'},
#  {'speaker': 'Agent', 'transcript': 'Baik'},
#  {'speaker': 'Agent',
#   'transcript': 'Dikarenakan untuk terkait dari limit total itu tidak dapat saya informasikan Ibu yang bisa saya informasikan itu eh untuk sisa limit Ibu saja seperti itu'},
#  {'speaker': 'Customer', 'transcript': 'Oh ya sudah berapa sisa limitnya Mas'},
#  {'speaker': 'Agent', 'transcript': 'Baik nomor kartunya bisa disebutkan'},
#  {'speaker': 'Customer', 'transcript': '5289'},
#  {'speaker': 'Agent', 'transcript': 'Iya'},
#  {'speaker': 'Customer', 'transcript': '1900'},
#  {'speaker': 'Agent', 'transcript': 'Baik'},
#  {'speaker': 'Customer', 'transcript': '0612'},
#  {'speaker': 'Agent', 'transcript': 'Iya'},
#  {'speaker': 'Customer', 'transcript': '3277'},
#  {'speaker': 'Agent',
#   'transcript': 'Untuk kartunya sudah dilengkapi dilengkapi Bu'},
#  {'speaker': 'Customer',
#   'transcript': 'Oh belum kayaknya sih kayaknya belum deh'},
#  {'speaker': 'Agent', 'transcript': 'Hah'},
#  {'speaker': 'Agent', 'transcript': 'Baik'},
#  {'speaker': 'Agent',
#   'transcript': 'Mohon ditunggu sebentar saya lakukan pengecekannya'},
#  {'speaker': 'Customer', 'transcript': 'Oke'},
#  {'speaker': 'Customer', 'transcript': 'Oke'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Customer', 'transcript': 'Se moment lagi ya Mas'},
#  {'speaker': 'Customer', 'transcript': 'Hmm, limitnya berapa sih?'},
#  {'speaker': 'Agent',
#   'transcript': 'Untuk pembukaan datanya akan saya tanyakan beberapa hal terlebih dahulu ya Bu?'},
#  {'speaker': 'Customer', 'transcript': 'Oke'},
#  {'speaker': 'Agent', 'transcript': 'Untuk nama Ibu kandung?'},
#  {'speaker': 'Customer', 'transcript': 'Sri Rohana'},
#  {'speaker': 'Agent', 'transcript': 'Untuk tanggal lahir Ibu?'},
#  {'speaker': 'Customer', 'transcript': '21 11 64'},
#  {'speaker': 'Agent',
#   'transcript': 'Kemudian untuk nomor handphone Ibu yang terdaftar?'},
#  {'speaker': 'Customer', 'transcript': '0812 8870 83'},
#  {'speaker': 'Agent',
#   'transcript': 'Kemudian untuk pembayaran tagihan Ibu, apakah terdaftar menggunakan fasilitas auto debet dari rekening CIMB Niaga ya?'},
#  {'speaker': 'Customer', 'transcript': 'Iya betul'},
#  {'speaker': 'Agent',
#   'transcript': 'Baik, terima kasih Ibu untuk verifikasinya sudah sesuai.'},
#  {'speaker': 'Customer', 'transcript': 'Iya'},
#  {'speaker': 'Agent',
#   'transcript': 'Saya lakukan pengecekan untuk sisa limitnya terlebih dahulu mohon ditunggu sebentar ya Bu ya.'},
#  {'speaker': 'Customer', 'transcript': 'Oke'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Agent',
#   'transcript': 'Baik, untuk sisa limit Ibu saat ini yaitu di nominal 49 juta 8'},
#  {'speaker': 'Customer', 'transcript': '1088.768'},
#  {'speaker': 'Agent',
#   'transcript': 'Oh oke oke. Eh terus eh mau ini lagi dong Mas. Kan saya kan auto debet kan ya? Baik.'},
#  {'speaker': 'Customer',
#   'transcript': 'Auto debetnya bisa diganti ke ini enggak? Full payment gitu enggak? 100% gitu.'},
#  {'speaker': 'Agent',
#   'transcript': 'Baik Ibu. Itu bisa saya lakukan pelaporannya. Saya lanjutkan untuk pelaporannya ya Bu.'},
#  {'speaker': 'Agent',
#   'transcript': 'Eh mohon ditunggu sebentar. Saya izin membuatkan pelaporannya terlebih dahulu ya Bu ya.'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Customer',
#   'transcript': 'Itu pelaporannya mau dibuat seperti apa?'},
#  {'speaker': 'Agent',
#   'transcript': 'Saya buat kan pelaporan untuk perubahan presentasinya seperti itu Bu.'},
#  {'speaker': 'Customer',
#   'transcript': 'Eh sekarang kan auto debet saya kalau enggak salah berapa persen sih?'},
#  {'speaker': 'Agent', 'transcript': 'Di minimal pembayaran seperti itu.'},
#  {'speaker': 'Customer',
#   'transcript': 'Nah saya enggak mau saya mau bikinnya full payment ya Bu ya.'},
#  {'speaker': 'Agent',
#   'transcript': 'Dibayar full payment haah. Kalau ada tagihan bayarnya full payment.'},
#  {'speaker': 'Customer', 'transcript': 'Baik.'},
#  {'speaker': 'Agent',
#   'transcript': 'Jika seperti itu saya buat kan untuk pelaporan eh perubahan auto debet dari minimal pembayaran ke full payment Ibu.'},
#  {'speaker': 'Agent', 'transcript': 'Sepi itu betul'},
#  {'speaker': 'Customer', 'transcript': 'Baik'},
#  {'speaker': 'Agent', 'transcript': 'Iya'},
#  {'speaker': 'Agent',
#   'transcript': 'Saya izin memberikan antrian tunggu untuk pembukaan klaim orange terlebih dahulu ya Bu ya'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Agent',
#   'transcript': 'Baik, Ibu Berliani terima kasih atas kesabarannya menunggu. Untuk saat ini pelaporan nya sudah selesai saya lakukan.'},
#  {'speaker': 'Agent',
#   'transcript': 'Saya lanjutkan dengan satu verifikasi terlebih dahulu, Bu.'},
#  {'speaker': 'Agent',
#   'transcript': 'Setelah ini akan saya kirimkan kode verifikasi OTP ke nomor handphone Ibu yang terdaftar pada sistem.'},
#  {'speaker': 'Agent', 'transcript': 'Saya kirimkan melalui SMS.'},
#  {'speaker': 'Customer', 'transcript': 'Eh, Pak.'},
#  {'speaker': 'Agent', 'transcript': 'Saya kirim melalui SMS, Bu.'},
#  {'speaker': 'Customer', 'transcript': 'Oh, SMS?'},
#  {'speaker': 'Customer', 'transcript': 'Hmm, enggak bisa lagi.'},
#  {'speaker': 'Customer',
#   'transcript': 'Oke, baik deh. Ini HP saya lagi ini, Pak. Saya lagi pakai HP orang lain. HP saya lagi rusak.'},
#  {'speaker': 'Agent', 'transcript': 'Baik, Ibu.'},
#  {'speaker': 'Agent',
#   'transcript': 'Ini akan saya coba kirimkan terlebih dahulu ya, Bu ya.'},
#  {'speaker': 'Customer',
#   'transcript': 'Hmm, coba, Pak. Saya lihat terima enggak ya?'},
#  {'speaker': 'Customer',
#   'transcript': 'Ya, enggak mungkin masuk ini nomor saya, Pak.'},
#  {'speaker': 'Customer',
#   'transcript': 'Ini bisa apa, Pak, nomor mama saya orang lain, gimana enggak SMS diterima, udah tau udah pesan, Pak?'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Customer', 'transcript': 'Halo, Pak.'},
#  {'speaker': 'Agent', 'transcript': 'Iya, Bu.'},
#  {'speaker': 'Customer', 'transcript': 'Oh, iya. 642'},
#  {'speaker': 'Customer', 'transcript': 'Tidak perlu disebutkan ya Bu ya'},
#  {'speaker': 'Agent',
#   'transcript': 'Setelah ini akan saya alihkan Ibu ke sistem untuk verifikasinya Silakan di eh inputkan untuk enam digit OTP-nya setelah terdengar instruksi'},
#  {'speaker': 'Customer', 'transcript': 'Oke'},
#  {'speaker': 'Agent', 'transcript': 'Baik Mohon ditunggu sebentar'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Agent', 'transcript': 'Saya alihkan ya Bu'},
#  {'speaker': 'Customer', 'transcript': 'Oke'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Agent', 'transcript': 'Masukkan SMS pasword Anda'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Agent', 'transcript': 'Pasword yang Anda masukkan benar'},
#  {'speaker': 'Agent',
#   'transcript': 'Baik terima kasih untuk verifikasinya sudah sesuai Saya lanjutkan satu pertanyaan terlebih dahulu'},
#  {'speaker': 'Agent',
#   'transcript': 'Untuk eh pengiriman lembar tagihan Ibu dikirim melalui apa'},
#  {'speaker': 'Customer', 'transcript': 'Email'},
#  {'speaker': 'Agent', 'transcript': 'Alamat email-nya bisa disebutkan Bu'},
#  {'speaker': 'Customer', 'transcript': 'Eh a b'},
#  {'speaker': 'Agent', 'transcript': 'Iya'},
#  {'speaker': 'Customer', 'transcript': 'underscore'},
#  {'speaker': 'Agent', 'transcript': 'Iya'},
#  {'speaker': 'Customer', 'transcript': 'c o m'},
#  {'speaker': 'Agent', 'transcript': 'GRSP'},
#  {'speaker': 'Customer', 'transcript': 'Iya'},
#  {'speaker': 'Customer', 'transcript': 'At my mail at y mail.com'},
#  {'speaker': 'Agent',
#   'transcript': 'Baik terima kasih untuk verifikasinya sudah berhasil mau ditunggu sebentar saya lanjutkan untuk pelaporannya'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Agent',
#   'transcript': 'Baik Ibu saya konfirmasi pada hari ini tepatnya tanggal 19 Juni 2024 dengan saya Eko keluhan Ibu terkait untuk perubahan persentase dari eh auto debit Ibu yaitu dari minimal pembayaran ke full payment kami terima dengan nomor pelaporannya yaitu D Charlie Bravo Golf Romeo Echo 1906 2400 2688 untuk pengaduan Ibu memerlukan waktu penanganan di 2 hari kerja hingga tanggal 21 Juni 2024'},
#  {'speaker': 'Agent', 'transcript': '124'},
#  {'speaker': 'Agent',
#   'transcript': 'Dan untuk nomor pelaporan, akan saya kirimkan ke nomor handphone Ibu yang terdaftar pada sistem'},
#  {'speaker': 'Agent',
#   'transcript': 'Untuk hasilnya, Ibu juga dapat mengetahui melalui layanan pesan WhatsApp CIMB Niaga di nomor 081197814041 dengan menyebutkan nama lengkap dan nomor pelaporan Ibu'},
#  {'speaker': 'Customer', 'transcript': 'Baik'},
#  {'speaker': 'Customer', 'transcript': 'Nanti dikirim'},
#  {'speaker': 'Agent',
#   'transcript': 'Untuk informasi yang saya sampaikan, apakah sudah cukup jelas Ibu?'},
#  {'speaker': 'Customer', 'transcript': 'Sudah sudah jelas Mas'},
#  {'speaker': 'Agent', 'transcript': 'Ada lagi yang bisa saya bantu?'},
#  {'speaker': 'Customer', 'transcript': 'Sudah Mas'},
#  {'speaker': 'Agent', 'transcript': 'Baik'},
#  {'speaker': 'Agent',
#   'transcript': 'Terima kasih Ibu Berliani telah menghubungi saya di Niaga'},
#  {'speaker': 'Agent', 'transcript': 'Selamat sore semoga sehat selalu ya Bu'},
#  {'speaker': 'Customer', 'transcript': 'Iya makasih Mas'},
#  {'speaker': 'silence', 'transcript': nan},
#  {'speaker': 'Agent', 'transcript': 'P'}]

# %% [markdown]
# # BATCH PROCESS

# %%
# get data from json file
import json

with open('./ground_truth/list_of_input.json') as f:
    list_of_input = json.load(f)

with open('./ref_data/action_product_to_detail.json') as f:
    ref_data = json.load(f)

interaction_id_to_list_of_option = {}
for interaction_id, input_value in list_of_input.items():
    interaction_id_to_list_of_option[interaction_id] = ref_data[input_value]

# %% [markdown]
# ## MODEL LLM

# %%
model = GenerativeModel('gemini-1.5-flash-002')
generation_config = GenerationConfig(
    temperature=1,  # Example temperature value
    # top_k=1,         # Example top-k value
    # top_p=0.1        # Example top-p value
)

def generate_content(prompt):
    result = model.generate_content(
        contents=prompt,
        safety_settings={
            HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        },
        generation_config=generation_config
    )
    return result

# %%
output_data = []
list_of_unknown_csv = [9151919416110000090, 9151919416110000091, 9151919416110000092]

for interaction_id, list_of_option in interaction_id_to_list_of_option.items():
    if interaction_id in list_of_unknown_csv:
        continue
    try:
        prompt = generate_prompt('athena-nonprod-gcs', 'athena-ws4a/athena-qapm', interaction_id, list_of_option)
        response = generate_content(prompt).text
        disposition_result = json.loads(response.replace("```json", "").replace("```", "").strip())
        output_data.append({
            'interaction_id': interaction_id,
            'option_1': disposition_result[0]['value'],
            'explanation_1': disposition_result[0]['field3'],
            'option_2': disposition_result[1]['value'] if len(disposition_result) > 1 else None,
            'explanation_2': disposition_result[1]['field3'] if len(disposition_result) > 1 else None,
            'option_3': disposition_result[2]['value'] if len(disposition_result) > 2 else None,
            'explanation_3': disposition_result[2]['field3'] if len(disposition_result) > 2 else None,
        })

        print(f"Processing interaction_id: {interaction_id}")
    except Exception as e:
        print(f"Error: {e} at interaction_id: {interaction_id}")
# Out:
# Processing interaction_id: 9151919416110000051
# Processing interaction_id: 9151919416110000052
# Processing interaction_id: 9151919416110000053
# Processing interaction_id: 9151919416110000054
# Processing interaction_id: 9151919416110000055
# Processing interaction_id: 9151919416110000056
# Processing interaction_id: 9151919416110000057
# Processing interaction_id: 9151919416110000058
# Processing interaction_id: 9151919416110000059
# Processing interaction_id: 9151919416110000061
# Processing interaction_id: 9151919416110000062
# Processing interaction_id: 9151919416110000063
# Processing interaction_id: 9151919416110000064
# Processing interaction_id: 9151919416110000065
# Processing interaction_id: 9151919416110000066
# Processing interaction_id: 9151919416110000067
# Processing interaction_id: 9151919416110000068
# Processing interaction_id: 9151919416110000069
# Processing interaction_id: 9151919416110000071
# Processing interaction_id: 9151919416110000072
# Processing interaction_id: 9151919416110000073
# Processing interaction_id: 9151919416110000074
# Processing interaction_id: 9151919416110000075
# Processing interaction_id: 9151919416110000076
# Processing interaction_id: 9151919416110000078
# Processing interaction_id: 9151919416110000079
# Processing interaction_id: 9151919416110000080
# Processing interaction_id: 9151919416110000082
# Processing interaction_id: 9151919416110000083
# Processing interaction_id: 9151919416110000084
# Processing interaction_id: 9151919416110000085
# Processing interaction_id: 9151919416110000086
# Processing interaction_id: 9151919416110000087
# Processing interaction_id: 9151919416110000088
# Processing interaction_id: 9151919416110000089
# Error: 404 GET https://storage.googleapis.com/download/storage/v1/b/athena-nonprod-gcs/o/athena-ws4a%2Fathena-qapm%2Ftranscription%2F9151919416110000090%2Ftranscription_results.csv?alt=media: No such object: athena-nonprod-gcs/athena-ws4a/athena-qapm/transcription/9151919416110000090/transcription_results.csv: ('Request failed with status code', 404, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.PARTIAL_CONTENT: 206>) at interaction_id: 9151919416110000090
# Error: 404 GET https://storage.googleapis.com/download/storage/v1/b/athena-nonprod-gcs/o/athena-ws4a%2Fathena-qapm%2Ftranscription%2F9151919416110000091%2Ftranscription_results.csv?alt=media: No such object: athena-nonprod-gcs/athena-ws4a/athena-qapm/transcription/9151919416110000091/transcription_results.csv: ('Request failed with status code', 404, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.PARTIAL_CONTENT: 206>) at interaction_id: 9151919416110000091
# Processing interaction_id: 9151919416110000092
# Processing interaction_id: 9151919416110000093
# Processing interaction_id: 9151919416110000096
# Processing interaction_id: 9151919416110000099

# %%
df = pd.DataFrame(output_data)
df
# Out:
#          interaction_id                           option_1  \
# 0   9151919416110000051                        Gagal Tarik
# 1   9151919416110000052                Sanggahan Transaksi
# 2   9151919416110000053                  Kendala Transaksi
# 3   9151919416110000054                Sanggahan Transaksi
# 4   9151919416110000055                      Kendala Login
# 5   9151919416110000056                              Fitur
# 6   9151919416110000057                             Status
# 7   9151919416110000058                              Limit
# 8   9151919416110000059     Pembayaran Tagihan Credit Card
# 9   9151919416110000061                            Tagihan
# 10  9151919416110000062                              Other
# 11  9151919416110000063                Biaya/ Bunga/ Denda
# 12  9151919416110000064                Biaya/ Bunga/ Denda
# 13  9151919416110000065     Cicilan (Bunga/ Jumlah/ Tenor)
# 14  9151919416110000066                     Cara Penagihan
# 15  9151919416110000067                              Limit
# 16  9151919416110000068                              Other
# 17  9151919416110000069                              Limit
# 18  9151919416110000071                            Tagihan
# 19  9151919416110000072                  Perhitungan Bunga
# 20  9151919416110000073    Tagihan (Tidak Terima/ Selisih)
# 21  9151919416110000074                         Pembatalan
# 22  9151919416110000075                   Credit Protector
# 23  9151919416110000076                   Credit Protector
# 24  9151919416110000078                   Reversal Payment
# 25  9151919416110000079    Tagihan (Tidak Terima/ Selisih)
# 26  9151919416110000080  Kendala Registrasi Perangkat Baru
# 27  9151919416110000082                  Kendala Transaksi
# 28  9151919416110000083                  Kendala Transaksi
# 29  9151919416110000084                          Terblokir
# 30  9151919416110000085     Pembayaran Tagihan Credit Card
# 31  9151919416110000086                            Tagihan
# 32  9151919416110000087    Tagihan (Tidak Terima/ Selisih)
# 33  9151919416110000088                    Penutupan Kartu
# 34  9151919416110000089                             Jumlah
# 35  9151919416110000092                  Kirim Ulang Kartu
# 36  9151919416110000093                   Aktivasi dan PIN
# 37  9151919416110000096                          Cash Plus
# 38  9151919416110000099                   Aktivasi dan PIN
#
#                                         explanation_1  \
# 0   Penjelasan klasifikasi: Nasabah mengalami gaga...
# 1   Penjelasan klasifikasi: Nasabah menanyakan tra...
# 2   Penjelasan klasifikasi: Nasabah mengalami kend...
# 3   Penjelasan klasifikasi: Nasabah menanyakan kej...
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...
# 5   Penjelasan klasifikasi: Nasabah menanyakan det...
# 6   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 7   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 8   Penjelasan klasifikasi: Nasabah menanyakan sta...
# 9   Penjelasan klasifikasi: Nasabah menanyakan sta...
# 10  Penjelasan klasifikasi: Nasabah komplain pemba...
# 11  Penjelasan klasifikasi: Nasabah memprotes tagi...
# 12  Penjelasan klasifikasi: Nasabah memprotes dend...
# 13  Penjelasan klasifikasi: Nasabah menanyakan det...
# 14  Penjelasan klasifikasi: Nasabah menanyakan ker...
# 15  Penjelasan klasifikasi: Nasabah mengalami masa...
# 16  Penjelasan klasifikasi: Nasabah menanyakan fol...
# 17  Penjelasan klasifikasi: Nasabah menanyakan lim...
# 18  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 19  Penjelasan klasifikasi: Nasabah menanyakan per...
# 20  Penjelasan klasifikasi: Nasabah menanyakan per...
# 21  Penjelasan klasifikasi: Nasabah meminta pengha...
# 22  Nasabah mempertanyakan tagihan kartu kredit, k...
# 23  Penjelasan klasifikasi: Nasabah menanyakan dan...
# 24  Penjelasan klasifikasi: Nasabah ingin mengalih...
# 25  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 26  Penjelasan klasifikasi: Nasabah mengalami kend...
# 27  Penjelasan klasifikasi: Nasabah mengalami kend...
# 28  Penjelasan klasifikasi: Nasabah mengalami kend...
# 29  Penjelasan klasifikasi: Nasabah mengalami kend...
# 30  Penjelasan klasifikasi: Nasabah menanyakan min...
# 31  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 32  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 33  Penjelasan klasifikasi: Nasabah meminta penutu...
# 34  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 35  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 36  Penjelasan klasifikasi: Nasabah mengalami kend...
# 37  Penjelasan klasifikasi: Nasabah menanyakan kem...
# 38  Penjelasan klasifikasi: Nasabah menanyakan per...
#
#                                   option_2  \
# 0                          Gagal Transaksi
# 1                      Blokir/ Buka Blokir
# 2                                    Other
# 3                                Transaksi
# 4        Kendala Registrasi Perangkat Baru
# 5                                   Status
# 6                                     None
# 7           Pembayaran Tagihan Credit Card
# 8                                   Status
# 9                          Penutupan Kartu
# 10                Tidak Berkenan Dihubungi
# 11                                 Tagihan
# 12                    Pengajuan  Corporate
# 13                     Bunga/ Biaya/ Denda
# 14                                   Other
# 15                                   Other
# 16                                    None
# 17                              Annual Fee
# 18         Tagihan (Tidak Terima/ Selisih)
# 19                               Transaksi
# 20                                 Tagihan
# 21                        Credit Protector
# 22                              Pembatalan
# 23                        Aktivasi dan PIN
# 24                        Aktivasi dan PIN
# 25          Cicilan (Bunga/ Jumlah/ Tenor)
# 26                               Terblokir
# 27                                   Other
# 28                                    None
# 29                        Tidak Terima OTP
# 30                       Kendala Transaksi
# 31                               Transaksi
# 32                       Pelunasan Cicilan
# 33                                    None
# 34                                   Other
# 35               Status Pengajuan Aplikasi
# 36                       Kendala Transaksi
# 37                               Transaksi
# 38  Pendaftaran dan Pembatalan E-Statement
#
#                                         explanation_2  \
# 0   Penjelasan klasifikasi: Transaksi gagal tarik ...
# 1   Penjelasan klasifikasi:  Nasabah mengalami mas...
# 2   Penjelasan klasifikasi:  Masalah top up GoPay ...
# 3   Penjelasan klasifikasi:  Percakapan berfokus p...
# 4   Penjelasan klasifikasi: Masalah utama adalah k...
# 5   Penjelasan klasifikasi: Nasabah ingin mengetah...
# 6                                                None
# 7   Penjelasan klasifikasi: Nasabah menanyakan dam...
# 8   Penjelasan klasifikasi: Nasabah mengalami kend...
# 9   Penjelasan klasifikasi: Nasabah mengeluhkan pr...
# 10  Penjelasan klasifikasi: Nasabah keberatan kare...
# 11  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 12  Penjelasan klasifikasi: Nasabah mengancam akan...
# 13  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 14  Penjelasan klasifikasi: Nasabah mengalami masa...
# 15  Penjelasan klasifikasi: Nasabah melaporkan gan...
# 16                                               None
# 17  Penjelasan klasifikasi: Nasabah menanyakan det...
# 18  Penjelasan klasifikasi: Nasabah menanyakan det...
# 19  Penjelasan klasifikasi: Nasabah ingin mengetah...
# 20  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 21  Penjelasan klasifikasi:  Pemrosesan pembatalan...
# 22  Nasabah meminta pembatalan Credit Protector. T...
# 23  Penjelasan klasifikasi: Nasabah melakukan veri...
# 24  Penjelasan klasifikasi:  Nasabah melakukan ver...
# 25  Penjelasan klasifikasi: Nasabah menanyakan det...
# 26  Penjelasan klasifikasi: Akun mobile banking na...
# 27  Penjelasan klasifikasi:  Agen melakukan pengec...
# 28                                               None
# 29  Penjelasan klasifikasi: Masalah utama adalah k...
# 30  Penjelasan klasifikasi: Nasabah mengalami kend...
# 31  Penjelasan klasifikasi: Nasabah menanyakan det...
# 32  Penjelasan klasifikasi: Percakapan internal ag...
# 33                                               None
# 34  Penjelasan klasifikasi: Nasabah menanyakan sya...
# 35  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 36  Penjelasan klasifikasi: Masalah transaksi kart...
# 37  Penjelasan klasifikasi: Nasabah ingin mengetah...
# 38  Penjelasan klasifikasi: Nasabah meminta bantua...
#
#                            option_3  \
# 0                             Other
# 1                         Transaksi
# 2                             Other
# 3                 Kendala Transaksi
# 4                 Kendala Transaksi
# 5                             Other
# 6                              None
# 7                         Transaksi
# 8       Naik/ Turun Limit Sementara
# 9   Tagihan (Tidak Terima/ Selisih)
# 10                             None
# 11                        Transaksi
# 12                        Pengajuan
# 13                            Other
# 14                             None
# 15                          Tagihan
# 16                             None
# 17                 Aktivasi dan PIN
# 18                       Pembatalan
# 19                Pelunasan Cicilan
# 20   Pembayaran Tagihan Credit Card
# 21              Biaya/ Bunga/ Denda
# 22                          Tagihan
# 23                          Tagihan
# 24                       Annual Fee
# 25                 Credit Protector
# 26                            Fitur
# 27                            Fitur
# 28                             None
# 29                    Kendala Login
# 30                            Other
# 31  Tagihan (Tidak Terima/ Selisih)
# 32                          Tagihan
# 33                             None
# 34          Promo/ Voucher/ Mileage
# 35                            Other
# 36                        Transaksi
# 37                        Cash Plus
# 38                            Other
#
#                                         explanation_3
# 0   Penjelasan klasifikasi:  Nasabah melaporkan tr...
# 1   Penjelasan klasifikasi: Nasabah melaporkan tra...
# 2   Penjelasan klasifikasi: Nasabah menanyakan kem...
# 3   Penjelasan klasifikasi:  Agen melakukan invest...
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...
# 5   Penjelasan klasifikasi: Nasabah menanyakan per...
# 6                                                None
# 7   Penjelasan klasifikasi: Nasabah menanyakan kon...
# 8   Penjelasan klasifikasi: Nasabah menanyakan pro...
# 9   Penjelasan klasifikasi: Nasabah menanyakan tag...
# 10                                               None
# 11  Penjelasan klasifikasi: Nasabah menanyakan pen...
# 12  Penjelasan klasifikasi: Nasabah meminta pengha...
# 13  Penjelasan klasifikasi:  Agent membuat laporan...
# 14                                               None
# 15  Penjelasan klasifikasi: Nasabah menanyakan ken...
# 16                                               None
# 17  Penjelasan klasifikasi:  Percakapan membahas v...
# 18  Penjelasan klasifikasi: Nasabah meminta pembat...
# 19  Penjelasan klasifikasi:  Pertanyaan nasabah te...
# 20  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 21  Penjelasan klasifikasi:  Penjelasan mengenai p...
# 22  Nasabah menanyakan detail tagihan kartu kredit...
# 23  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 24  Penjelasan klasifikasi:  Pembahasan mengenai a...
# 25  Penjelasan klasifikasi: Nasabah meminta pembat...
# 26  Penjelasan klasifikasi: Nasabah membutuhkan ba...
# 27  Penjelasan klasifikasi:  Nasabah meminta pandu...
# 28                                               None
# 29  Penjelasan klasifikasi: Akun Octo Click nasaba...
# 30  Penjelasan klasifikasi:  Nasabah memprotes pro...
# 31  Penjelasan klasifikasi:  Nasabah mempertanyaka...
# 32  Penjelasan klasifikasi: Nasabah menanyakan ken...
# 33                                               None
# 34  Penjelasan klasifikasi: Nasabah ingin menukark...
# 35  Penjelasan klasifikasi: Nasabah menanyakan inf...
# 36  Penjelasan klasifikasi:  Nasabah mengalami ken...
# 37  Penjelasan klasifikasi: Nasabah memilih progra...
# 38  Penjelasan klasifikasi: Nasabah menanyakan pro...

# %% [markdown]
# # Combine data with ground truth

# %%
# read json file
import json

with open('./ground_truth/ground_truth.json') as f:
    ground_truth = json.load(f)

# map with ground truth
df['interaction_id'] = df['interaction_id'].astype(str)
df['ground_truth'] = df['interaction_id'].map(ground_truth)

# save to csv
df.to_csv('output.csv', index=False)

# %% [markdown]
# # Read the output.csv file

# %%
df = pd.read_csv('output.csv')

# check whether option_1 or option_2 or option_3 is equal to ground_truth, the result is True or False in "is_match" column
df['is_match'] = df['ground_truth'] == df['option_1']

show_df = df[['interaction_id', 'option_1', 'ground_truth', 'is_match']]
show_df
# Out:
#          interaction_id                           option_1  \
# 0   9151919416110000051                        Gagal Tarik
# 1   9151919416110000052                Sanggahan Transaksi
# 2   9151919416110000053                  Kendala Transaksi
# 3   9151919416110000054                Sanggahan Transaksi
# 4   9151919416110000055                      Kendala Login
# 5   9151919416110000056                              Fitur
# 6   9151919416110000057                             Status
# 7   9151919416110000058                              Limit
# 8   9151919416110000059     Pembayaran Tagihan Credit Card
# 9   9151919416110000061                            Tagihan
# 10  9151919416110000062                              Other
# 11  9151919416110000063                Biaya/ Bunga/ Denda
# 12  9151919416110000064                Biaya/ Bunga/ Denda
# 13  9151919416110000065     Cicilan (Bunga/ Jumlah/ Tenor)
# 14  9151919416110000066                     Cara Penagihan
# 15  9151919416110000067                              Limit
# 16  9151919416110000068                              Other
# 17  9151919416110000069                              Limit
# 18  9151919416110000071                            Tagihan
# 19  9151919416110000072                  Perhitungan Bunga
# 20  9151919416110000073    Tagihan (Tidak Terima/ Selisih)
# 21  9151919416110000074                         Pembatalan
# 22  9151919416110000075                   Credit Protector
# 23  9151919416110000076                   Credit Protector
# 24  9151919416110000078                   Reversal Payment
# 25  9151919416110000079    Tagihan (Tidak Terima/ Selisih)
# 26  9151919416110000080  Kendala Registrasi Perangkat Baru
# 27  9151919416110000082                  Kendala Transaksi
# 28  9151919416110000083                  Kendala Transaksi
# 29  9151919416110000084                          Terblokir
# 30  9151919416110000085     Pembayaran Tagihan Credit Card
# 31  9151919416110000086                            Tagihan
# 32  9151919416110000087    Tagihan (Tidak Terima/ Selisih)
# 33  9151919416110000088                    Penutupan Kartu
# 34  9151919416110000089                             Jumlah
# 35  9151919416110000092                  Kirim Ulang Kartu
# 36  9151919416110000093                   Aktivasi dan PIN
# 37  9151919416110000096                          Cash Plus
# 38  9151919416110000099                   Aktivasi dan PIN
#
#                               ground_truth  is_match
# 0                              Gagal Tarik      True
# 1                      Sanggahan Transaksi      True
# 2                        Kendala Transaksi      True
# 3                      Sanggahan Transaksi      True
# 4                            Kendala Login      True
# 5                                    Other     False
# 6                                    Other     False
# 7                                    Limit      True
# 8           Pembayaran Tagihan Credit Card      True
# 9                          Penutupan Kartu     False
# 10                  Penawaran Tidak Sesuai     False
# 11                     Biaya/ Bunga/ Denda      True
# 12                     Biaya/ Bunga/ Denda      True
# 13          Cicilan (Bunga/ Jumlah/ Tenor)      True
# 14                          Cara Penagihan      True
# 15          Pembayaran Tagihan Credit Card     False
# 16                   Pelunasan Keseluruhan     False
# 17                                   Fitur     False
# 18                     Biaya/ Bunga/ Denda     False
# 19          Cicilan (Bunga/ Jumlah/ Tenor)     False
# 20          Pembayaran Tagihan Credit Card     False
# 21                        Credit Protector     False
# 22                        Credit Protector      True
# 23                        Credit Protector      True
# 24                        Reversal Payment      True
# 25          Cicilan (Bunga/ Jumlah/ Tenor)     False
# 26                              Registrasi     False
# 27                       Kendala Transaksi      True
# 28                           Kendala Login     False
# 29                       Kendala Transaksi     False
# 30          Pembayaran Tagihan Credit Card      True
# 31         Tagihan (Tidak Terima/ Selisih)     False
# 32         Tagihan (Tidak Terima/ Selisih)      True
# 33                         Penutupan Kartu      True
# 34                                   Other     False
# 35                       Kirim Ulang Kartu      True
# 36                        Aktivasi dan PIN      True
# 37          Cicilan (Bunga/ Jumlah/ Tenor)     False
# 38  Pendaftaran dan Pembatalan E-Statement     False

# %% [markdown]
# # CALCULATE ACCURACY

# %%
# calculate the mean of "is_match" column where ground_truth is not NaN
accuracy = df[df['ground_truth'].notnull()]['is_match'].mean()
accuracy
# Out:
# np.float64(0.5128205128205128)

# %%
df
