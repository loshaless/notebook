# %% [markdown]
# # MODEL LLM

# %%
from vertexai.generative_models import (
    GenerativeModel,
    GenerationConfig,
    HarmCategory,
    HarmBlockThreshold
)

model = GenerativeModel('gemini-1.5-flash-002')
generation_config = GenerationConfig(
    temperature=0.1,  # Example temperature value
    top_k=1,         # Example top-k value
    top_p=0.1        # Example top-p value
)

def generate_content(prompt):
    result = model.generate_content(
        contents=prompt,
        safety_settings={
            HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
            HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        },
        generation_config=generation_config
    )
    return result

# %% [markdown]
# # FUNCTION

# %%
import pandas as pd
from io import StringIO
from google.cloud import storage
import os
BASE_DIR = os.getcwd()

def load_transcription_csv(bucket_name, file_path):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(file_path)
    content = blob.download_as_text()

    return pd.read_csv(StringIO(content))[['speaker', 'transcript']]

def get_prompt(**kwargs):
    with open('prompt/disposition_code.txt', 'r') as file:
        prompt_template = file.read()

    return prompt_template.format(**kwargs)

def get_ref_table():
    excel_path = "disposition_code_ref_table_cleaned.xlsx"
    ref_table_df = pd.read_excel(os.path.join(BASE_DIR, excel_path))
    ref_table_df.drop(columns=["Konkatenasi_Layer123"], inplace=True)
    ref_table_dict = ref_table_df.to_dict(orient='records')
    return ref_table_dict

def generate_prompt(bucket_name, file_path, interaction_id: str):
    transcript_df = load_transcription_csv(bucket_name,f"{file_path}/transcription/{interaction_id}/transcription_results.csv")
    transcript_df = transcript_df.where(pd.notnull(transcript_df), 'silence')
    # json_dict = {
    #     'speaker': transcript_df['speaker'].tolist(),
    #     'transcript': transcript_df['transcript'].tolist()
    # }
    json_dict = transcript_df.to_dict(orient='records')
    prompt = get_prompt(
        transcript=json_dict,
        disposition_code_ref_table=get_ref_table()
    )
    return prompt

# %%
# generate_prompt('athena-nonprod-gcs', 'athena-ws4a/athena-qapm', '9151919416110000051')

# %% [markdown]
# # BATCH PROCESS

# %%
import json

list_of_unknown_csv = [9151919416110000090, 9151919416110000091, 9151919416110000092]
output_data = []
for i in range(9151919416110000051, 9151919416110000099+1):
    if i in list_of_unknown_csv:
        continue
    try:
        prompt = generate_prompt('athena-nonprod-gcs', 'athena-ws4a/athena-qapm', i)
        response = generate_content(prompt).text
        disposition_result = json.loads(response.replace("```json", "").replace("```", "").strip())
        output_data.append({
            'interaction_id': i,
            'option_1': disposition_result[0]['value'],
            'explanation_1': disposition_result[0]['field3'],
            'option_2': disposition_result[1]['value'] if len(disposition_result) > 1 else None,
            'explanation_2': disposition_result[1]['field3'] if len(disposition_result) > 1 else None,
            'option_3': disposition_result[2]['value'] if len(disposition_result) > 2 else None,
            'explanation_3': disposition_result[2]['field3'] if len(disposition_result) > 2 else None,
        })
        print(f"Processed interaction_id: {i}")
    except Exception as e:
        print(f"Error: {e} at interaction_id: {i}")

df = pd.DataFrame(output_data)
# Out:
# Processed interaction_id: 9151919416110000051
# Processed interaction_id: 9151919416110000052
# Processed interaction_id: 9151919416110000053
# Processed interaction_id: 9151919416110000054
# Processed interaction_id: 9151919416110000055
# Processed interaction_id: 9151919416110000056
# Processed interaction_id: 9151919416110000057
# Processed interaction_id: 9151919416110000058
# Processed interaction_id: 9151919416110000059
# Processed interaction_id: 9151919416110000060
# Processed interaction_id: 9151919416110000061
# Processed interaction_id: 9151919416110000062
# Processed interaction_id: 9151919416110000063
# Processed interaction_id: 9151919416110000064
# Processed interaction_id: 9151919416110000065
# Processed interaction_id: 9151919416110000066
# Processed interaction_id: 9151919416110000067
# Processed interaction_id: 9151919416110000068
# Processed interaction_id: 9151919416110000069
# Processed interaction_id: 9151919416110000070
# Processed interaction_id: 9151919416110000071
# Processed interaction_id: 9151919416110000072
# Processed interaction_id: 9151919416110000073
# Processed interaction_id: 9151919416110000074
# Processed interaction_id: 9151919416110000075
# Processed interaction_id: 9151919416110000076
# Processed interaction_id: 9151919416110000077
# Processed interaction_id: 9151919416110000078
# Processed interaction_id: 9151919416110000079
# Processed interaction_id: 9151919416110000080
# Processed interaction_id: 9151919416110000081
# Processed interaction_id: 9151919416110000082
# Processed interaction_id: 9151919416110000083
# Processed interaction_id: 9151919416110000084
# Processed interaction_id: 9151919416110000085
# Processed interaction_id: 9151919416110000086
# Processed interaction_id: 9151919416110000087
# Processed interaction_id: 9151919416110000088
# Processed interaction_id: 9151919416110000089
# Processed interaction_id: 9151919416110000093
# Processed interaction_id: 9151919416110000094
# Processed interaction_id: 9151919416110000095
# Processed interaction_id: 9151919416110000096
# Processed interaction_id: 9151919416110000097
# Processed interaction_id: 9151919416110000098
# Processed interaction_id: 9151919416110000099

# %%
df
# Out:
#          interaction_id                                           option_1  \
# 0   9151919416110000051                           Complain|ATM|Gagal Tarik
# 1   9151919416110000052           Complain|Credit Card|Sanggahan Transaksi
# 2   9151919416110000053             Complain|OCTO Mobile|Kendala Transaksi
# 3   9151919416110000054           Complain|Credit Card|Sanggahan Transaksi
# 4   9151919416110000055                 Complain|OCTO Mobile|Kendala Login
# 5   9151919416110000056                           Inquiry|Debit Card|Other
# 6   9151919416110000057                                  Inquiry|KPR|Other
# 7   9151919416110000058                          Inquiry|Credit Card|Limit
# 8   9151919416110000059  Complain|Credit Card|Pembayaran Tagihan Credit...
# 9   9151919416110000060                     Request|Credit Card|Annual Fee
# 10  9151919416110000061               Complain|Credit Card|Penutupan Kartu
# 11  9151919416110000062  Complain|Credit Card|Pembayaran Tagihan Credit...
# 12  9151919416110000063           Complain|Credit Card|Biaya/ Bunga/ Denda
# 13  9151919416110000064           Complain|Credit Card|Biaya/ Bunga/ Denda
# 14  9151919416110000065               Complain|KTA/ PL|Bunga/ Biaya/ Denda
# 15  9151919416110000066  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...
# 16  9151919416110000067           Complain|Credit Card|Biaya/ Bunga/ Denda
# 17  9151919416110000068                 Complain|KPR|Pelunasan Keseluruhan
# 18  9151919416110000069                          Inquiry|Credit Card|Limit
# 19  9151919416110000070               Inquiry|Credit Card|Aktivasi dan PIN
# 20  9151919416110000071                       Complain|Credit Card|Tagihan
# 21  9151919416110000072  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 22  9151919416110000073  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 23  9151919416110000074               Request|Credit Card|Credit Protector
# 24  9151919416110000075              Complain|Credit Card|Credit Protector
# 25  9151919416110000076                     Request|Credit Card|Pembatalan
# 26  9151919416110000077               Request|Credit Card|Credit Protector
# 27  9151919416110000078               Request|Credit Card|Reversal Payment
# 28  9151919416110000079  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 29  9151919416110000080  Complain|OCTO Mobile|Kendala Registrasi Perang...
# 30  9151919416110000081                     Complain|OCTO Mobile|Terblokir
# 31  9151919416110000082             Complain|OCTO Mobile|Kendala Transaksi
# 32  9151919416110000083             Complain|OCTO Mobile|Kendala Transaksi
# 33  9151919416110000084                     Complain|OCTO Clicks|Terblokir
# 34  9151919416110000085                       Complain|Credit Card|Tagihan
# 35  9151919416110000086                        Inquiry|Credit Card|Tagihan
# 36  9151919416110000087  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37  9151919416110000088           Complain|Credit Card|Biaya/ Bunga/ Denda
# 38  9151919416110000089                          Inquiry|Credit Card|Limit
# 39  9151919416110000093              Complain|Credit Card|Aktivasi dan PIN
# 40  9151919416110000094  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 41  9151919416110000095  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 42  9151919416110000096                      Inquiry|Credit Card|Cash Plus
# 43  9151919416110000097  Request|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 44  9151919416110000098                      Request|Credit Card|Pengajuan
# 45  9151919416110000099               Request|Credit Card|Aktivasi dan PIN
#
#                                         explanation_1  \
# 0   Penjelasan klasifikasi: Nasabah mengalami gaga...
# 1   Penjelasan klasifikasi: Nasabah melaporkan tra...
# 2   Penjelasan klasifikasi: Nasabah mengalami kend...
# 3   Penjelasan klasifikasi: Nasabah menanyakan tra...
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...
# 5   Penjelasan klasifikasi: Nasabah menanyakan det...
# 6   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 7   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 8   Penjelasan klasifikasi: Nasabah menanyakan sta...
# 9   Penjelasan klasifikasi: Nasabah meminta pengha...
# 10  Penjelasan klasifikasi: Nasabah komplain menge...
# 11  Penjelasan klasifikasi: Nasabah komplain pemba...
# 12  Penjelasan klasifikasi: Nasabah komplain menge...
# 13  Penjelasan klasifikasi: Nasabah komplain menge...
# 14  Penjelasan klasifikasi: Nasabah menanyakan det...
# 15  Penjelasan klasifikasi: Nasabah meminta kering...
# 16  Penjelasan klasifikasi: Nasabah mengeluhkan mi...
# 17  Penjelasan klasifikasi: Nasabah komplain menge...
# 18  Penjelasan klasifikasi: Nasabah menanyakan lim...
# 19  Penjelasan klasifikasi: Nasabah menanyakan car...
# 20  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 21  Penjelasan klasifikasi: Nasabah menanyakan est...
# 22  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 23  Penjelasan klasifikasi: Nasabah meminta pengha...
# 24  Penjelasan klasifikasi: Nasabah memprotes adan...
# 25  Penjelasan klasifikasi: Nasabah ingin membatal...
# 26  Penjelasan klasifikasi: Nasabah meminta pengha...
# 27  Penjelasan klasifikasi: Nasabah meminta pemind...
# 28  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 29  Penjelasan klasifikasi: Nasabah mengalami kend...
# 30  Penjelasan klasifikasi: Nasabah mengalami kend...
# 31  Penjelasan klasifikasi: Nasabah mengalami gaga...
# 32  Penjelasan klasifikasi: Nasabah mengalami gaga...
# 33  Penjelasan klasifikasi: Nasabah mengalami kend...
# 34  Penjelasan klasifikasi: Nasabah komplain menge...
# 35  Penjelasan klasifikasi: Nasabah menanyakan det...
# 36  Penjelasan klasifikasi: Nasabah komplain terka...
# 37  Penjelasan klasifikasi: Nasabah meminta penutu...
# 38  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 39  Penjelasan klasifikasi: Nasabah mengalami kend...
# 40  Penjelasan klasifikasi: Nasabah komplain menge...
# 41  Penjelasan klasifikasi: Nasabah komplain menge...
# 42  Penjelasan klasifikasi: Nasabah menanyakan kem...
# 43  Penjelasan klasifikasi: Nasabah ingin mengubah...
# 44  Penjelasan klasifikasi: Nasabah meminta pembua...
# 45  Penjelasan klasifikasi: Nasabah mengalami kend...
#
#                                              option_2  \
# 0                                                None
# 1                Request|Credit Card|Pergantian Kartu
# 2                                                None
# 3                                                None
# 4            Complain|Credit Card|Sanggahan Transaksi
# 5                       Inquiry|OCTO Mobile|Transaksi
# 6                                                None
# 7                           Inquiry|Credit Card|Other
# 8                          Complain|Credit Card|Limit
# 9                                                None
# 10                       Complain|Credit Card|Tagihan
# 11                      Complain|Credit Card|Penipuan
# 12                                               None
# 13            Request|Credit Card|Biaya/ Bunga/ Denda
# 14     Inquiry|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 15                                               None
# 16                            Complain|Services|Other
# 17                                               None
# 18                     Inquiry|Credit Card|Annual Fee
# 19                          Inquiry|Credit Card|Fitur
# 20           Complain|Credit Card|Biaya/ Bunga/ Denda
# 21                                               None
# 22  Complain|Credit Card|Pembayaran Tagihan Credit...
# 23                                               None
# 24                     Request|Credit Card|Pembatalan
# 25                          Inquiry|Credit Card|Limit
# 26                                               None
# 27                    Complain|Credit Card|Annual Fee
# 28     Inquiry|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 29                     Complain|OCTO Mobile|Terblokir
# 30                 Inquiry|OCTO Pay|Kendala Transaksi
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 36  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37                Request|Credit Card|Penutupan Kartu
# 38     Request|Credit Card|Naik/ Turun Limit Permanen
# 39             Complain|Credit Card|Kendala Transaksi
# 40                                               None
# 41  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 42            Inquiry|Credit Card|Biaya/ Bunga/ Denda
# 43                                               None
# 44                                               None
# 45                          Inquiry|Credit Card|Other
#
#                                         explanation_2  \
# 0                                                None
# 1   Penjelasan klasifikasi: Nasabah meminta pencet...
# 2                                                None
# 3                                                None
# 4   Penjelasan klasifikasi: Nasabah komplain sangg...
# 5   Penjelasan klasifikasi: Nasabah menanyakan per...
# 6                                                None
# 7   Penjelasan klasifikasi: Nasabah ingin mengetah...
# 8   Penjelasan klasifikasi: Nasabah mengalami keti...
# 9                                                None
# 10  Penjelasan klasifikasi: Nasabah komplain menge...
# 11  Penjelasan klasifikasi: Nasabah komplain dihub...
# 12                                               None
# 13  Penjelasan klasifikasi: Nasabah meminta pengha...
# 14  Penjelasan klasifikasi: Nasabah meminta penjel...
# 15                                               None
# 16  Penjelasan klasifikasi: Nasabah melaporkan gan...
# 17                                               None
# 18  Penjelasan klasifikasi: Nasabah menanyakan bia...
# 19  Penjelasan klasifikasi: Nasabah menanyakan per...
# 20  Penjelasan klasifikasi: Nasabah meminta penjel...
# 21                                               None
# 22  Penjelasan klasifikasi: Nasabah mengalami kend...
# 23                                               None
# 24  Penjelasan klasifikasi: Nasabah meminta pembat...
# 25  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 26                                               None
# 27  Penjelasan klasifikasi: Nasabah menanyakan ann...
# 28  Penjelasan klasifikasi: Nasabah meminta penjel...
# 29  Penjelasan klasifikasi: Aplikasi Octo Mobile n...
# 30  Penjelasan klasifikasi: Nasabah menanyakan car...
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 36  Penjelasan klasifikasi: Agent meminta bantuan ...
# 37  Penjelasan klasifikasi: Nasabah mengajukan pen...
# 38  Penjelasan klasifikasi: Nasabah meminta kenaik...
# 39  Penjelasan klasifikasi: Nasabah mengalami kend...
# 40                                               None
# 41  Penjelasan klasifikasi: Nasabah meminta penjel...
# 42  Penjelasan klasifikasi: Nasabah ingin mengetah...
# 43                                               None
# 44                                               None
# 45  Penjelasan klasifikasi: Nasabah menanyakan pro...
#
#                                              option_3  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4            Complain|Credit Card|Biaya/ Bunga/ Denda
# 5                           Request|OCTO Mobile|Other
# 6                                                None
# 7                                                None
# 8      Inquiry|Credit Card|Naik/ Turun Limit Permanen
# 9                                                None
# 10                        Inquiry|Credit Card|Tagihan
# 11                 Request|Credit Card|Perubahan Data
# 12                                               None
# 13                          Request|Credit Card|Other
# 14                              Request|KTA/ PL|Other
# 15                                               None
# 16                        Inquiry|Credit Card|Tagihan
# 17                                               None
# 18                        Inquiry|Credit Card|Tagihan
# 19                          Inquiry|Credit Card|Promo
# 20                        Inquiry|Credit Card|Tagihan
# 21                                               None
# 22  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 23                                               None
# 24                                               None
# 25  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 26                                               None
# 27                                               None
# 28                     Request|Credit Card|Pembatalan
# 29                                               None
# 30                  Inquiry|OCTO Mobile|Pemulihan PIN
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                      Inquiry|Credit Card|Poin Xtra
# 36                       Complain|Credit Card|Tagihan
# 37                                               None
# 38               Request|Credit Card|Redeem Cash Back
# 39                                Inquiry|Other|Other
# 40                                               None
# 41   Complain|Credit Card|Naik/ Turun Limit Sementara
# 42             Campaign/ Sales|Cash Plus|Sales Setuju
# 43                                               None
# 44                                               None
# 45                               Complain|Other|Other
#
#                                         explanation_3
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   Penjelasan klasifikasi: Nasabah dikenakan dend...
# 5   Penjelasan klasifikasi: Nasabah ingin menonakt...
# 6                                                None
# 7                                                None
# 8   Penjelasan klasifikasi: Nasabah meminta inform...
# 9                                                None
# 10  Penjelasan klasifikasi: Nasabah meminta penjel...
# 11  Penjelasan klasifikasi: Nasabah meminta peruba...
# 12                                               None
# 13  Penjelasan klasifikasi: Nasabah meminta pembua...
# 14  Penjelasan klasifikasi: Nasabah meminta lapora...
# 15                                               None
# 16  Penjelasan klasifikasi: Nasabah menanyakan ala...
# 17                                               None
# 18  Penjelasan klasifikasi: Nasabah menanyakan jat...
# 19  Penjelasan klasifikasi: Nasabah menanyakan inf...
# 20  Penjelasan klasifikasi: Nasabah menanyakan per...
# 21                                               None
# 22  Penjelasan klasifikasi: Nasabah ingin memastik...
# 23                                               None
# 24                                               None
# 25  Penjelasan klasifikasi: Nasabah menanyakan met...
# 26                                               None
# 27                                               None
# 28  Penjelasan klasifikasi: Nasabah meminta pembat...
# 29                                               None
# 30  Penjelasan klasifikasi: Nasabah menanyakan bag...
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35  Penjelasan klasifikasi: Nasabah menanyakan poi...
# 36  Penjelasan klasifikasi: Nasabah komplain tagih...
# 37                                               None
# 38  Penjelasan klasifikasi: Nasabah ingin menukark...
# 39  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 40                                               None
# 41  Penjelasan klasifikasi: Nasabah komplain karen...
# 42  Penjelasan klasifikasi: Nasabah akhirnya setuj...
# 43                                               None
# 44                                               None
# 45  Penjelasan klasifikasi: Nasabah mengalami kend...

# %% [markdown]
# # Combine data with ground truth

# %%
# read json file
import json

with open('./ground_truth/ground_truth.json') as f:
    ground_truth = json.load(f)

# map with ground truth
df['interaction_id'] = df['interaction_id'].astype(str)
df['ground_truth'] = df['interaction_id'].map(ground_truth)

# save to csv
df.to_csv('output.csv', index=False)

# %% [markdown]
# # Read the output.csv file

# %%
df = pd.read_csv('output.csv')
df
# Out:
#          interaction_id                                           option_1  \
# 0   9151919416110000051                           Complain|ATM|Gagal Tarik
# 1   9151919416110000052           Complain|Credit Card|Sanggahan Transaksi
# 2   9151919416110000053             Complain|OCTO Mobile|Kendala Transaksi
# 3   9151919416110000054           Complain|Credit Card|Sanggahan Transaksi
# 4   9151919416110000055                 Complain|OCTO Mobile|Kendala Login
# 5   9151919416110000056                           Inquiry|Debit Card|Other
# 6   9151919416110000057                                  Inquiry|KPR|Other
# 7   9151919416110000058                          Inquiry|Credit Card|Limit
# 8   9151919416110000059  Complain|Credit Card|Pembayaran Tagihan Credit...
# 9   9151919416110000060                     Request|Credit Card|Annual Fee
# 10  9151919416110000061               Complain|Credit Card|Penutupan Kartu
# 11  9151919416110000062  Complain|Credit Card|Pembayaran Tagihan Credit...
# 12  9151919416110000063           Complain|Credit Card|Biaya/ Bunga/ Denda
# 13  9151919416110000064           Complain|Credit Card|Biaya/ Bunga/ Denda
# 14  9151919416110000065               Complain|KTA/ PL|Bunga/ Biaya/ Denda
# 15  9151919416110000066  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...
# 16  9151919416110000067           Complain|Credit Card|Biaya/ Bunga/ Denda
# 17  9151919416110000068                 Complain|KPR|Pelunasan Keseluruhan
# 18  9151919416110000069                          Inquiry|Credit Card|Limit
# 19  9151919416110000070               Inquiry|Credit Card|Aktivasi dan PIN
# 20  9151919416110000071                       Complain|Credit Card|Tagihan
# 21  9151919416110000072  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 22  9151919416110000073  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 23  9151919416110000074               Request|Credit Card|Credit Protector
# 24  9151919416110000075              Complain|Credit Card|Credit Protector
# 25  9151919416110000076                     Request|Credit Card|Pembatalan
# 26  9151919416110000077               Request|Credit Card|Credit Protector
# 27  9151919416110000078               Request|Credit Card|Reversal Payment
# 28  9151919416110000079  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 29  9151919416110000080  Complain|OCTO Mobile|Kendala Registrasi Perang...
# 30  9151919416110000081                     Complain|OCTO Mobile|Terblokir
# 31  9151919416110000082             Complain|OCTO Mobile|Kendala Transaksi
# 32  9151919416110000083             Complain|OCTO Mobile|Kendala Transaksi
# 33  9151919416110000084                     Complain|OCTO Clicks|Terblokir
# 34  9151919416110000085                       Complain|Credit Card|Tagihan
# 35  9151919416110000086                        Inquiry|Credit Card|Tagihan
# 36  9151919416110000087  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37  9151919416110000088           Complain|Credit Card|Biaya/ Bunga/ Denda
# 38  9151919416110000089                          Inquiry|Credit Card|Limit
# 39  9151919416110000093              Complain|Credit Card|Aktivasi dan PIN
# 40  9151919416110000094  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 41  9151919416110000095  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 42  9151919416110000096                      Inquiry|Credit Card|Cash Plus
# 43  9151919416110000097  Request|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 44  9151919416110000098                      Request|Credit Card|Pengajuan
# 45  9151919416110000099               Request|Credit Card|Aktivasi dan PIN
#
#                                         explanation_1  \
# 0   Penjelasan klasifikasi: Nasabah mengalami gaga...
# 1   Penjelasan klasifikasi: Nasabah melaporkan tra...
# 2   Penjelasan klasifikasi: Nasabah mengalami kend...
# 3   Penjelasan klasifikasi: Nasabah menanyakan tra...
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...
# 5   Penjelasan klasifikasi: Nasabah menanyakan det...
# 6   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 7   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 8   Penjelasan klasifikasi: Nasabah menanyakan sta...
# 9   Penjelasan klasifikasi: Nasabah meminta pengha...
# 10  Penjelasan klasifikasi: Nasabah komplain menge...
# 11  Penjelasan klasifikasi: Nasabah komplain pemba...
# 12  Penjelasan klasifikasi: Nasabah komplain menge...
# 13  Penjelasan klasifikasi: Nasabah komplain menge...
# 14  Penjelasan klasifikasi: Nasabah menanyakan det...
# 15  Penjelasan klasifikasi: Nasabah meminta kering...
# 16  Penjelasan klasifikasi: Nasabah mengeluhkan mi...
# 17  Penjelasan klasifikasi: Nasabah komplain menge...
# 18  Penjelasan klasifikasi: Nasabah menanyakan lim...
# 19  Penjelasan klasifikasi: Nasabah menanyakan car...
# 20  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 21  Penjelasan klasifikasi: Nasabah menanyakan est...
# 22  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 23  Penjelasan klasifikasi: Nasabah meminta pengha...
# 24  Penjelasan klasifikasi: Nasabah memprotes adan...
# 25  Penjelasan klasifikasi: Nasabah ingin membatal...
# 26  Penjelasan klasifikasi: Nasabah meminta pengha...
# 27  Penjelasan klasifikasi: Nasabah meminta pemind...
# 28  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 29  Penjelasan klasifikasi: Nasabah mengalami kend...
# 30  Penjelasan klasifikasi: Nasabah mengalami kend...
# 31  Penjelasan klasifikasi: Nasabah mengalami gaga...
# 32  Penjelasan klasifikasi: Nasabah mengalami gaga...
# 33  Penjelasan klasifikasi: Nasabah mengalami kend...
# 34  Penjelasan klasifikasi: Nasabah komplain menge...
# 35  Penjelasan klasifikasi: Nasabah menanyakan det...
# 36  Penjelasan klasifikasi: Nasabah komplain terka...
# 37  Penjelasan klasifikasi: Nasabah meminta penutu...
# 38  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 39  Penjelasan klasifikasi: Nasabah mengalami kend...
# 40  Penjelasan klasifikasi: Nasabah komplain menge...
# 41  Penjelasan klasifikasi: Nasabah komplain menge...
# 42  Penjelasan klasifikasi: Nasabah menanyakan kem...
# 43  Penjelasan klasifikasi: Nasabah ingin mengubah...
# 44  Penjelasan klasifikasi: Nasabah meminta pembua...
# 45  Penjelasan klasifikasi: Nasabah mengalami kend...
#
#                                              option_2  \
# 0                                                 NaN
# 1                Request|Credit Card|Pergantian Kartu
# 2                                                 NaN
# 3                                                 NaN
# 4            Complain|Credit Card|Sanggahan Transaksi
# 5                       Inquiry|OCTO Mobile|Transaksi
# 6                                                 NaN
# 7                           Inquiry|Credit Card|Other
# 8                          Complain|Credit Card|Limit
# 9                                                 NaN
# 10                       Complain|Credit Card|Tagihan
# 11                      Complain|Credit Card|Penipuan
# 12                                                NaN
# 13            Request|Credit Card|Biaya/ Bunga/ Denda
# 14     Inquiry|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 15                                                NaN
# 16                            Complain|Services|Other
# 17                                                NaN
# 18                     Inquiry|Credit Card|Annual Fee
# 19                          Inquiry|Credit Card|Fitur
# 20           Complain|Credit Card|Biaya/ Bunga/ Denda
# 21                                                NaN
# 22  Complain|Credit Card|Pembayaran Tagihan Credit...
# 23                                                NaN
# 24                     Request|Credit Card|Pembatalan
# 25                          Inquiry|Credit Card|Limit
# 26                                                NaN
# 27                    Complain|Credit Card|Annual Fee
# 28     Inquiry|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 29                     Complain|OCTO Mobile|Terblokir
# 30                 Inquiry|OCTO Pay|Kendala Transaksi
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 36  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37                Request|Credit Card|Penutupan Kartu
# 38     Request|Credit Card|Naik/ Turun Limit Permanen
# 39             Complain|Credit Card|Kendala Transaksi
# 40                                                NaN
# 41  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 42            Inquiry|Credit Card|Biaya/ Bunga/ Denda
# 43                                                NaN
# 44                                                NaN
# 45                          Inquiry|Credit Card|Other
#
#                                         explanation_2  \
# 0                                                 NaN
# 1   Penjelasan klasifikasi: Nasabah meminta pencet...
# 2                                                 NaN
# 3                                                 NaN
# 4   Penjelasan klasifikasi: Nasabah komplain sangg...
# 5   Penjelasan klasifikasi: Nasabah menanyakan per...
# 6                                                 NaN
# 7   Penjelasan klasifikasi: Nasabah ingin mengetah...
# 8   Penjelasan klasifikasi: Nasabah mengalami keti...
# 9                                                 NaN
# 10  Penjelasan klasifikasi: Nasabah komplain menge...
# 11  Penjelasan klasifikasi: Nasabah komplain dihub...
# 12                                                NaN
# 13  Penjelasan klasifikasi: Nasabah meminta pengha...
# 14  Penjelasan klasifikasi: Nasabah meminta penjel...
# 15                                                NaN
# 16  Penjelasan klasifikasi: Nasabah melaporkan gan...
# 17                                                NaN
# 18  Penjelasan klasifikasi: Nasabah menanyakan bia...
# 19  Penjelasan klasifikasi: Nasabah menanyakan per...
# 20  Penjelasan klasifikasi: Nasabah meminta penjel...
# 21                                                NaN
# 22  Penjelasan klasifikasi: Nasabah mengalami kend...
# 23                                                NaN
# 24  Penjelasan klasifikasi: Nasabah meminta pembat...
# 25  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 26                                                NaN
# 27  Penjelasan klasifikasi: Nasabah menanyakan ann...
# 28  Penjelasan klasifikasi: Nasabah meminta penjel...
# 29  Penjelasan klasifikasi: Aplikasi Octo Mobile n...
# 30  Penjelasan klasifikasi: Nasabah menanyakan car...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 36  Penjelasan klasifikasi: Agent meminta bantuan ...
# 37  Penjelasan klasifikasi: Nasabah mengajukan pen...
# 38  Penjelasan klasifikasi: Nasabah meminta kenaik...
# 39  Penjelasan klasifikasi: Nasabah mengalami kend...
# 40                                                NaN
# 41  Penjelasan klasifikasi: Nasabah meminta penjel...
# 42  Penjelasan klasifikasi: Nasabah ingin mengetah...
# 43                                                NaN
# 44                                                NaN
# 45  Penjelasan klasifikasi: Nasabah menanyakan pro...
#
#                                              option_3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4            Complain|Credit Card|Biaya/ Bunga/ Denda
# 5                           Request|OCTO Mobile|Other
# 6                                                 NaN
# 7                                                 NaN
# 8      Inquiry|Credit Card|Naik/ Turun Limit Permanen
# 9                                                 NaN
# 10                        Inquiry|Credit Card|Tagihan
# 11                 Request|Credit Card|Perubahan Data
# 12                                                NaN
# 13                          Request|Credit Card|Other
# 14                              Request|KTA/ PL|Other
# 15                                                NaN
# 16                        Inquiry|Credit Card|Tagihan
# 17                                                NaN
# 18                        Inquiry|Credit Card|Tagihan
# 19                          Inquiry|Credit Card|Promo
# 20                        Inquiry|Credit Card|Tagihan
# 21                                                NaN
# 22  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 23                                                NaN
# 24                                                NaN
# 25  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 26                                                NaN
# 27                                                NaN
# 28                     Request|Credit Card|Pembatalan
# 29                                                NaN
# 30                  Inquiry|OCTO Mobile|Pemulihan PIN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                      Inquiry|Credit Card|Poin Xtra
# 36                       Complain|Credit Card|Tagihan
# 37                                                NaN
# 38               Request|Credit Card|Redeem Cash Back
# 39                                Inquiry|Other|Other
# 40                                                NaN
# 41   Complain|Credit Card|Naik/ Turun Limit Sementara
# 42             Campaign/ Sales|Cash Plus|Sales Setuju
# 43                                                NaN
# 44                                                NaN
# 45                               Complain|Other|Other
#
#                                         explanation_3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Penjelasan klasifikasi: Nasabah dikenakan dend...
# 5   Penjelasan klasifikasi: Nasabah ingin menonakt...
# 6                                                 NaN
# 7                                                 NaN
# 8   Penjelasan klasifikasi: Nasabah meminta inform...
# 9                                                 NaN
# 10  Penjelasan klasifikasi: Nasabah meminta penjel...
# 11  Penjelasan klasifikasi: Nasabah meminta peruba...
# 12                                                NaN
# 13  Penjelasan klasifikasi: Nasabah meminta pembua...
# 14  Penjelasan klasifikasi: Nasabah meminta lapora...
# 15                                                NaN
# 16  Penjelasan klasifikasi: Nasabah menanyakan ala...
# 17                                                NaN
# 18  Penjelasan klasifikasi: Nasabah menanyakan jat...
# 19  Penjelasan klasifikasi: Nasabah menanyakan inf...
# 20  Penjelasan klasifikasi: Nasabah menanyakan per...
# 21                                                NaN
# 22  Penjelasan klasifikasi: Nasabah ingin memastik...
# 23                                                NaN
# 24                                                NaN
# 25  Penjelasan klasifikasi: Nasabah menanyakan met...
# 26                                                NaN
# 27                                                NaN
# 28  Penjelasan klasifikasi: Nasabah meminta pembat...
# 29                                                NaN
# 30  Penjelasan klasifikasi: Nasabah menanyakan bag...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Penjelasan klasifikasi: Nasabah menanyakan poi...
# 36  Penjelasan klasifikasi: Nasabah komplain tagih...
# 37                                                NaN
# 38  Penjelasan klasifikasi: Nasabah ingin menukark...
# 39  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 40                                                NaN
# 41  Penjelasan klasifikasi: Nasabah komplain karen...
# 42  Penjelasan klasifikasi: Nasabah akhirnya setuj...
# 43                                                NaN
# 44                                                NaN
# 45  Penjelasan klasifikasi: Nasabah mengalami kend...
#
#                                          ground_truth
# 0                            Complain|ATM|Gagal Tarik
# 1            Complain|Credit Card|Sanggahan Transaksi
# 2              Complain|OCTO Mobile|Kendala Transaksi
# 3            Complain|Credit Card|Sanggahan Transaksi
# 4                  Complain|OCTO Mobile|Kendala Login
# 5                              Inquiry|Tabungan|Other
# 6                                   Inquiry|KPR|Other
# 7                           Inquiry|Credit Card|Limit
# 8   Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 9                                                 NaN
# 10               Complain|Credit Card|Penutupan Kartu
# 11          Complain|Telesales|Penawaran Tidak Sesuai
# 12           Complain|Credit Card|Biaya/ Bunga/ Denda
# 13           Complain|Credit Card|Biaya/ Bunga/ Denda
# 14    Complain|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 15                 Complain|Collection|Cara Penagihan
# 16  Complain|Credit Card|Pembayaran Tagihan Credit...
# 17                 Complain|KPR|Pelunasan Keseluruhan
# 18                          Inquiry|Credit Card|Fitur
# 19                                                NaN
# 20           Complain|Credit Card|Biaya/ Bunga/ Denda
# 21  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 22  Complain|Credit Card|Pembayaran Tagihan Credit...
# 23              Complain|Credit Card|Credit Protector
# 24              Complain|Credit Card|Credit Protector
# 25               Request|Credit Card|Credit Protector
# 26                                                NaN
# 27               Request|Credit Card|Reversal Payment
# 28  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...
# 29                    Complain|OCTO Mobile|Registrasi
# 30                                                NaN
# 31             Complain|OCTO Mobile|Kendala Transaksi
# 32                 Complain|OCTO Clicks|Kendala Login
# 33             Complain|OCTO Clicks|Kendala Transaksi
# 34  Complain|Credit Card|Pembayaran Tagihan Credit...
# 35  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 36  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37                Request|Credit Card|Penutupan Kartu
# 38                            Request|Poin Xtra|Other
# 39              Complain|Credit Card|Aktivasi dan PIN
# 40                                                NaN
# 41                                                NaN
# 42  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 43                                                NaN
# 44                                                NaN
# 45  Request|Credit Card|Pendaftaran dan Pembatalan...

# %% [markdown]
# # CALCULATE ACCURACY

# %%
import pandas as pd

# check whether option_1 or option_2 or option_3 is equal to ground_truth, the result is True or False in "is_match" column
df['is_match'] = (df['ground_truth'] == df['option_1']) | (df['ground_truth'] == df['option_2']) | (df['ground_truth'] == df['option_3'])
df_view = df[['interaction_id', 'option_1', 'option_2', 'option_3', 'ground_truth', 'is_match']]
df_view
# Out:
#          interaction_id                                           option_1  \
# 0   9151919416110000051                           Complain|ATM|Gagal Tarik
# 1   9151919416110000052           Complain|Credit Card|Sanggahan Transaksi
# 2   9151919416110000053             Complain|OCTO Mobile|Kendala Transaksi
# 3   9151919416110000054           Complain|Credit Card|Sanggahan Transaksi
# 4   9151919416110000055                 Complain|OCTO Mobile|Kendala Login
# 5   9151919416110000056                           Inquiry|Debit Card|Other
# 6   9151919416110000057                                  Inquiry|KPR|Other
# 7   9151919416110000058                          Inquiry|Credit Card|Limit
# 8   9151919416110000059  Complain|Credit Card|Pembayaran Tagihan Credit...
# 9   9151919416110000060                     Request|Credit Card|Annual Fee
# 10  9151919416110000061               Complain|Credit Card|Penutupan Kartu
# 11  9151919416110000062  Complain|Credit Card|Pembayaran Tagihan Credit...
# 12  9151919416110000063           Complain|Credit Card|Biaya/ Bunga/ Denda
# 13  9151919416110000064           Complain|Credit Card|Biaya/ Bunga/ Denda
# 14  9151919416110000065               Complain|KTA/ PL|Bunga/ Biaya/ Denda
# 15  9151919416110000066  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...
# 16  9151919416110000067           Complain|Credit Card|Biaya/ Bunga/ Denda
# 17  9151919416110000068                 Complain|KPR|Pelunasan Keseluruhan
# 18  9151919416110000069                          Inquiry|Credit Card|Limit
# 19  9151919416110000070               Inquiry|Credit Card|Aktivasi dan PIN
# 20  9151919416110000071                       Complain|Credit Card|Tagihan
# 21  9151919416110000072  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 22  9151919416110000073  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 23  9151919416110000074               Request|Credit Card|Credit Protector
# 24  9151919416110000075              Complain|Credit Card|Credit Protector
# 25  9151919416110000076                     Request|Credit Card|Pembatalan
# 26  9151919416110000077               Request|Credit Card|Credit Protector
# 27  9151919416110000078               Request|Credit Card|Reversal Payment
# 28  9151919416110000079  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 29  9151919416110000080  Complain|OCTO Mobile|Kendala Registrasi Perang...
# 30  9151919416110000081                     Complain|OCTO Mobile|Terblokir
# 31  9151919416110000082             Complain|OCTO Mobile|Kendala Transaksi
# 32  9151919416110000083             Complain|OCTO Mobile|Kendala Transaksi
# 33  9151919416110000084                     Complain|OCTO Clicks|Terblokir
# 34  9151919416110000085                       Complain|Credit Card|Tagihan
# 35  9151919416110000086                        Inquiry|Credit Card|Tagihan
# 36  9151919416110000087  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37  9151919416110000088           Complain|Credit Card|Biaya/ Bunga/ Denda
# 38  9151919416110000089                          Inquiry|Credit Card|Limit
# 39  9151919416110000093              Complain|Credit Card|Aktivasi dan PIN
# 40  9151919416110000094  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 41  9151919416110000095  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 42  9151919416110000096                      Inquiry|Credit Card|Cash Plus
# 43  9151919416110000097  Request|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 44  9151919416110000098                      Request|Credit Card|Pengajuan
# 45  9151919416110000099               Request|Credit Card|Aktivasi dan PIN
#
#                                              option_2  \
# 0                                                 NaN
# 1                Request|Credit Card|Pergantian Kartu
# 2                                                 NaN
# 3                                                 NaN
# 4            Complain|Credit Card|Sanggahan Transaksi
# 5                       Inquiry|OCTO Mobile|Transaksi
# 6                                                 NaN
# 7                           Inquiry|Credit Card|Other
# 8                          Complain|Credit Card|Limit
# 9                                                 NaN
# 10                       Complain|Credit Card|Tagihan
# 11                      Complain|Credit Card|Penipuan
# 12                                                NaN
# 13            Request|Credit Card|Biaya/ Bunga/ Denda
# 14     Inquiry|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 15                                                NaN
# 16                            Complain|Services|Other
# 17                                                NaN
# 18                     Inquiry|Credit Card|Annual Fee
# 19                          Inquiry|Credit Card|Fitur
# 20           Complain|Credit Card|Biaya/ Bunga/ Denda
# 21                                                NaN
# 22  Complain|Credit Card|Pembayaran Tagihan Credit...
# 23                                                NaN
# 24                     Request|Credit Card|Pembatalan
# 25                          Inquiry|Credit Card|Limit
# 26                                                NaN
# 27                    Complain|Credit Card|Annual Fee
# 28     Inquiry|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 29                     Complain|OCTO Mobile|Terblokir
# 30                 Inquiry|OCTO Pay|Kendala Transaksi
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 36  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37                Request|Credit Card|Penutupan Kartu
# 38     Request|Credit Card|Naik/ Turun Limit Permanen
# 39             Complain|Credit Card|Kendala Transaksi
# 40                                                NaN
# 41  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 42            Inquiry|Credit Card|Biaya/ Bunga/ Denda
# 43                                                NaN
# 44                                                NaN
# 45                          Inquiry|Credit Card|Other
#
#                                              option_3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4            Complain|Credit Card|Biaya/ Bunga/ Denda
# 5                           Request|OCTO Mobile|Other
# 6                                                 NaN
# 7                                                 NaN
# 8      Inquiry|Credit Card|Naik/ Turun Limit Permanen
# 9                                                 NaN
# 10                        Inquiry|Credit Card|Tagihan
# 11                 Request|Credit Card|Perubahan Data
# 12                                                NaN
# 13                          Request|Credit Card|Other
# 14                              Request|KTA/ PL|Other
# 15                                                NaN
# 16                        Inquiry|Credit Card|Tagihan
# 17                                                NaN
# 18                        Inquiry|Credit Card|Tagihan
# 19                          Inquiry|Credit Card|Promo
# 20                        Inquiry|Credit Card|Tagihan
# 21                                                NaN
# 22  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 23                                                NaN
# 24                                                NaN
# 25  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 26                                                NaN
# 27                                                NaN
# 28                     Request|Credit Card|Pembatalan
# 29                                                NaN
# 30                  Inquiry|OCTO Mobile|Pemulihan PIN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                      Inquiry|Credit Card|Poin Xtra
# 36                       Complain|Credit Card|Tagihan
# 37                                                NaN
# 38               Request|Credit Card|Redeem Cash Back
# 39                                Inquiry|Other|Other
# 40                                                NaN
# 41   Complain|Credit Card|Naik/ Turun Limit Sementara
# 42             Campaign/ Sales|Cash Plus|Sales Setuju
# 43                                                NaN
# 44                                                NaN
# 45                               Complain|Other|Other
#
#                                          ground_truth  is_match
# 0                            Complain|ATM|Gagal Tarik      True
# 1            Complain|Credit Card|Sanggahan Transaksi      True
# 2              Complain|OCTO Mobile|Kendala Transaksi      True
# 3            Complain|Credit Card|Sanggahan Transaksi      True
# 4                  Complain|OCTO Mobile|Kendala Login      True
# 5                              Inquiry|Tabungan|Other     False
# 6                                   Inquiry|KPR|Other      True
# 7                           Inquiry|Credit Card|Limit      True
# 8   Inquiry|Credit Card|Pembayaran Tagihan Credit ...     False
# 9                                                 NaN     False
# 10               Complain|Credit Card|Penutupan Kartu      True
# 11          Complain|Telesales|Penawaran Tidak Sesuai     False
# 12           Complain|Credit Card|Biaya/ Bunga/ Denda      True
# 13           Complain|Credit Card|Biaya/ Bunga/ Denda      True
# 14    Complain|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)     False
# 15                 Complain|Collection|Cara Penagihan     False
# 16  Complain|Credit Card|Pembayaran Tagihan Credit...     False
# 17                 Complain|KPR|Pelunasan Keseluruhan      True
# 18                          Inquiry|Credit Card|Fitur     False
# 19                                                NaN     False
# 20           Complain|Credit Card|Biaya/ Bunga/ Denda      True
# 21  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...      True
# 22  Complain|Credit Card|Pembayaran Tagihan Credit...      True
# 23              Complain|Credit Card|Credit Protector     False
# 24              Complain|Credit Card|Credit Protector      True
# 25               Request|Credit Card|Credit Protector     False
# 26                                                NaN     False
# 27               Request|Credit Card|Reversal Payment      True
# 28  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...     False
# 29                    Complain|OCTO Mobile|Registrasi     False
# 30                                                NaN     False
# 31             Complain|OCTO Mobile|Kendala Transaksi      True
# 32                 Complain|OCTO Clicks|Kendala Login     False
# 33             Complain|OCTO Clicks|Kendala Transaksi     False
# 34  Complain|Credit Card|Pembayaran Tagihan Credit...     False
# 35  Complain|Credit Card|Tagihan (Tidak Terima/ Se...      True
# 36  Complain|Credit Card|Tagihan (Tidak Terima/ Se...      True
# 37                Request|Credit Card|Penutupan Kartu      True
# 38                            Request|Poin Xtra|Other     False
# 39              Complain|Credit Card|Aktivasi dan PIN      True
# 40                                                NaN     False
# 41                                                NaN     False
# 42  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...     False
# 43                                                NaN     False
# 44                                                NaN     False
# 45  Request|Credit Card|Pendaftaran dan Pembatalan...     False

# %%
# calculate the mean of "is_match" column where ground_truth is not NaN
accuracy = df[df['ground_truth'].notnull()]['is_match'].mean()
accuracy*100
# Out:
# np.float64(55.26315789473685)

# %%
# GET WHICH LAYER GET THE WRONG PREDICTION
def split_option(df, column_name):
    """Memisahkan kolom berdasarkan '|' dan membuat kolom baru."""
    df[column_name + '_layer_1'] = df[column_name].str.split('|').str[0]
    df[column_name + '_layer_2'] = df[column_name].str.split('|').str[1]
    df[column_name + '_layer_3'] = df[column_name].str.split('|').str[2]
    return df

df = split_option(df, 'option_1')
df = split_option(df, 'option_2')
df = split_option(df, 'option_3')
df = split_option(df, 'ground_truth')

# check if layer 1, layer 2, layer 3 match with ground_truth layer 1, layer 2, layer 3
df['is_match_layer_1'] = (df['ground_truth_layer_1'] == df['option_1_layer_1']) | (df['ground_truth_layer_1'] == df['option_2_layer_1']) | (df['ground_truth_layer_1'] == df['option_3_layer_1'])
df['is_match_layer_2'] = (df['ground_truth_layer_2'] == df['option_1_layer_2']) | (df['ground_truth_layer_2'] == df['option_2_layer_2']) | (df['ground_truth_layer_2'] == df['option_3_layer_2'])
df['is_match_layer_3'] = (df['ground_truth_layer_3'] == df['option_1_layer_3']) | (df['ground_truth_layer_3'] == df['option_2_layer_3']) | (df['ground_truth_layer_3'] == df['option_3_layer_3'])

# %%
df
# Out:
#          interaction_id                                           option_1  \
# 0   9151919416110000051                           Complain|ATM|Gagal Tarik
# 1   9151919416110000052           Complain|Credit Card|Sanggahan Transaksi
# 2   9151919416110000053             Complain|OCTO Mobile|Kendala Transaksi
# 3   9151919416110000054           Complain|Credit Card|Sanggahan Transaksi
# 4   9151919416110000055                 Complain|OCTO Mobile|Kendala Login
# 5   9151919416110000056                           Inquiry|Debit Card|Other
# 6   9151919416110000057                                  Inquiry|KPR|Other
# 7   9151919416110000058                          Inquiry|Credit Card|Limit
# 8   9151919416110000059  Complain|Credit Card|Pembayaran Tagihan Credit...
# 9   9151919416110000060                     Request|Credit Card|Annual Fee
# 10  9151919416110000061               Complain|Credit Card|Penutupan Kartu
# 11  9151919416110000062  Complain|Credit Card|Pembayaran Tagihan Credit...
# 12  9151919416110000063           Complain|Credit Card|Biaya/ Bunga/ Denda
# 13  9151919416110000064           Complain|Credit Card|Biaya/ Bunga/ Denda
# 14  9151919416110000065               Complain|KTA/ PL|Bunga/ Biaya/ Denda
# 15  9151919416110000066  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...
# 16  9151919416110000067           Complain|Credit Card|Biaya/ Bunga/ Denda
# 17  9151919416110000068                 Complain|KPR|Pelunasan Keseluruhan
# 18  9151919416110000069                          Inquiry|Credit Card|Limit
# 19  9151919416110000070               Inquiry|Credit Card|Aktivasi dan PIN
# 20  9151919416110000071                       Complain|Credit Card|Tagihan
# 21  9151919416110000072  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 22  9151919416110000073  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 23  9151919416110000074               Request|Credit Card|Credit Protector
# 24  9151919416110000075              Complain|Credit Card|Credit Protector
# 25  9151919416110000076                     Request|Credit Card|Pembatalan
# 26  9151919416110000077               Request|Credit Card|Credit Protector
# 27  9151919416110000078               Request|Credit Card|Reversal Payment
# 28  9151919416110000079  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 29  9151919416110000080  Complain|OCTO Mobile|Kendala Registrasi Perang...
# 30  9151919416110000081                     Complain|OCTO Mobile|Terblokir
# 31  9151919416110000082             Complain|OCTO Mobile|Kendala Transaksi
# 32  9151919416110000083             Complain|OCTO Mobile|Kendala Transaksi
# 33  9151919416110000084                     Complain|OCTO Clicks|Terblokir
# 34  9151919416110000085                       Complain|Credit Card|Tagihan
# 35  9151919416110000086                        Inquiry|Credit Card|Tagihan
# 36  9151919416110000087  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37  9151919416110000088           Complain|Credit Card|Biaya/ Bunga/ Denda
# 38  9151919416110000089                          Inquiry|Credit Card|Limit
# 39  9151919416110000093              Complain|Credit Card|Aktivasi dan PIN
# 40  9151919416110000094  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 41  9151919416110000095  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 42  9151919416110000096                      Inquiry|Credit Card|Cash Plus
# 43  9151919416110000097  Request|Credit Card|Cicilan (Bunga/ Jumlah/ Te...
# 44  9151919416110000098                      Request|Credit Card|Pengajuan
# 45  9151919416110000099               Request|Credit Card|Aktivasi dan PIN
#
#                                         explanation_1  \
# 0   Penjelasan klasifikasi: Nasabah mengalami gaga...
# 1   Penjelasan klasifikasi: Nasabah melaporkan tra...
# 2   Penjelasan klasifikasi: Nasabah mengalami kend...
# 3   Penjelasan klasifikasi: Nasabah menanyakan tra...
# 4   Penjelasan klasifikasi: Nasabah mengalami kend...
# 5   Penjelasan klasifikasi: Nasabah menanyakan det...
# 6   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 7   Penjelasan klasifikasi: Nasabah menanyakan sis...
# 8   Penjelasan klasifikasi: Nasabah menanyakan sta...
# 9   Penjelasan klasifikasi: Nasabah meminta pengha...
# 10  Penjelasan klasifikasi: Nasabah komplain menge...
# 11  Penjelasan klasifikasi: Nasabah komplain pemba...
# 12  Penjelasan klasifikasi: Nasabah komplain menge...
# 13  Penjelasan klasifikasi: Nasabah komplain menge...
# 14  Penjelasan klasifikasi: Nasabah menanyakan det...
# 15  Penjelasan klasifikasi: Nasabah meminta kering...
# 16  Penjelasan klasifikasi: Nasabah mengeluhkan mi...
# 17  Penjelasan klasifikasi: Nasabah komplain menge...
# 18  Penjelasan klasifikasi: Nasabah menanyakan lim...
# 19  Penjelasan klasifikasi: Nasabah menanyakan car...
# 20  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 21  Penjelasan klasifikasi: Nasabah menanyakan est...
# 22  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 23  Penjelasan klasifikasi: Nasabah meminta pengha...
# 24  Penjelasan klasifikasi: Nasabah memprotes adan...
# 25  Penjelasan klasifikasi: Nasabah ingin membatal...
# 26  Penjelasan klasifikasi: Nasabah meminta pengha...
# 27  Penjelasan klasifikasi: Nasabah meminta pemind...
# 28  Penjelasan klasifikasi: Nasabah menanyakan tag...
# 29  Penjelasan klasifikasi: Nasabah mengalami kend...
# 30  Penjelasan klasifikasi: Nasabah mengalami kend...
# 31  Penjelasan klasifikasi: Nasabah mengalami gaga...
# 32  Penjelasan klasifikasi: Nasabah mengalami gaga...
# 33  Penjelasan klasifikasi: Nasabah mengalami kend...
# 34  Penjelasan klasifikasi: Nasabah komplain menge...
# 35  Penjelasan klasifikasi: Nasabah menanyakan det...
# 36  Penjelasan klasifikasi: Nasabah komplain terka...
# 37  Penjelasan klasifikasi: Nasabah meminta penutu...
# 38  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 39  Penjelasan klasifikasi: Nasabah mengalami kend...
# 40  Penjelasan klasifikasi: Nasabah komplain menge...
# 41  Penjelasan klasifikasi: Nasabah komplain menge...
# 42  Penjelasan klasifikasi: Nasabah menanyakan kem...
# 43  Penjelasan klasifikasi: Nasabah ingin mengubah...
# 44  Penjelasan klasifikasi: Nasabah meminta pembua...
# 45  Penjelasan klasifikasi: Nasabah mengalami kend...
#
#                                              option_2  \
# 0                                                 NaN
# 1                Request|Credit Card|Pergantian Kartu
# 2                                                 NaN
# 3                                                 NaN
# 4            Complain|Credit Card|Sanggahan Transaksi
# 5                       Inquiry|OCTO Mobile|Transaksi
# 6                                                 NaN
# 7                           Inquiry|Credit Card|Other
# 8                          Complain|Credit Card|Limit
# 9                                                 NaN
# 10                       Complain|Credit Card|Tagihan
# 11                      Complain|Credit Card|Penipuan
# 12                                                NaN
# 13            Request|Credit Card|Biaya/ Bunga/ Denda
# 14     Inquiry|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 15                                                NaN
# 16                            Complain|Services|Other
# 17                                                NaN
# 18                     Inquiry|Credit Card|Annual Fee
# 19                          Inquiry|Credit Card|Fitur
# 20           Complain|Credit Card|Biaya/ Bunga/ Denda
# 21                                                NaN
# 22  Complain|Credit Card|Pembayaran Tagihan Credit...
# 23                                                NaN
# 24                     Request|Credit Card|Pembatalan
# 25                          Inquiry|Credit Card|Limit
# 26                                                NaN
# 27                    Complain|Credit Card|Annual Fee
# 28     Inquiry|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)
# 29                     Complain|OCTO Mobile|Terblokir
# 30                 Inquiry|OCTO Pay|Kendala Transaksi
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 36  Complain|Credit Card|Tagihan (Tidak Terima/ Se...
# 37                Request|Credit Card|Penutupan Kartu
# 38     Request|Credit Card|Naik/ Turun Limit Permanen
# 39             Complain|Credit Card|Kendala Transaksi
# 40                                                NaN
# 41  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 42            Inquiry|Credit Card|Biaya/ Bunga/ Denda
# 43                                                NaN
# 44                                                NaN
# 45                          Inquiry|Credit Card|Other
#
#                                         explanation_2  \
# 0                                                 NaN
# 1   Penjelasan klasifikasi: Nasabah meminta pencet...
# 2                                                 NaN
# 3                                                 NaN
# 4   Penjelasan klasifikasi: Nasabah komplain sangg...
# 5   Penjelasan klasifikasi: Nasabah menanyakan per...
# 6                                                 NaN
# 7   Penjelasan klasifikasi: Nasabah ingin mengetah...
# 8   Penjelasan klasifikasi: Nasabah mengalami keti...
# 9                                                 NaN
# 10  Penjelasan klasifikasi: Nasabah komplain menge...
# 11  Penjelasan klasifikasi: Nasabah komplain dihub...
# 12                                                NaN
# 13  Penjelasan klasifikasi: Nasabah meminta pengha...
# 14  Penjelasan klasifikasi: Nasabah meminta penjel...
# 15                                                NaN
# 16  Penjelasan klasifikasi: Nasabah melaporkan gan...
# 17                                                NaN
# 18  Penjelasan klasifikasi: Nasabah menanyakan bia...
# 19  Penjelasan klasifikasi: Nasabah menanyakan per...
# 20  Penjelasan klasifikasi: Nasabah meminta penjel...
# 21                                                NaN
# 22  Penjelasan klasifikasi: Nasabah mengalami kend...
# 23                                                NaN
# 24  Penjelasan klasifikasi: Nasabah meminta pembat...
# 25  Penjelasan klasifikasi: Nasabah menanyakan sis...
# 26                                                NaN
# 27  Penjelasan klasifikasi: Nasabah menanyakan ann...
# 28  Penjelasan klasifikasi: Nasabah meminta penjel...
# 29  Penjelasan klasifikasi: Aplikasi Octo Mobile n...
# 30  Penjelasan klasifikasi: Nasabah menanyakan car...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Penjelasan klasifikasi: Nasabah mempertanyakan...
# 36  Penjelasan klasifikasi: Agent meminta bantuan ...
# 37  Penjelasan klasifikasi: Nasabah mengajukan pen...
# 38  Penjelasan klasifikasi: Nasabah meminta kenaik...
# 39  Penjelasan klasifikasi: Nasabah mengalami kend...
# 40                                                NaN
# 41  Penjelasan klasifikasi: Nasabah meminta penjel...
# 42  Penjelasan klasifikasi: Nasabah ingin mengetah...
# 43                                                NaN
# 44                                                NaN
# 45  Penjelasan klasifikasi: Nasabah menanyakan pro...
#
#                                              option_3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4            Complain|Credit Card|Biaya/ Bunga/ Denda
# 5                           Request|OCTO Mobile|Other
# 6                                                 NaN
# 7                                                 NaN
# 8      Inquiry|Credit Card|Naik/ Turun Limit Permanen
# 9                                                 NaN
# 10                        Inquiry|Credit Card|Tagihan
# 11                 Request|Credit Card|Perubahan Data
# 12                                                NaN
# 13                          Request|Credit Card|Other
# 14                              Request|KTA/ PL|Other
# 15                                                NaN
# 16                        Inquiry|Credit Card|Tagihan
# 17                                                NaN
# 18                        Inquiry|Credit Card|Tagihan
# 19                          Inquiry|Credit Card|Promo
# 20                        Inquiry|Credit Card|Tagihan
# 21                                                NaN
# 22  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 23                                                NaN
# 24                                                NaN
# 25  Inquiry|Credit Card|Pembayaran Tagihan Credit ...
# 26                                                NaN
# 27                                                NaN
# 28                     Request|Credit Card|Pembatalan
# 29                                                NaN
# 30                  Inquiry|OCTO Mobile|Pemulihan PIN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                      Inquiry|Credit Card|Poin Xtra
# 36                       Complain|Credit Card|Tagihan
# 37                                                NaN
# 38               Request|Credit Card|Redeem Cash Back
# 39                                Inquiry|Other|Other
# 40                                                NaN
# 41   Complain|Credit Card|Naik/ Turun Limit Sementara
# 42             Campaign/ Sales|Cash Plus|Sales Setuju
# 43                                                NaN
# 44                                                NaN
# 45                               Complain|Other|Other
#
#                                         explanation_3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Penjelasan klasifikasi: Nasabah dikenakan dend...
# 5   Penjelasan klasifikasi: Nasabah ingin menonakt...
# 6                                                 NaN
# 7                                                 NaN
# 8   Penjelasan klasifikasi: Nasabah meminta inform...
# 9                                                 NaN
# 10  Penjelasan klasifikasi: Nasabah meminta penjel...
# 11  Penjelasan klasifikasi: Nasabah meminta peruba...
# 12                                                NaN
# 13  Penjelasan klasifikasi: Nasabah meminta pembua...
# 14  Penjelasan klasifikasi: Nasabah meminta lapora...
# 15                                                NaN
# 16  Penjelasan klasifikasi: Nasabah menanyakan ala...
# 17                                                NaN
# 18  Penjelasan klasifikasi: Nasabah menanyakan jat...
# 19  Penjelasan klasifikasi: Nasabah menanyakan inf...
# 20  Penjelasan klasifikasi: Nasabah menanyakan per...
# 21                                                NaN
# 22  Penjelasan klasifikasi: Nasabah ingin memastik...
# 23                                                NaN
# 24                                                NaN
# 25  Penjelasan klasifikasi: Nasabah menanyakan met...
# 26                                                NaN
# 27                                                NaN
# 28  Penjelasan klasifikasi: Nasabah meminta pembat...
# 29                                                NaN
# 30  Penjelasan klasifikasi: Nasabah menanyakan bag...
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Penjelasan klasifikasi: Nasabah menanyakan poi...
# 36  Penjelasan klasifikasi: Nasabah komplain tagih...
# 37                                                NaN
# 38  Penjelasan klasifikasi: Nasabah ingin menukark...
# 39  Penjelasan klasifikasi: Nasabah menanyakan sta...
# 40                                                NaN
# 41  Penjelasan klasifikasi: Nasabah komplain karen...
# 42  Penjelasan klasifikasi: Nasabah akhirnya setuj...
# 43                                                NaN
# 44                                                NaN
# 45  Penjelasan klasifikasi: Nasabah mengalami kend...
#
#                                          ground_truth  is_match  \
# 0                            Complain|ATM|Gagal Tarik      True
# 1            Complain|Credit Card|Sanggahan Transaksi      True
# 2              Complain|OCTO Mobile|Kendala Transaksi      True
# 3            Complain|Credit Card|Sanggahan Transaksi      True
# 4                  Complain|OCTO Mobile|Kendala Login      True
# 5                              Inquiry|Tabungan|Other     False
# 6                                   Inquiry|KPR|Other      True
# 7                           Inquiry|Credit Card|Limit      True
# 8   Inquiry|Credit Card|Pembayaran Tagihan Credit ...     False
# 9                                                 NaN     False
# 10               Complain|Credit Card|Penutupan Kartu      True
# 11          Complain|Telesales|Penawaran Tidak Sesuai     False
# 12           Complain|Credit Card|Biaya/ Bunga/ Denda      True
# 13           Complain|Credit Card|Biaya/ Bunga/ Denda      True
# 14    Complain|KTA/ PL|Cicilan (Bunga/ Jumlah/ Tenor)     False
# 15                 Complain|Collection|Cara Penagihan     False
# 16  Complain|Credit Card|Pembayaran Tagihan Credit...     False
# 17                 Complain|KPR|Pelunasan Keseluruhan      True
# 18                          Inquiry|Credit Card|Fitur     False
# 19                                                NaN     False
# 20           Complain|Credit Card|Biaya/ Bunga/ Denda      True
# 21  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...      True
# 22  Complain|Credit Card|Pembayaran Tagihan Credit...      True
# 23              Complain|Credit Card|Credit Protector     False
# 24              Complain|Credit Card|Credit Protector      True
# 25               Request|Credit Card|Credit Protector     False
# 26                                                NaN     False
# 27               Request|Credit Card|Reversal Payment      True
# 28  Complain|Credit Card|Cicilan (Bunga/ Jumlah/ T...     False
# 29                    Complain|OCTO Mobile|Registrasi     False
# 30                                                NaN     False
# 31             Complain|OCTO Mobile|Kendala Transaksi      True
# 32                 Complain|OCTO Clicks|Kendala Login     False
# 33             Complain|OCTO Clicks|Kendala Transaksi     False
# 34  Complain|Credit Card|Pembayaran Tagihan Credit...     False
# 35  Complain|Credit Card|Tagihan (Tidak Terima/ Se...      True
# 36  Complain|Credit Card|Tagihan (Tidak Terima/ Se...      True
# 37                Request|Credit Card|Penutupan Kartu      True
# 38                            Request|Poin Xtra|Other     False
# 39              Complain|Credit Card|Aktivasi dan PIN      True
# 40                                                NaN     False
# 41                                                NaN     False
# 42  Inquiry|Credit Card|Cicilan (Bunga/ Jumlah/ Te...     False
# 43                                                NaN     False
# 44                                                NaN     False
# 45  Request|Credit Card|Pendaftaran dan Pembatalan...     False
#
#    option_1_layer_1  ...                 option_2_layer_3 option_3_layer_1  \
# 0          Complain  ...                              NaN              NaN
# 1          Complain  ...                 Pergantian Kartu              NaN
# 2          Complain  ...                              NaN              NaN
# 3          Complain  ...                              NaN              NaN
# 4          Complain  ...              Sanggahan Transaksi         Complain
# 5           Inquiry  ...                        Transaksi          Request
# 6           Inquiry  ...                              NaN              NaN
# 7           Inquiry  ...                            Other              NaN
# 8          Complain  ...                            Limit          Inquiry
# 9           Request  ...                              NaN              NaN
# 10         Complain  ...                          Tagihan          Inquiry
# 11         Complain  ...                         Penipuan          Request
# 12         Complain  ...                              NaN              NaN
# 13         Complain  ...              Biaya/ Bunga/ Denda          Request
# 14         Complain  ...   Cicilan (Bunga/ Jumlah/ Tenor)          Request
# 15         Complain  ...                              NaN              NaN
# 16         Complain  ...                            Other          Inquiry
# 17         Complain  ...                              NaN              NaN
# 18          Inquiry  ...                       Annual Fee          Inquiry
# 19          Inquiry  ...                            Fitur          Inquiry
# 20         Complain  ...              Biaya/ Bunga/ Denda          Inquiry
# 21          Inquiry  ...                              NaN              NaN
# 22         Complain  ...   Pembayaran Tagihan Credit Card          Inquiry
# 23          Request  ...                              NaN              NaN
# 24         Complain  ...                       Pembatalan              NaN
# 25          Request  ...                            Limit          Inquiry
# 26          Request  ...                              NaN              NaN
# 27          Request  ...                       Annual Fee              NaN
# 28         Complain  ...   Cicilan (Bunga/ Jumlah/ Tenor)          Request
# 29         Complain  ...                        Terblokir              NaN
# 30         Complain  ...                Kendala Transaksi          Inquiry
# 31         Complain  ...                              NaN              NaN
# 32         Complain  ...                              NaN              NaN
# 33         Complain  ...                              NaN              NaN
# 34         Complain  ...                              NaN              NaN
# 35          Inquiry  ...  Tagihan (Tidak Terima/ Selisih)          Inquiry
# 36         Complain  ...  Tagihan (Tidak Terima/ Selisih)         Complain
# 37         Complain  ...                  Penutupan Kartu              NaN
# 38          Inquiry  ...       Naik/ Turun Limit Permanen          Request
# 39         Complain  ...                Kendala Transaksi          Inquiry
# 40         Complain  ...                              NaN              NaN
# 41         Complain  ...   Pembayaran Tagihan Credit Card         Complain
# 42          Inquiry  ...              Biaya/ Bunga/ Denda  Campaign/ Sales
# 43          Request  ...                              NaN              NaN
# 44          Request  ...                              NaN              NaN
# 45          Request  ...                            Other         Complain
#
#    option_3_layer_2                option_3_layer_3 ground_truth_layer_1  \
# 0               NaN                             NaN             Complain
# 1               NaN                             NaN             Complain
# 2               NaN                             NaN             Complain
# 3               NaN                             NaN             Complain
# 4       Credit Card             Biaya/ Bunga/ Denda             Complain
# 5       OCTO Mobile                           Other              Inquiry
# 6               NaN                             NaN              Inquiry
# 7               NaN                             NaN              Inquiry
# 8       Credit Card      Naik/ Turun Limit Permanen              Inquiry
# 9               NaN                             NaN                  NaN
# 10      Credit Card                         Tagihan             Complain
# 11      Credit Card                  Perubahan Data             Complain
# 12              NaN                             NaN             Complain
# 13      Credit Card                           Other             Complain
# 14          KTA/ PL                           Other             Complain
# 15              NaN                             NaN             Complain
# 16      Credit Card                         Tagihan             Complain
# 17              NaN                             NaN             Complain
# 18      Credit Card                         Tagihan              Inquiry
# 19      Credit Card                           Promo                  NaN
# 20      Credit Card                         Tagihan             Complain
# 21              NaN                             NaN              Inquiry
# 22      Credit Card  Pembayaran Tagihan Credit Card             Complain
# 23              NaN                             NaN             Complain
# 24              NaN                             NaN             Complain
# 25      Credit Card  Pembayaran Tagihan Credit Card              Request
# 26              NaN                             NaN                  NaN
# 27              NaN                             NaN              Request
# 28      Credit Card                      Pembatalan             Complain
# 29              NaN                             NaN             Complain
# 30      OCTO Mobile                   Pemulihan PIN                  NaN
# 31              NaN                             NaN             Complain
# 32              NaN                             NaN             Complain
# 33              NaN                             NaN             Complain
# 34              NaN                             NaN             Complain
# 35      Credit Card                       Poin Xtra             Complain
# 36      Credit Card                         Tagihan             Complain
# 37              NaN                             NaN              Request
# 38      Credit Card                Redeem Cash Back              Request
# 39            Other                           Other             Complain
# 40              NaN                             NaN                  NaN
# 41      Credit Card     Naik/ Turun Limit Sementara                  NaN
# 42        Cash Plus                    Sales Setuju              Inquiry
# 43              NaN                             NaN                  NaN
# 44              NaN                             NaN                  NaN
# 45            Other                           Other              Request
#
#    ground_truth_layer_2                    ground_truth_layer_3  \
# 0                   ATM                             Gagal Tarik
# 1           Credit Card                     Sanggahan Transaksi
# 2           OCTO Mobile                       Kendala Transaksi
# 3           Credit Card                     Sanggahan Transaksi
# 4           OCTO Mobile                           Kendala Login
# 5              Tabungan                                   Other
# 6                   KPR                                   Other
# 7           Credit Card                                   Limit
# 8           Credit Card          Pembayaran Tagihan Credit Card
# 9                   NaN                                     NaN
# 10          Credit Card                         Penutupan Kartu
# 11            Telesales                  Penawaran Tidak Sesuai
# 12          Credit Card                     Biaya/ Bunga/ Denda
# 13          Credit Card                     Biaya/ Bunga/ Denda
# 14              KTA/ PL          Cicilan (Bunga/ Jumlah/ Tenor)
# 15           Collection                          Cara Penagihan
# 16          Credit Card          Pembayaran Tagihan Credit Card
# 17                  KPR                   Pelunasan Keseluruhan
# 18          Credit Card                                   Fitur
# 19                  NaN                                     NaN
# 20          Credit Card                     Biaya/ Bunga/ Denda
# 21          Credit Card          Cicilan (Bunga/ Jumlah/ Tenor)
# 22          Credit Card          Pembayaran Tagihan Credit Card
# 23          Credit Card                        Credit Protector
# 24          Credit Card                        Credit Protector
# 25          Credit Card                        Credit Protector
# 26                  NaN                                     NaN
# 27          Credit Card                        Reversal Payment
# 28          Credit Card          Cicilan (Bunga/ Jumlah/ Tenor)
# 29          OCTO Mobile                              Registrasi
# 30                  NaN                                     NaN
# 31          OCTO Mobile                       Kendala Transaksi
# 32          OCTO Clicks                           Kendala Login
# 33          OCTO Clicks                       Kendala Transaksi
# 34          Credit Card          Pembayaran Tagihan Credit Card
# 35          Credit Card         Tagihan (Tidak Terima/ Selisih)
# 36          Credit Card         Tagihan (Tidak Terima/ Selisih)
# 37          Credit Card                         Penutupan Kartu
# 38            Poin Xtra                                   Other
# 39          Credit Card                        Aktivasi dan PIN
# 40                  NaN                                     NaN
# 41                  NaN                                     NaN
# 42          Credit Card          Cicilan (Bunga/ Jumlah/ Tenor)
# 43                  NaN                                     NaN
# 44                  NaN                                     NaN
# 45          Credit Card  Pendaftaran dan Pembatalan E-Statement
#
#    is_match_layer_1 is_match_layer_2 is_match_layer_3
# 0              True             True             True
# 1              True             True             True
# 2              True             True             True
# 3              True             True             True
# 4              True             True             True
# 5              True            False             True
# 6              True             True             True
# 7              True             True             True
# 8              True             True             True
# 9             False            False            False
# 10             True             True             True
# 11             True            False            False
# 12             True             True             True
# 13             True             True             True
# 14             True             True             True
# 15             True            False            False
# 16             True             True            False
# 17             True             True             True
# 18             True             True            False
# 19            False            False            False
# 20             True             True             True
# 21             True             True             True
# 22             True             True             True
# 23            False             True             True
# 24             True             True             True
# 25             True             True            False
# 26            False            False            False
# 27             True             True             True
# 28             True             True             True
# 29             True             True            False
# 30            False            False            False
# 31             True             True             True
# 32             True            False            False
# 33             True             True            False
# 34             True             True            False
# 35             True             True             True
# 36             True             True             True
# 37             True             True             True
# 38             True            False            False
# 39             True             True             True
# 40            False            False            False
# 41            False            False            False
# 42             True             True            False
# 43            False            False            False
# 44            False            False            False
# 45             True             True            False
#
# [46 rows x 24 columns]

# %%
accuracy_layer_1 = df[df['ground_truth_layer_1'].notnull()]['is_match_layer_1'].mean()
print(f"Layer 1 accuracy: {accuracy_layer_1}")
# show df for layer 1
# df[['interaction_id', 'option_1_layer_1','option_2_layer_1','option_3_layer_1', 'ground_truth_layer_1', 'is_match_layer_1']]
df[['interaction_id', 'option_1_layer_1', 'ground_truth_layer_1', 'is_match_layer_1']]
# Out:
# Layer 1 accuracy: 0.9736842105263158
#          interaction_id option_1_layer_1 ground_truth_layer_1  \
# 0   9151919416110000051         Complain             Complain
# 1   9151919416110000052         Complain             Complain
# 2   9151919416110000053         Complain             Complain
# 3   9151919416110000054         Complain             Complain
# 4   9151919416110000055         Complain             Complain
# 5   9151919416110000056          Inquiry              Inquiry
# 6   9151919416110000057          Inquiry              Inquiry
# 7   9151919416110000058          Inquiry              Inquiry
# 8   9151919416110000059         Complain              Inquiry
# 9   9151919416110000060          Request                  NaN
# 10  9151919416110000061         Complain             Complain
# 11  9151919416110000062         Complain             Complain
# 12  9151919416110000063         Complain             Complain
# 13  9151919416110000064         Complain             Complain
# 14  9151919416110000065         Complain             Complain
# 15  9151919416110000066         Complain             Complain
# 16  9151919416110000067         Complain             Complain
# 17  9151919416110000068         Complain             Complain
# 18  9151919416110000069          Inquiry              Inquiry
# 19  9151919416110000070          Inquiry                  NaN
# 20  9151919416110000071         Complain             Complain
# 21  9151919416110000072          Inquiry              Inquiry
# 22  9151919416110000073         Complain             Complain
# 23  9151919416110000074          Request             Complain
# 24  9151919416110000075         Complain             Complain
# 25  9151919416110000076          Request              Request
# 26  9151919416110000077          Request                  NaN
# 27  9151919416110000078          Request              Request
# 28  9151919416110000079         Complain             Complain
# 29  9151919416110000080         Complain             Complain
# 30  9151919416110000081         Complain                  NaN
# 31  9151919416110000082         Complain             Complain
# 32  9151919416110000083         Complain             Complain
# 33  9151919416110000084         Complain             Complain
# 34  9151919416110000085         Complain             Complain
# 35  9151919416110000086          Inquiry             Complain
# 36  9151919416110000087         Complain             Complain
# 37  9151919416110000088         Complain              Request
# 38  9151919416110000089          Inquiry              Request
# 39  9151919416110000093         Complain             Complain
# 40  9151919416110000094         Complain                  NaN
# 41  9151919416110000095         Complain                  NaN
# 42  9151919416110000096          Inquiry              Inquiry
# 43  9151919416110000097          Request                  NaN
# 44  9151919416110000098          Request                  NaN
# 45  9151919416110000099          Request              Request
#
#     is_match_layer_1
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9              False
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19             False
# 20              True
# 21              True
# 22              True
# 23             False
# 24              True
# 25              True
# 26             False
# 27              True
# 28              True
# 29              True
# 30             False
# 31              True
# 32              True
# 33              True
# 34              True
# 35              True
# 36              True
# 37              True
# 38              True
# 39              True
# 40             False
# 41             False
# 42              True
# 43             False
# 44             False
# 45              True

# %%
accuracy_layer_2 = df[df['ground_truth_layer_2'].notnull()]['is_match_layer_2'].mean()
print(f"Layer 2 accuracy: {accuracy_layer_2}")
df[['interaction_id','option_1_layer_2','option_2_layer_2','option_3_layer_2', 'ground_truth_layer_2', 'is_match_layer_2']]
# Out:
# Layer 2 accuracy: 0.868421052631579
#          interaction_id option_1_layer_2 option_2_layer_2 option_3_layer_2  \
# 0   9151919416110000051              ATM              NaN              NaN
# 1   9151919416110000052      Credit Card      Credit Card              NaN
# 2   9151919416110000053      OCTO Mobile              NaN              NaN
# 3   9151919416110000054      Credit Card              NaN              NaN
# 4   9151919416110000055      OCTO Mobile      Credit Card      Credit Card
# 5   9151919416110000056       Debit Card      OCTO Mobile      OCTO Mobile
# 6   9151919416110000057              KPR              NaN              NaN
# 7   9151919416110000058      Credit Card      Credit Card              NaN
# 8   9151919416110000059      Credit Card      Credit Card      Credit Card
# 9   9151919416110000060      Credit Card              NaN              NaN
# 10  9151919416110000061      Credit Card      Credit Card      Credit Card
# 11  9151919416110000062      Credit Card      Credit Card      Credit Card
# 12  9151919416110000063      Credit Card              NaN              NaN
# 13  9151919416110000064      Credit Card      Credit Card      Credit Card
# 14  9151919416110000065          KTA/ PL          KTA/ PL          KTA/ PL
# 15  9151919416110000066      Credit Card              NaN              NaN
# 16  9151919416110000067      Credit Card         Services      Credit Card
# 17  9151919416110000068              KPR              NaN              NaN
# 18  9151919416110000069      Credit Card      Credit Card      Credit Card
# 19  9151919416110000070      Credit Card      Credit Card      Credit Card
# 20  9151919416110000071      Credit Card      Credit Card      Credit Card
# 21  9151919416110000072      Credit Card              NaN              NaN
# 22  9151919416110000073      Credit Card      Credit Card      Credit Card
# 23  9151919416110000074      Credit Card              NaN              NaN
# 24  9151919416110000075      Credit Card      Credit Card              NaN
# 25  9151919416110000076      Credit Card      Credit Card      Credit Card
# 26  9151919416110000077      Credit Card              NaN              NaN
# 27  9151919416110000078      Credit Card      Credit Card              NaN
# 28  9151919416110000079      Credit Card          KTA/ PL      Credit Card
# 29  9151919416110000080      OCTO Mobile      OCTO Mobile              NaN
# 30  9151919416110000081      OCTO Mobile         OCTO Pay      OCTO Mobile
# 31  9151919416110000082      OCTO Mobile              NaN              NaN
# 32  9151919416110000083      OCTO Mobile              NaN              NaN
# 33  9151919416110000084      OCTO Clicks              NaN              NaN
# 34  9151919416110000085      Credit Card              NaN              NaN
# 35  9151919416110000086      Credit Card      Credit Card      Credit Card
# 36  9151919416110000087      Credit Card      Credit Card      Credit Card
# 37  9151919416110000088      Credit Card      Credit Card              NaN
# 38  9151919416110000089      Credit Card      Credit Card      Credit Card
# 39  9151919416110000093      Credit Card      Credit Card            Other
# 40  9151919416110000094      Credit Card              NaN              NaN
# 41  9151919416110000095      Credit Card      Credit Card      Credit Card
# 42  9151919416110000096      Credit Card      Credit Card        Cash Plus
# 43  9151919416110000097      Credit Card              NaN              NaN
# 44  9151919416110000098      Credit Card              NaN              NaN
# 45  9151919416110000099      Credit Card      Credit Card            Other
#
#    ground_truth_layer_2  is_match_layer_2
# 0                   ATM              True
# 1           Credit Card              True
# 2           OCTO Mobile              True
# 3           Credit Card              True
# 4           OCTO Mobile              True
# 5              Tabungan             False
# 6                   KPR              True
# 7           Credit Card              True
# 8           Credit Card              True
# 9                   NaN             False
# 10          Credit Card              True
# 11            Telesales             False
# 12          Credit Card              True
# 13          Credit Card              True
# 14              KTA/ PL              True
# 15           Collection             False
# 16          Credit Card              True
# 17                  KPR              True
# 18          Credit Card              True
# 19                  NaN             False
# 20          Credit Card              True
# 21          Credit Card              True
# 22          Credit Card              True
# 23          Credit Card              True
# 24          Credit Card              True
# 25          Credit Card              True
# 26                  NaN             False
# 27          Credit Card              True
# 28          Credit Card              True
# 29          OCTO Mobile              True
# 30                  NaN             False
# 31          OCTO Mobile              True
# 32          OCTO Clicks             False
# 33          OCTO Clicks              True
# 34          Credit Card              True
# 35          Credit Card              True
# 36          Credit Card              True
# 37          Credit Card              True
# 38            Poin Xtra             False
# 39          Credit Card              True
# 40                  NaN             False
# 41                  NaN             False
# 42          Credit Card              True
# 43                  NaN             False
# 44                  NaN             False
# 45          Credit Card              True

# %%
accuracy_layer_3 = df[df['ground_truth_layer_3'].notnull()]['is_match_layer_3'].mean()
print(f"Layer 3 accuracy: {accuracy_layer_3}")
df[['interaction_id','option_1_layer_3','option_2_layer_3','option_3_layer_3', 'ground_truth_layer_3', 'is_match_layer_3']]
# Out:
# Layer 3 accuracy: 0.6842105263157895
#          interaction_id                   option_1_layer_3  \
# 0   9151919416110000051                        Gagal Tarik
# 1   9151919416110000052                Sanggahan Transaksi
# 2   9151919416110000053                  Kendala Transaksi
# 3   9151919416110000054                Sanggahan Transaksi
# 4   9151919416110000055                      Kendala Login
# 5   9151919416110000056                              Other
# 6   9151919416110000057                              Other
# 7   9151919416110000058                              Limit
# 8   9151919416110000059     Pembayaran Tagihan Credit Card
# 9   9151919416110000060                         Annual Fee
# 10  9151919416110000061                    Penutupan Kartu
# 11  9151919416110000062     Pembayaran Tagihan Credit Card
# 12  9151919416110000063                Biaya/ Bunga/ Denda
# 13  9151919416110000064                Biaya/ Bunga/ Denda
# 14  9151919416110000065                Bunga/ Biaya/ Denda
# 15  9151919416110000066     Cicilan (Bunga/ Jumlah/ Tenor)
# 16  9151919416110000067                Biaya/ Bunga/ Denda
# 17  9151919416110000068              Pelunasan Keseluruhan
# 18  9151919416110000069                              Limit
# 19  9151919416110000070                   Aktivasi dan PIN
# 20  9151919416110000071                            Tagihan
# 21  9151919416110000072     Cicilan (Bunga/ Jumlah/ Tenor)
# 22  9151919416110000073    Tagihan (Tidak Terima/ Selisih)
# 23  9151919416110000074                   Credit Protector
# 24  9151919416110000075                   Credit Protector
# 25  9151919416110000076                         Pembatalan
# 26  9151919416110000077                   Credit Protector
# 27  9151919416110000078                   Reversal Payment
# 28  9151919416110000079    Tagihan (Tidak Terima/ Selisih)
# 29  9151919416110000080  Kendala Registrasi Perangkat Baru
# 30  9151919416110000081                          Terblokir
# 31  9151919416110000082                  Kendala Transaksi
# 32  9151919416110000083                  Kendala Transaksi
# 33  9151919416110000084                          Terblokir
# 34  9151919416110000085                            Tagihan
# 35  9151919416110000086                            Tagihan
# 36  9151919416110000087    Tagihan (Tidak Terima/ Selisih)
# 37  9151919416110000088                Biaya/ Bunga/ Denda
# 38  9151919416110000089                              Limit
# 39  9151919416110000093                   Aktivasi dan PIN
# 40  9151919416110000094    Tagihan (Tidak Terima/ Selisih)
# 41  9151919416110000095    Tagihan (Tidak Terima/ Selisih)
# 42  9151919416110000096                          Cash Plus
# 43  9151919416110000097     Cicilan (Bunga/ Jumlah/ Tenor)
# 44  9151919416110000098                          Pengajuan
# 45  9151919416110000099                   Aktivasi dan PIN
#
#                    option_2_layer_3                option_3_layer_3  \
# 0                               NaN                             NaN
# 1                  Pergantian Kartu                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4               Sanggahan Transaksi             Biaya/ Bunga/ Denda
# 5                         Transaksi                           Other
# 6                               NaN                             NaN
# 7                             Other                             NaN
# 8                             Limit      Naik/ Turun Limit Permanen
# 9                               NaN                             NaN
# 10                          Tagihan                         Tagihan
# 11                         Penipuan                  Perubahan Data
# 12                              NaN                             NaN
# 13              Biaya/ Bunga/ Denda                           Other
# 14   Cicilan (Bunga/ Jumlah/ Tenor)                           Other
# 15                              NaN                             NaN
# 16                            Other                         Tagihan
# 17                              NaN                             NaN
# 18                       Annual Fee                         Tagihan
# 19                            Fitur                           Promo
# 20              Biaya/ Bunga/ Denda                         Tagihan
# 21                              NaN                             NaN
# 22   Pembayaran Tagihan Credit Card  Pembayaran Tagihan Credit Card
# 23                              NaN                             NaN
# 24                       Pembatalan                             NaN
# 25                            Limit  Pembayaran Tagihan Credit Card
# 26                              NaN                             NaN
# 27                       Annual Fee                             NaN
# 28   Cicilan (Bunga/ Jumlah/ Tenor)                      Pembatalan
# 29                        Terblokir                             NaN
# 30                Kendala Transaksi                   Pemulihan PIN
# 31                              NaN                             NaN
# 32                              NaN                             NaN
# 33                              NaN                             NaN
# 34                              NaN                             NaN
# 35  Tagihan (Tidak Terima/ Selisih)                       Poin Xtra
# 36  Tagihan (Tidak Terima/ Selisih)                         Tagihan
# 37                  Penutupan Kartu                             NaN
# 38       Naik/ Turun Limit Permanen                Redeem Cash Back
# 39                Kendala Transaksi                           Other
# 40                              NaN                             NaN
# 41   Pembayaran Tagihan Credit Card     Naik/ Turun Limit Sementara
# 42              Biaya/ Bunga/ Denda                    Sales Setuju
# 43                              NaN                             NaN
# 44                              NaN                             NaN
# 45                            Other                           Other
#
#                       ground_truth_layer_3  is_match_layer_3
# 0                              Gagal Tarik              True
# 1                      Sanggahan Transaksi              True
# 2                        Kendala Transaksi              True
# 3                      Sanggahan Transaksi              True
# 4                            Kendala Login              True
# 5                                    Other              True
# 6                                    Other              True
# 7                                    Limit              True
# 8           Pembayaran Tagihan Credit Card              True
# 9                                      NaN             False
# 10                         Penutupan Kartu              True
# 11                  Penawaran Tidak Sesuai             False
# 12                     Biaya/ Bunga/ Denda              True
# 13                     Biaya/ Bunga/ Denda              True
# 14          Cicilan (Bunga/ Jumlah/ Tenor)              True
# 15                          Cara Penagihan             False
# 16          Pembayaran Tagihan Credit Card             False
# 17                   Pelunasan Keseluruhan              True
# 18                                   Fitur             False
# 19                                     NaN             False
# 20                     Biaya/ Bunga/ Denda              True
# 21          Cicilan (Bunga/ Jumlah/ Tenor)              True
# 22          Pembayaran Tagihan Credit Card              True
# 23                        Credit Protector              True
# 24                        Credit Protector              True
# 25                        Credit Protector             False
# 26                                     NaN             False
# 27                        Reversal Payment              True
# 28          Cicilan (Bunga/ Jumlah/ Tenor)              True
# 29                              Registrasi             False
# 30                                     NaN             False
# 31                       Kendala Transaksi              True
# 32                           Kendala Login             False
# 33                       Kendala Transaksi             False
# 34          Pembayaran Tagihan Credit Card             False
# 35         Tagihan (Tidak Terima/ Selisih)              True
# 36         Tagihan (Tidak Terima/ Selisih)              True
# 37                         Penutupan Kartu              True
# 38                                   Other             False
# 39                        Aktivasi dan PIN              True
# 40                                     NaN             False
# 41                                     NaN             False
# 42          Cicilan (Bunga/ Jumlah/ Tenor)             False
# 43                                     NaN             False
# 44                                     NaN             False
# 45  Pendaftaran dan Pembatalan E-Statement             False
