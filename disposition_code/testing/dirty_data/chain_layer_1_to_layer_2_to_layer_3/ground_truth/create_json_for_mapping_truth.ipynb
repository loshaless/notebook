# %%
import pandas as pd

# import the data from excell with sheet name 'ground_truth'
ground_truth = pd.read_excel('Disposition Code Testing.xlsx', sheet_name='ground_truth')
view_ground_truth = ground_truth[['interaction_id_edit', 'GroundTruth']]
view_ground_truth
# Out:
#      interaction_id_edit                                        GroundTruth
# 0   9151919416110000051'  Complain (General Customer)|Branchless|BLB: AT...
# 1   9151919416110000052'  Complain (General Customer)|Credit Card|CRD: C...
# 2   9151919416110000053'  Complain (General Customer)|Branchless|BLB: OC...
# 3   9151919416110000054'  Complain (General Customer)|Credit Card|CRD: C...
# 4   9151919416110000055'  Complain (General Customer)|Branchless|BLB: OC...
# 5   9151919416110000056'  Inquiry (General Customer)|Funding (FND)|FND: ...
# 6   9151919416110000057'  Inquiry (General Customer)|Lending|LND: KPR Ot...
# 7   9151919416110000058'  Inquiry (General Customer)|Credit Card|CRD: Cr...
# 8   9151919416110000059'  Inquiry (General Customer)|Credit Card|CRD: Pe...
# 9   9151919416110000060'  Feedback/Report (General Customer)|Credit Card...
# 10  9151919416110000061'  Complain (General Customer)|Credit Card|CRD: C...
# 11  9151919416110000062'  Complain (General Customer)|Other|OTH: Telesal...
# 12  9151919416110000063'  Complain (General Customer)|Credit Card|CRD: B...
# 13  9151919416110000064'  Complain (General Customer)|Credit Card|CRD: B...
# 14  9151919416110000065'  Complain (General Customer)|Lending|LND: KTA/P...
# 15  9151919416110000066'  Complain (General Customer)|Other|OTH:Collecti...
# 16  9151919416110000067'  Complain (General Customer)|Credit Card|CRD: P...
# 17  9151919416110000068'  Complain (General Customer)|Lending|LND: KPR P...
# 18  9151919416110000069'  Inquiry (General Customer)|Credit Card|CRD: Cr...
# 19  9151919416110000070'                                                NaN
# 20  9151919416110000071'  Complain (General Customer)|Credit Card|CRD: B...
# 21  9151919416110000072'  Inquiry (General Customer)|Credit Card|CRD: Ci...
# 22  9151919416110000073'  Complain (General Customer)|Credit Card|CRD: P...
# 23  9151919416110000074'  Complain (General Customer)|Credit Card|CRD: C...
# 24  9151919416110000075'  Complain (General Customer)|Credit Card|CRD: C...
# 25  9151919416110000076'  Request (General Customer)|Credit Card|CRD: Cr...
# 26  9151919416110000078'  Request (General Customer)|Credit Card|CRD: Cr...
# 27  9151919416110000079'  Complain (General Customer)|Credit Card|CRD: C...
# 28  9151919416110000080'  Complain (General Customer)|Branchless|BLB: OC...
# 29  9151919416110000081'                                                NaN
# 30  9151919416110000082'  Complain (General Customer)|Branchless|BLB: OC...
# 31  9151919416110000083'  Complain (General Customer)|Branchless|BLB: OC...
# 32  9151919416110000084'  Complain (General Customer)|Branchless|BLB: OC...
# 33  9151919416110000085'  Complain (General Customer)|Credit Card|CRD: P...
# 34  9151919416110000086'  Complain (General Customer)|Credit Card|CRD: T...
# 35  9151919416110000087'  Complain (General Customer)|Credit Card|CRD: T...
# 36  9151919416110000088'  Request (General Customer)|Credit Card|CRD: Cr...
# 37  9151919416110000089'  Request (General Customer)|Others|OTH: Poin Xt...
# 38  9151919416110000090'  Request (General Customer)|Credit Card|CRD: Cr...
# 39  9151919416110000091'  Complain (General Customer)|Credit Card|CRD: C...
# 40  9151919416110000092'  Complain (General Customer)|Credit Card|CRD: C...
# 41  9151919416110000093'  Complain (General Customer)|Credit Card|CRD: A...
# 42  9151919416110000094'                                                NaN
# 43  9151919416110000095'                                                NaN
# 44  9151919416110000096'  Inquiry (General Customer)|Credit Card|CRD: Ci...
# 45  9151919416110000097'  Request (General Customer)|Credit Card|CRD: Cr...
# 46  9151919416110000098'  Request (General Customer)|Credit Card|CRD: Cr...
# 47  9151919416110000099'  Request (General Customer)|Credit Card|CRD: Cr...
# 48  9151919416110000100'  Complain (General Customer)|Branchless |BLB: O...

# %% [markdown]
# # CREATE GROUND TRUTH JSON FILE

# %%
import json

# filter df, to only show interaction_id_edit and GroundTruth columns
ground_truth = ground_truth[['interaction_id_edit', 'GroundTruth']]
# create a json with the interaction_id_edit as key and GroundTruth as value
ground_truth = ground_truth.set_index('interaction_id_edit').to_dict()['GroundTruth']
# remove all last char from they key
ground_truth = {k[:-1]: v for k, v in ground_truth.items()}

# export this to json file, please add new line for better view
with open('ground_truth.json', 'w') as f:
    json.dump(ground_truth, f, indent=4)

# %% [markdown]
# # TEST JSON FILE

# %%
# load json file
with open('ground_truth.json', 'r') as f:
    data = json.load(f)

data
# Out:
# {'9151919416110000051': 'Complain (General Customer)|Branchless|BLB: ATM Gagal Tarik',
#  '9151919416110000052': 'Complain (General Customer)|Credit Card|CRD: Credit Cards Sanggahan Transaksi',
#  '9151919416110000053': 'Complain (General Customer)|Branchless|BLB: OCTO Mobile Kendala Transaksi',
#  '9151919416110000054': 'Complain (General Customer)|Credit Card|CRD: Credit Cards Sanggahan Transaksi',
#  '9151919416110000055': 'Complain (General Customer)|Branchless|BLB: OCTO Mobile Kendala Login',
#  '9151919416110000056': 'Inquiry (General Customer)|Funding (FND)|FND: Tabungan Others',
#  '9151919416110000057': 'Inquiry (General Customer)|Lending|LND: KPR Others',
#  '9151919416110000058': 'Inquiry (General Customer)|Credit Card|CRD: Credit Cards Limit',
#  '9151919416110000059': 'Inquiry (General Customer)|Credit Card|CRD: Pembayaran Tagihan Kartu Kredit',
#  '9151919416110000060': 'Feedback/Report (General Customer)|Credit Card|CRD: Credit Cards',
#  '9151919416110000061': 'Complain (General Customer)|Credit Card|CRD: Credit Cards Penutupan Kartu',
#  '9151919416110000062': 'Complain (General Customer)|Other|OTH: Telesales Penawaran Tidak Sesuai',
#  '9151919416110000063': 'Complain (General Customer)|Credit Card|CRD: Biaya/ Bunga/ Denda',
#  '9151919416110000064': 'Complain (General Customer)|Credit Card|CRD: Biaya/ Bunga/ Denda',
#  '9151919416110000065': 'Complain (General Customer)|Lending|LND: KTA/PL Cicilan (Bunga/ Jumlah/ Tenor)',
#  '9151919416110000066': 'Complain (General Customer)|Other|OTH:Collection Cara Penagihan',
#  '9151919416110000067': 'Complain (General Customer)|Credit Card|CRD: Pembayaran Tagihan Kartu Kredit',
#  '9151919416110000068': 'Complain (General Customer)|Lending|LND: KPR Pelunasan Keseluruhan',
#  '9151919416110000069': 'Inquiry (General Customer)|Credit Card|CRD: Credit Cards Fitur',
#  '9151919416110000070': nan,
#  '9151919416110000071': 'Complain (General Customer)|Credit Card|CRD: Biaya/ Bunga/ Denda',
#  '9151919416110000072': 'Inquiry (General Customer)|Credit Card|CRD: Cicilan (Bunga/ Jumlah/ Tenor)',
#  '9151919416110000073': 'Complain (General Customer)|Credit Card|CRD: Pembayaran Tagihan Kartu Kredit',
#  '9151919416110000074': 'Complain (General Customer)|Credit Card|CRD: Credit Protector',
#  '9151919416110000075': 'Complain (General Customer)|Credit Card|CRD: Credit Protector',
#  '9151919416110000076': 'Request (General Customer)|Credit Card|CRD: Credit Protector',
#  '9151919416110000078': 'Request (General Customer)|Credit Card|CRD: Credit Cards Reversal Payment',
#  '9151919416110000079': 'Complain (General Customer)|Credit Card|CRD: Cicilan (Bunga/ Jumlah/ Tenor)',
#  '9151919416110000080': 'Complain (General Customer)|Branchless|BLB: OCTO Mobile Registrasi',
#  '9151919416110000081': nan,
#  '9151919416110000082': 'Complain (General Customer)|Branchless|BLB: OCTO Mobile Kendala Transaksi',
#  '9151919416110000083': 'Complain (General Customer)|Branchless|BLB: OCTO Clicks Kendala Login',
#  '9151919416110000084': 'Complain (General Customer)|Branchless|BLB: OCTO Clicks Kendala Transaksi',
#  '9151919416110000085': 'Complain (General Customer)|Credit Card|CRD: Pembayaran Tagihan Kartu Kredit',
#  '9151919416110000086': 'Complain (General Customer)|Credit Card|CRD: Tagihan (Belum Terima/ Selisih)',
#  '9151919416110000087': 'Complain (General Customer)|Credit Card|CRD: Tagihan (Belum Terima/ Selisih)',
#  '9151919416110000088': 'Request (General Customer)|Credit Card|CRD: Credit Cards Penutupan',
#  '9151919416110000089': 'Request (General Customer)|Others|OTH: Poin Xtra Others',
#  '9151919416110000090': 'Request (General Customer)|Credit Card|CRD: Credit Cards Blokir/Buka Blokir',
#  '9151919416110000091': 'Complain (General Customer)|Credit Card|CRD: Credit Cards Tagihan',
#  '9151919416110000092': 'Complain (General Customer)|Credit Card|CRD: Credit Cards Kirim Ulang Kartu',
#  '9151919416110000093': 'Complain (General Customer)|Credit Card|CRD: Aktivasi dan PIN',
#  '9151919416110000094': nan,
#  '9151919416110000095': nan,
#  '9151919416110000096': 'Inquiry (General Customer)|Credit Card|CRD: Cicilan (Bunga/ Jumlah/ Tenor)',
#  '9151919416110000097': 'Request (General Customer)|Credit Card|CRD: Credit Cards',
#  '9151919416110000098': 'Request (General Customer)|Credit Card|CRD: Credit Cards',
#  '9151919416110000099': 'Request (General Customer)|Credit Card|CRD: Credit Cards Pendaftaran dan Pembatalan E-Statement',
#  '9151919416110000100': 'Complain (General Customer)|Branchless |BLB: OCTO Mobile Others '}
