# %%
import pandas as pd
import os
import dotenv
import numpy as np

dotenv.load_dotenv()
BASE_DIR = os.getcwd()

# %% [markdown]
# # Import excel

# %%
excel_path = "disposition_code_ref_table.xlsx"

df = pd.read_excel(os.path.join(BASE_DIR, excel_path))
df.drop(columns=["Konkatenasi_Layer123"], inplace=True)

# %% [markdown]
# # Define functions

# %%
def split_layer3to2(layer2_name:str, layer3_product_list:list, layer2_prefix:str="", layer2_postfix:str=""):
    for product in layer3_product_list:
        df["Layer 2"] = np.where(
                (df["Layer 2"] == layer2_name) &
                ((df["Layer 3"].str.startswith(product)) |
                 (df["Layer 3"].str.endswith(product))),
            layer2_prefix   + product + layer2_postfix,
            df["Layer 2"])
        df["Layer 3"] = np.where(
                (df["Layer 2"] == 
                layer2_prefix + product + layer2_postfix) &
                ((df["Layer 3"].str.startswith(product)) |
                 (df["Layer 3"].str.endswith(product))),
            df["Layer 3"].str.split(product).str[1],
            df["Layer 3"])
    strip_all()

def split_layer2to3(layer2_product_list:list, layer2_name:str, layer3_prefix:str="", layer3_postfix:str=""):
    for product in layer2_product_list:
        df["Layer 3"] = np.where(
                (df["Layer 2"] == product),
            layer3_prefix + product + layer3_postfix + df["Layer 3"],
            df["Layer 3"])
        df["Layer 2"] = np.where(
                (df["Layer 2"] == product),
            layer2_name,
            df["Layer 2"])
    strip_all()

def swap_layers(layer_name_1:str, layer_name_2:str, layer_name_1_contain:str="", layer_name_2_contain:str=""):
    df[layer_name_1], df[layer_name_2] = np.where(
        (df[layer_name_1].str.contains(layer_name_1_contain) &
         df[layer_name_2].str.contains(layer_name_2_contain)),
            df[layer_name_2],
            df[layer_name_1]), np.where(
        (df[layer_name_1].str.contains(layer_name_1_contain) &
         df[layer_name_2].str.contains(layer_name_2_contain)),
            df[layer_name_1],
            df[layer_name_2])

def strip_all():
    df["Layer 1"] = df["Layer 1"].str.strip()
    df["Layer 2"] = df["Layer 2"].str.strip()
    df["Layer 3"] = df["Layer 3"].str.strip()

    df.fillna(" ", inplace=True)

def group_label(layer:str, list_of_labels:list[str], result_label:str):
    strip_all()
    for label in list_of_labels:
        df.loc[df[layer].str.contains(label), layer] = result_label
    strip_all()

def remove_prefix(layer, suffix):
    df.loc[df[layer].str.startswith(suffix), layer] = df[layer].str.split(suffix).str[1].str.strip()

def remove_postfix(layer, suffix):
    df.loc[df[layer].str.endswith(suffix), layer] = df[layer].str.split(suffix).str[0].str.strip()
    # print(df[layer].str.split(suffix).str[0].str.strip())

# %%
def add_stage(stage):
    strstage = str(stage)
    df[["Stage "+strstage+" - Layer 1", "Stage "+strstage+" - Layer 2", "Stage "+strstage+" - Layer 3"]] = df[["Layer 1", "Layer 2", "Layer 3"]]

# %%
stage = 0
add_stage(stage)

# %% [markdown]
# Stage 1: Standardizing terms

# %%
# 
# 
# 
# Replace Synonyms, Typo
# print(df["Stage 0 - Layer 1"].value_counts())
df.loc[df["Layer 1"].str.contains("General Customer"), "Layer 1"] = df["Layer 1"].str.split(regex=r" (General Customer)").str[0]
strip_all()
# print(df["Layer 1"].value_counts())
df.replace({"Credit Cards": "Credit Card",
            "Kartu Kredit": "Credit Card",
            "Credit Card Suppl": "Credit Card Supplementary",
            "Kartu Debit": "Debit Card",
            "Watsapp": "Whatsapp",
            "Octo": "OCTO",
            "Transaksi  1500800": "Transaksi 1500800",
            "Pembesihan": "Pembersihan",
            r" /": "/",
            r"/ ": "/",
            r"/": "/ ",
            "Sevices": "Services",
            "Top UP": "Top Up",
            "Others": "Other",
            "E-mandate": "E-Mandate",
            "Belum Terima": "Tidak Terima",
            "Belum Menerima": "Tidak Terima",
            "Tidak Menerima": "Tidak Terima",
            "Vending Other": "Vending Machine Other",
            "CNY": "Customer Preferred Valas Chinese Yuan",
            "CP Blast": "Customer Preferred Blast",
            "CP Staff": "Customer Preferred Staff",
            "CPVALAS": "Customer Preferred Valas",
            "CPDORMANT": "Customer Preferred Dormant",
            "Done Contact Center Dok KTP Supplement": "Contact Center Dok KTP Supplement",
            "Done Telesales Dok KTP Supplement": "Telesales Dok KTP Supplement",
            # "KPR": "Kredit Pemilikan Rumah",
            # "KPM": "Kredit Pemilikan Mobil",
            "XKB ": "XKB: ",
            # "KTA": "Kredit Tanpa Agunan",
            # "PL": "Personal Loan",
            # "CDM": "CDM (Cash Deposit Machine)",
            # "CRM": "CRM (Cash Recycling Machine)",
            # "EDC": "EDC (Electronic Data Capture)",
            # "CNAF": "CNAF (CIMB Niaga Auto Finance)",
            # "KTA": "KTA (Kredit Tanpa Agunan)",
            # "ARO": "ARO (Automatic Roll Over)",
            # "PCL": "PCL (Permanent Credit Limit)",
            # "TCL": "TCL (Temporary Credit Limit)",
            # "POH": "POH (Pembantu Operasional Harian)",
            # "SPV": "SPV (Supervisor)",
            # "CC": "CC (Credit Card)",
            # "SLIK": "SLIK (Sistem Layanan Informasi Keuangan)",
            # "DSE": "DSE (Digital Sales Enablement)",
            },regex=True, inplace=True)
# print(df["Layer 1"].value_counts())

strip_all()
df.loc[df["Layer 3"].str.contains(": "), "Layer 3"] = df["Layer 3"].str.split(": ").str[1]
strip_all()
# print(df["Layer 1"].value_counts())
# print(df["Stage 1 - Layer 1"].value_counts())

# %%
stage+=1
add_stage(stage)

# %% [markdown]
# Stage 2: Split Layer 2 using Layer 3 prefixes

# %%
branchless_products = ["ATM/ CDM/ CRM",
                           "ATM",
                           "CDM",
                           "CRM",
                           "Kartu Debit",
                           "Debit Card",
                           "OCTO Clicks",
                           "OCTO Mobile",
                           "OCTO Pay",
                           "QRIS",
                           "Rekpon",
                           ]
split_layer3to2('Branchless', branchless_products)
# , "Branchless: ")

# %%
services_products = ["Biz Channel OCTO Merchant",
                     "Biz Channel",
                     "Social Media",
                     "Website",
                     "Contact Center",
                     "Whatsapp",
                     "Digital Lounge",
                     "Phone Banking",
                     "E-mail",
                     "EDC",
                     "Branch",
                     "Live Chat",
                     "Preferred",
                     "Chatbot",
                     "Transaksi 1500800",
                     "Vending Machine",
                     "Telesales",
                     "Restrukturisasi Kredit",
                     "Poin Xtra",
                     "Collection",
                     "Beasiswa",
                     "Asuransi",
                     ]
split_layer3to2('Services', services_products)
# , "Services: ")

# %%
lending_products = ["KTA/ PL",
                    "KPR",
                    "KPM",
                    "Refinancing (Multi Guna)",
                    "Xtra Kasbon",
                    ]
split_layer3to2('Lending', lending_products)
# , "Lending: ")

# %%
funding_products = ["Tabungan",
                    "Giro",
                    "Deposito",
                    "Obligasi",
                    "Reksa Dana",
                    ]
split_layer3to2('Funding', funding_products)
# , "Funding: ")

# %%
preferred_products = ["Poin Xtra",
                      "Customer Preferred Valas",
                      "Personal Credit Line (PCL)",
                      "PVI (Program Green Lane)",
                      ]
split_layer3to2('Program Preferred Blast', preferred_products)
#, "Preferred: ")

# %%
other_products = ["Poin Xtra",
                  "Asuransi",
                  "Vending Machine",
                  "Collection",
                  "Beasiswa",
                  "Telesales",
                  "Restrukturisasi Kredit",
                  ]
split_layer3to2('Other', other_products)

# %%
# split_layer3to2('Telesales Dok KTP Supplement', ["Telesales"])
# split_layer3to2('Done Telesales Dok KTP Supplement', ["Telesales Done"])
# split_layer3to2('Done Contact Center Dok KTP Supplement', ["Done Contact Center"])
# split_layer3to2('Contact Center Dok KTP Supplement', ["Contact Center"])
remove_postfix("Layer 3", "Contact Center")
remove_postfix("Layer 3", "Telesales")

# %%
stage+=1
add_stage(stage)

# %% [markdown]
# Stage 3: Credit Card

# %%
remove_prefix("Layer 3", "Credit Card")

# %%
credit_card_products = [
        "Credit Card",
        "Credit Card Aktivasi Accor Platinum",
        "Credit Card Aktivasi Accor World",
        "Credit Card Basic",
        "Credit Card General",
        "Credit Card Inactive & Dormant",
        "Credit Card Stickiness CPROT",
        "Credit Card Stickiness Non-Activated",
        "Credit Card Supplementary",
        "Credit Card Tendency Card",
    ]
split_layer2to3(credit_card_products, "Credit Card", "[", "] ")

# %%
stage+=1
add_stage(stage)

# %% [markdown]
# Stage 4: Feedback/Report and Report Status Checking -> Report Status

# %%
df.loc[df["Layer 1"] == "Report Status Checking", "Layer 3"] = "Status Open"
df.loc[df["Layer 1"] == "Feedback/ Report", "Layer 3"] = "Status Closed"
df.loc[df["Layer 1"] == "Report Status Checking", "Layer 1"] = "Report Status"
df.loc[df["Layer 1"] == "Feedback/ Report", "Layer 1"] = "Report Status"

# %%
stage+=1
add_stage(stage)

# %% [markdown]
# Stage 5: Grouping Labels

# %%
# 
# 
# 
# Grouping Layer 1, Typo
group_label("Layer 1", ["Spam", "Ongoing", "Miscellaneous", "Test"], "Other")
group_label("Layer 1", ["Sales", "Campaign"], "Campaign/ Sales")

# %%
# 
# 
# 
# Grouping Layer 3, Typo
group_label("Layer 3", ["Promo/ Voucher", "Promo/ Voucher/milliage", "Promo/ Voucher/ Milliage", "Promo/ Voucher/Milliage"], "Promo/ Voucher/ Mileage")
group_label("Layer 3", ["Prank Call/ Spam Call/ Bogus Call"], "Spam")
group_label("Layer 3", ["Penerbitan", "Penggantian"], "Penerbitan/ Penggantian")

# %%
stage+=1
add_stage(stage)

# %% [markdown]
# Stage 6: Swapping Layers

# %%
swap_layers(layer_name_1="Layer 2",layer_name_2="Layer 3",layer_name_1_contain="Other")
swap_layers(layer_name_1="Layer 2",layer_name_2="Layer 3",layer_name_1_contain="Salah Nama",layer_name_2_contain="Other")
swap_layers(layer_name_1="Layer 2",layer_name_2="Layer 3",layer_name_1_contain="Test",layer_name_2_contain="Other")
swap_layers(layer_name_1="Layer 2",layer_name_2="Layer 3",layer_name_1_contain="Chat lanjutan",layer_name_2_contain="Other")
swap_layers(layer_name_1="Layer 2",layer_name_2="Layer 3",layer_name_1_contain="Info belum lengkap",layer_name_2_contain="Other")
swap_layers(layer_name_1="Layer 2",layer_name_2="Layer 3",layer_name_2_contain="OCTO ")
swap_layers(layer_name_1="Layer 2",layer_name_2="Layer 3",layer_name_1_contain="Whatsapp")
swap_layers(layer_name_1="Layer 2",layer_name_2="Layer 3",layer_name_1_contain="Blast")

# %%
stage+=1
add_stage(stage)

# %% [markdown]
# Stage 7: Targeted Cleaning

# %%
# remove_prefix("Layer 3", "Sales")
# remove_prefix("Layer 3", "XKB")

# remove_prefix("Layer 2", "Done Contact Center")
# remove_prefix("Layer 2", "Done Telesales")

# PCL = Personal Credit Line

# %%
df.loc[(df["Layer 1"] == "Other") & (df["Layer 2"] == "Salah layanan"), "Layer 2"] = "Other"
df.loc[(df["Layer 1"] == "Other") & (df["Layer 2"] == "Spam"), "Layer 2"] = "Other"    
df.loc[df["Layer 3"] == "No", "Layer 3"] = "Tidak Setuju"
df.loc[df["Layer 2"] == "Contact", "Layer 2"] = "Contact Center"

# %%
stage+=1
add_stage(stage)

# %% [markdown]
# Stage 8: Cleaning Empty Data

# %%
strip_all()
df.loc[df["Layer 1"] == "", "Layer 1"] = None
df.loc[df["Layer 2"] == "", "Layer 2"] = None
df.loc[df["Layer 3"] == "", "Layer 3"] = None
df.fillna("Other", inplace=True)
df.drop_duplicates(inplace=True)
# df.sort_values(by=["Layer 1","Layer 2","Layer 3"],inplace=True)
# print(df.size//3)

# %%
stage+=1
add_stage(stage)

# %%
# print(df["Layer 1"].unique().size)
# print(df["Layer 2"].unique().size)
# print(df["Layer 3"].unique().size)
# print(df["Layer 1"].value_counts())
# print(df["Layer 2"].value_counts())
# print(df["Layer 3"].value_counts())

# print("Layer 1 - Layer 2")
# print(df[["Layer 1", "Layer 2"]].value_counts().size)
# print(df[["Layer 1", "Layer 2"]].value_counts())

# print("Layer 2 - Layer 3")
# print(df[["Layer 2", "Layer 3"]].value_counts().size)
# print(df[["Layer 2", "Layer 3"]].value_counts())

# print("Layer 1 - Layer 3")
# print(df[["Layer 1", "Layer 3"]].value_counts().size)
# print(df[["Layer 1", "Layer 3"]].value_counts())

# %% [markdown]
# Display

# %%
df[["Layer 1", "Layer 2", "Layer 3"]].value_counts().size
# Out:
# 1145

# %%
# df.to_csv("C:\\Users\\CX16230X\\Documents\\Projects\\ATHENA\\disposition-code\\disp.csv")

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# 369        Compliment                             Branch
# 370        Compliment                     Contact Center
# 371        Compliment                     Contact Center
# 372        Compliment                     Digital Lounge
# 373        Compliment                                EDC
# 374        Compliment                             E-mail
# 375        Compliment                          Live Chat
# 376        Compliment                       Social Media
# 377        Compliment                            Website
# 378        Compliment                              Other
# 379     Report Status                      ATM/ CDM/ CRM
# 380     Report Status                         Debit Card
# 381     Report Status                        OCTO Clicks
# 382     Report Status                        OCTO Mobile
# 383     Report Status                               QRIS
# 384     Report Status                             Rekpon
# 385     Report Status                        Credit Card
# 386     Report Status                           Deposito
# 387     Report Status                               Giro
# 388     Report Status                           Tabungan
# 389     Report Status                                KPM
# 390     Report Status                                KPR
# 391     Report Status                            KTA/ PL
# 392     Report Status                           Asuransi
# 393     Report Status                           Beasiswa
# 394     Report Status                         Collection
# 395     Report Status                          Poin Xtra
# 396     Report Status             Restrukturisasi Kredit
# 397     Report Status                          Telesales
# 398     Report Status                    Vending Machine
# 399     Report Status                        Biz Channel
# 400     Report Status                             Branch
# 401     Report Status                     Digital Lounge
# 402     Report Status                                EDC
# 403     Report Status                      Phone Banking
# 404     Report Status                       Social Media
# 405     Report Status                            Website
# 406           Inquiry                                ATM
# 407           Inquiry                                ATM
# 408           Inquiry                      ATM/ CDM/ CRM
# 409           Inquiry                      ATM/ CDM/ CRM
# 410           Inquiry                      ATM/ CDM/ CRM
# 411           Inquiry                                CDM
# 412           Inquiry                                CRM
# 413           Inquiry                         Debit Card
# 414           Inquiry                         Debit Card
# 415           Inquiry                         Debit Card
# 416           Inquiry                         Debit Card
# 417           Inquiry                         Debit Card
# 418           Inquiry                         Debit Card
# 419           Inquiry                        OCTO Clicks
# 420           Inquiry                        OCTO Clicks
# 421           Inquiry                        OCTO Clicks
# 422           Inquiry                        OCTO Clicks
# 423           Inquiry                        OCTO Clicks
# 424           Inquiry                        OCTO Clicks
# 425           Inquiry                        OCTO Clicks
# 426           Inquiry                        OCTO Clicks
# 427           Inquiry                        OCTO Clicks
# 428           Inquiry                        OCTO Clicks
# 429           Inquiry                        OCTO Clicks
# 430           Inquiry                        OCTO Mobile
# 431           Inquiry                        OCTO Mobile
# 432           Inquiry                        OCTO Mobile
# 433           Inquiry                        OCTO Mobile
# 434           Inquiry                        OCTO Mobile
# 435           Inquiry                        OCTO Mobile
# 436           Inquiry                        OCTO Mobile
# 437           Inquiry                        OCTO Mobile
# 438           Inquiry                        OCTO Mobile
# 439           Inquiry                        OCTO Mobile
# 440           Inquiry                        OCTO Mobile
# 441           Inquiry                        OCTO Mobile
# 442           Inquiry                        OCTO Mobile
# 443           Inquiry                           OCTO Pay
# 444           Inquiry                           OCTO Pay
# 445           Inquiry                           OCTO Pay
# 446           Inquiry                           OCTO Pay
# 447           Inquiry                           OCTO Pay
# 448           Inquiry                           OCTO Pay
# 449           Inquiry                           OCTO Pay
# 450           Inquiry                           OCTO Pay
# 451           Inquiry                           OCTO Pay
# 541           Inquiry                                KPM
# 542           Inquiry                                KPM
# 543           Inquiry                                KPM
# 544           Inquiry                                KPR
# 545           Inquiry                                KPR
# 546           Inquiry                                KPR
# 547           Inquiry                                KPR
# 548           Inquiry                                KPR
# 549           Inquiry                                KPR
# 550           Inquiry                                KPR
# 551           Inquiry                                KPR
# 552           Inquiry                                KPR
# 553           Inquiry                            KTA/ PL
# 554           Inquiry                            KTA/ PL
# 555           Inquiry                            KTA/ PL
# 556           Inquiry                            KTA/ PL
# 557           Inquiry                            KTA/ PL
# 558           Inquiry                            KTA/ PL
# 559           Inquiry                            KTA/ PL
# 560           Inquiry                            KTA/ PL
# 561           Inquiry                            KTA/ PL
# 562           Inquiry                            KTA/ PL
# 563           Inquiry                            KTA/ PL
# 564           Inquiry           Refinancing (Multi Guna)
# 565           Inquiry           Refinancing (Multi Guna)
# 566           Inquiry                        Xtra Kasbon
# 567           Inquiry                           Asuransi
# 568           Inquiry                           Asuransi
# 569           Inquiry                           Asuransi
# 570           Inquiry                           Asuransi
# 571           Inquiry                           Asuransi
# 572           Inquiry                           Asuransi
# 573           Inquiry                           Beasiswa
# 574           Inquiry                         Collection
# 575           Inquiry                         Collection
# 576           Inquiry                          Poin Xtra
# 577           Inquiry                          Poin Xtra
# 578           Inquiry                          Poin Xtra
# 579           Inquiry                          Poin Xtra
# 580           Inquiry                          Poin Xtra
# 581           Inquiry                          Poin Xtra
# 582           Inquiry             Restrukturisasi Kredit
# 583           Inquiry             Restrukturisasi Kredit
# 584           Inquiry             Restrukturisasi Kredit
# 585           Inquiry             Restrukturisasi Kredit
# 586           Inquiry                          Telesales
# 587           Inquiry                          Telesales
# 588           Inquiry                          Telesales
# 589           Inquiry                          Telesales
# 590           Inquiry                    Vending Machine
# 591           Inquiry                    Vending Machine
# 592           Inquiry                    Vending Machine
# 593           Inquiry                           Services
# 594           Inquiry                        Biz Channel
# 595           Inquiry                        Biz Channel
# 596           Inquiry          Biz Channel OCTO Merchant
# 597           Inquiry          Biz Channel OCTO Merchant
# 598           Inquiry          Biz Channel OCTO Merchant
# 599           Inquiry                        Biz Channel
# 600           Inquiry                        Biz Channel
# 601           Inquiry                        Biz Channel
# 602           Inquiry                             Branch
# 603           Inquiry                             Branch
# 604           Inquiry                             Branch
# 605           Inquiry                             Branch
# 606           Inquiry                             Branch
# 607           Inquiry                            Chatbot
# 608           Inquiry                     Digital Lounge
# 609           Inquiry                     Digital Lounge
# 610           Inquiry                     Digital Lounge
# 611           Inquiry                     Digital Lounge
# 612           Inquiry                                EDC
# 613           Inquiry                                EDC
# 614           Inquiry                                EDC
# 615           Inquiry                                EDC
# 616           Inquiry                             E-mail
# 617           Inquiry                             E-mail
# 618           Inquiry                             E-mail
# 619           Inquiry                          Live Chat
# 620           Inquiry                          Live Chat
# 621           Inquiry                          Live Chat
# 622           Inquiry                           Services
# 623           Inquiry                      Phone Banking
# 624           Inquiry                      Phone Banking
# 625           Inquiry                      Phone Banking
# 626           Inquiry                          Preferred
# 627           Inquiry                          Preferred
# 628           Inquiry                       Social Media
# 629           Inquiry                       Social Media
# 630           Inquiry                  Transaksi 1500800
# 631           Inquiry                            Website
# 632           Inquiry                            Website
# 633           Inquiry                            Website
# 634           Inquiry                           Whatsapp
# 635           Inquiry                    Cakupan Layanan
# 636           Inquiry                          Interaksi
# 637           Inquiry                              Other
# 638           Inquiry                Aktivasi CC by Bank
# 639           Inquiry                      Card Delivery
# 640           Inquiry                         Collection
# 641           Inquiry                              Other
# 642           Inquiry                                PCL
# 643           Inquiry                    Pengkinian Data
# 644           Inquiry                              Promo
# 645           Inquiry                                TCL
# 646           Inquiry                Aktivasi CC by Bank
# 647           Inquiry                      Card Delivery
# 648           Inquiry                         Collection
# 649           Inquiry                              Other
# 650           Inquiry                                PCL
# 651           Inquiry                    Pengkinian Data
# 652           Inquiry                              Promo
# 653           Inquiry                                TCL
# 654           Inquiry                Aktivasi CC by Bank
# 655           Inquiry                      Card Delivery
# 656           Inquiry                         Collection
# 657           Inquiry                              Other
# 658           Inquiry                                PCL
# 659           Inquiry                    Pengkinian Data
# 660           Inquiry                              Promo
# 661           Inquiry                                TCL
# 662           Inquiry           PVI (Program Green Lane)
# 663           Inquiry         Personal Credit Line (PCL)
# 664           Inquiry                           Birthday
# 665           Inquiry                   Goal Savers Gift
# 666           Inquiry         Top Up Preferred (CPTOPUP)
# 667           Inquiry           New To Invest/ Insurance
# 668           Inquiry                       Program TGIF
# 669           Inquiry           Customer Preferred Valas
# 670           Inquiry           WM (Reksadana/ Obligasi)
# 671           Inquiry                            UPGRADE
# 672           Inquiry                         UPGRADENTB
# 673           Inquiry                               CNAF
# 674           Inquiry                             GSCUAN
# 675           Inquiry                              NTPCS
# 676           Inquiry         CATHAYTOPUP/ CATHAYUPGRADE
# 677           Inquiry               Fall Below Fee (FBF)
# 678           Inquiry                          MLDREKPON
# 679           Inquiry                             SLAMAN
# 680           Inquiry         Customer Preferred Dormant
# 681           Inquiry                           SLCERMAT
# 682           Inquiry                              SLXPR
# 683           Inquiry                             NEWPVI
# 684           Inquiry                            VALAS50
# 685           Inquiry                            SOMPOCP
# 686           Inquiry                              GSUSD
# 687           Inquiry                                RBP
# 688           Inquiry                            CPXS500
# 689           Inquiry           Customer Preferred Valas
# 690           Inquiry                        MLDCASHBACK
# 691           Inquiry                       UPGRADESTAFF
# 692           Inquiry                          GSDIGITAL
# 693           Inquiry                          UPGRADEKM
# 694           Inquiry                             CPCXTF
# 695           Inquiry           Customer Preferred Blast
# 696           Inquiry                    Special Invitee
# 697           Inquiry                  Qualified Invitee
# 698           Inquiry             Qualified Invitee OCTO
# 699           Inquiry             Qualified Invitee PSRM
# 700           Inquiry                         NTP Reward
# 701           Inquiry                                MGM
# 702           Inquiry           Customer Preferred Staff
# 703           Inquiry                                RTE
# 704           Inquiry                Preferred Assistant
# 705           Inquiry                              GSNTP
# 706           Request                                ATM
# 707           Request                                ATM
# 708           Request                                ATM
# 709           Request                                ATM
# 710           Request                                ATM
# 711           Request                                ATM
# 712           Request                                CDM
# 713           Request                                CDM
# 714           Request                                CDM
# 715           Request                                CDM
# 716           Request                                CDM
# 717           Request                                CRM
# 718           Request                                CRM
# 719           Request                                CRM
# 720           Request                                CRM
# 721           Request                                CRM
# 722           Request                         Debit Card
# 723           Request                         Debit Card
# 724           Request                         Debit Card
# 725           Request                         Debit Card
# 726           Request                         Debit Card
# 727           Request                         Debit Card
# 728           Request                         Debit Card
# 729           Request                        OCTO Clicks
# 730           Request                        OCTO Clicks
# 731           Request                        OCTO Clicks
# 732           Request                        OCTO Clicks
# 733           Request                        OCTO Clicks
# 734           Request                        OCTO Clicks
# 735           Request                        OCTO Clicks
# 736           Request                        OCTO Clicks
# 737           Request                        OCTO Clicks
# 738           Request                        OCTO Clicks
# 739           Request                        OCTO Clicks
# 740           Request                        OCTO Mobile
# 741           Request                        OCTO Mobile
# 742           Request                        OCTO Mobile
# 743           Request                        OCTO Mobile
# 744           Request                        OCTO Mobile
# 745           Request                        OCTO Mobile
# 746           Request                        OCTO Mobile
# 747           Request                        OCTO Mobile
# 748           Request                        OCTO Mobile
# 749           Request                        OCTO Mobile
# 750           Request                        OCTO Mobile
# 751           Request                        OCTO Mobile
# 752           Request                           OCTO Pay
# 753           Request                           OCTO Pay
# 754           Request                           OCTO Pay
# 755           Request                           OCTO Pay
# 756           Request                           OCTO Pay
# 757           Request                           OCTO Pay
# 758           Request                           OCTO Pay
# 759           Request                           OCTO Pay
# 760           Request                               QRIS
# 761           Request                               QRIS
# 762           Request                               QRIS
# 763           Request                               QRIS
# 764           Request                             Rekpon
# 765           Request                             Rekpon
# 766           Request                             Rekpon
# 767           Request                             Rekpon
# 768           Request                        Credit Card
# 769           Request                        Credit Card
# 770           Request                        Credit Card
# 771           Request                        Credit Card
# 772           Request                        Credit Card
# 773           Request                        Credit Card
# 774           Request                        Credit Card
# 775           Request                        Credit Card
# 776           Request                        Credit Card
# 777           Request                        Credit Card
# 778           Request                        Credit Card
# 779           Request                        Credit Card
# 780           Request                        Credit Card
# 781           Request                        Credit Card
# 782           Request                        Credit Card
# 783           Request                        Credit Card
# 784           Request                        Credit Card
# 785           Request                        Credit Card
# 786           Request                        Credit Card
# 787           Request                        Credit Card
# 788           Request                        Credit Card
# 789           Request                        Credit Card
# 790           Request                        Credit Card
# 791           Request                        Credit Card
# 792           Request                        Credit Card
# 793           Request                        Credit Card
# 794           Request                        Credit Card
# 795           Request                        Credit Card
# 796           Request                        Credit Card
# 797           Request                        Credit Card
# 798           Request                        Credit Card
# ...
# 893                                               Fitur
# 894                                 Kendala Menghubungi
# 895                                 Kendala Pendaftaran
# 896                              Transaksi Dalam Proses
# 897                                     Transaksi Gagal
# 898                                               Other
# 899                                     Cakupan Layanan
# 900                     Ketidaksesuaian Jam Operasional
# 901                                         Operasional
# 902                                               Other
# 903                                          SWIFT Code
# 904                                               Other
# 905                                     Cakupan Layanan
# 906                                         Operasional
# 907                                               Other
# 908                              Digital Branch Manager
# 909                                               Other
# 910                             Penambahan/ Pengurangan
# 911                             Penerbitan/ Penggantian
# 912                   Tidak Berfungsi/ Kendala Jaringan
# 913                                     Cakupan Layanan
# 914                                           Interaksi
# 915                                               Other
# 916                                     Cakupan Layanan
# 917                                           Interaksi
# 918                                               Other
# 919                Permintaan informasi dari RM/ Cabang
# 920                              Fitur/ Cakupan Layanan
# 921                                        Kontak Other
# 922                                   Kontak/ Dihubungi
# 923                               Tidak Dapat Terhubung
# 924                                        Layanan CIMB
# 925                                               Other
# 926                                               Other
# 927                              Informasi Tidak Sesuai
# 928                                               Other
# 929                                               Blast
# 930                                            Whatsapp
# 931                                            Whatsapp
# 932                                            Whatsapp
# 933                                           SMS Blast
# 934                                           SMS Blast
# 935                                           SMS Blast
# 936                                           SMS Blast
# 937                                           SMS Blast
# 938                                           SMS Blast
# 939                                           SMS Blast
# 940                                           SMS Blast
# 941                                      WhatsApp Blast
# 942                                      WhatsApp Blast
# 943                                      WhatsApp Blast
# 944                                      WhatsApp Blast
# 945                                      WhatsApp Blast
# 946                                      WhatsApp Blast
# 947                                      WhatsApp Blast
# 948                                      WhatsApp Blast
# 949                                         Email Blast
# 950                                         Email Blast
# 951                                         Email Blast
# 952                                         Email Blast
# 953                                         Email Blast
# 954                                         Email Blast
# 955                                         Email Blast
# 956                                         Email Blast
# 957                                               Other
# 958                                               Other
# 959                             Program Preferred Blast
# 960                             Program Preferred Blast
# 961                             Program Preferred Blast
# 962                             Program Preferred Blast
# 963                             Program Preferred Blast
# 964                                               Other
# 965                             Program Preferred Blast
# 966                             Program Preferred Blast
# 967                             Program Preferred Blast
# 968                             Program Preferred Blast
# 969                             Program Preferred Blast
# 970                             Program Preferred Blast
# 971                             Program Preferred Blast
# 972                             Program Preferred Blast
# 973                             Program Preferred Blast
# 974                             Program Preferred Blast
# 975                             Program Preferred Blast
# 976                             Program Preferred Blast
# 977                             Program Preferred Blast
# 978                             Program Preferred Blast
# 979                             Program Preferred Blast
# 980                             Program Preferred Blast
# 981                             Program Preferred Blast
# 982                             Program Preferred Blast
# 983                             Program Preferred Blast
# 984                                        Chinese Yuan
# 985                             Program Preferred Blast
# 986                             Program Preferred Blast
# 987                             Program Preferred Blast
# 988                             Program Preferred Blast
# 989                             Program Preferred Blast
# 990                             Program Preferred Blast
# 991                             Program Preferred Blast
# 992                             Program Preferred Blast
# 993                             Program Preferred Blast
# 994                             Program Preferred Blast
# 995                             Program Preferred Blast
# 996                             Program Preferred Blast
# 997                             Program Preferred Blast
# 998                             Program Preferred Blast
# 999                             Program Preferred Blast
# 1000                            Program Preferred Blast
# 1001                                               Spam
# 1002                                               Spam
# 1003                                        Status Open
# 1004                                        Status Open
# 1005                                        Status Open
# 1006                                        Status Open
